# %%
import sys
sys.path.append('../code')
import sampler
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import numpy as np
import scipy as sp
import scipy.optimize

# %%
import mpoints
import mpoints.hybrid_hawkes_exp

# %%
# ?mpoints.hybrid_hawkes_exp.HybridHawkesExp.simulate

# %%
mpoints.hybrid_hawkes_exp.HybridHawkesExp.simulate
# Out:
# <function mpoints.hybrid_hawkes_exp.HybridHawkesExp.simulate(self, time_start: float, time_end: float, initial_condition_times: Optional[Sequence] = None, initial_condition_events: Optional[Sequence] = None, initial_condition_states: Optional[Sequence] = None, initial_partial_sums: Optional[<built-in function array>] = None, initial_state: int = 0, max_number_of_events: int = 1000000)>

# %% [markdown]
# # Simulation

# %%
mu = 1
alpha = 1
beta = 1.1
T = 200

# %%
events = sampler.generate_events(base_rate=mu,alpha=alpha,beta=beta,maxtime=T)

# %%
times = np.array([e[0] for e in events])

# %%
plt.scatter([e[0] for e in events],[0 for _ in events])
plt.plot([e[0] for e in events],[e[1] for e in events])

# %%
plt.vlines([e[0] for e in events[100:130]],1,2,color='red',alpha=0.2)
plt.plot([e[0] for e in events[100:130]],[e[1] for e in events[100:130]])
plt.xlabel('Time')
plt.ylabel('Intensity')
# Out:
# Text(0, 0.5, 'Intensity')

# %% [markdown]
# # EM

# %% [markdown]
# $$\lambda_0(t)=\mu, \lambda_j(t) = p(t-t_j)^{-1}$$

# %% [markdown]
# $$Q\left(\hat\theta\right) = \mathbb E[\log \mathcal L(t,b;\hat\theta)]=-\int_0^T \lambda(t)dt + \sum_{i=1}^n \mathbb E[\log\left(\lambda_{b_i}(t_i)\right)]=-\int_0^T \lambda(t)dt + \sum_{i=1}^n \sum_{j=0}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\log\left(\lambda_{j}(t_i)\right)$$

# %% [markdown]
# $$=-\mu T - \sum_{j=1}^n \int_{t_j}^T p(t-t_j)^{-1} dt + \sum_{i=1}^n \left(\mathbb P(b_i=0\vert t,\hat\theta)\log(\mu)-\sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\log(p(t_i-t_j))\right)$$

# %% [markdown]
# $$Q_{p_k}(\hat\theta)= \sum_{j=1}^n \int_{t_j}^T (t-t_j)^k p(t-t_j)^{-2} dt - \sum_{i=1}^n \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)(t_i-t_j)^k p(t_i-t_j)^{-1}$$

# %% [markdown]
# $$\sum_{i=1}^n \left(p(t_i-t_j)\int_{t_i}^T(t-t_i)^k p(t-t_i)^{-2}dt - \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)(t_i-t_j)^k\right)=0$$

# %% [markdown]
# $$\theta=\left[\begin{matrix}\mu\\\alpha\\\beta\\\tau\end{matrix}\right]$$

# %% [markdown]
# $$\lambda_0(t)=\mu, \lambda_j(t) = \alpha(\tau+t-t_j)^\beta$$

# %% [markdown]
# $$Q\left(\hat\theta\right) = \mathbb E[\log \mathcal L(t,b;\hat\theta)]=-\int_0^T \lambda(t)dt + \sum_{i=1}^n \mathbb E[\log\left(\lambda_{b_i}(t_i)\right)]=-\int_0^T \lambda(t)dt + \sum_{i=1}^n \sum_{j=0}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\log\left(\lambda_{j}(t_i)\right)$$

# %% [markdown]
# $$=-\mu T - \alpha \sum_{j=1}^n \int_{t_j}^T (\tau+t-t_j)^\beta dt + \sum_{i=1}^n \left(\mathbb P(b_i=0\vert t,\hat\theta)\log(\mu)+\sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\left(\log\left(\alpha\right)+\beta \log(\tau+t_i-t_j)\right)\right)$$

# %% [markdown]
# $$=-\mu T - \frac{\alpha}{\beta+1} \sum_{j=1}^n \left((\tau+T-t_j)^{\beta+1}-\tau^{\beta+1}\right) + \sum_{i=1}^n \left(\mathbb P(b_i=0\vert t,\hat\theta)\log(\mu)+\sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\left(\log\left(\alpha\right)+\beta \log(\tau+t_i-t_j)\right)\right)$$

# %% [markdown]
# $$\lambda(t) = \mu + \sum_{t_j<t}\alpha \exp(\beta (t_j-t))$$

# %% [markdown]
# $$\theta=\left[\begin{matrix}\mu\\\alpha\\\beta\end{matrix}\right]$$

# %% [markdown]
# $$\phi(t) = \sum_{t_i< t} \alpha \exp(\beta (t_i-t))$$

# %% [markdown]
# $$Q\left(\hat\theta\right) = \mathbb E[\log \mathcal L(t,b;\hat\theta)]=-\int_0^T \lambda(t)dt + \sum_{i=1}^n \mathbb E[\log\left(\lambda_{b_i}(t_i)\right)]=-\int_0^T \lambda(t)dt + \sum_{i=1}^n \sum_{j=0}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\log\left(\lambda_{j}(t_i)\right)$$$$=-\mu T - \sum_{j=1}^n \int_{t_j}^T \alpha\exp\left(\beta(t_j-t)\right)dt + \sum_{i=1}^n \sum_{j=0}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\log\left(\lambda_{j}(t_i)\right)$$$$=-\mu T + \frac{\alpha}{\beta}\sum_{j=1}^n \left(\exp\left(\beta(t_j-T)\right)-1\right) + \sum_{i=1}^n \sum_{j=0}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)\log\left(\lambda_{j}(t_i)\right)$$

# %% [markdown]
# $$Q_\mu\left(\hat\theta\right) =-T + \frac{1}{\mu}\sum_{i=1}^n \mathbb P(b_i=0\vert t,\hat\theta)=0\implies \mu=\frac{1}{T}\sum_{i=1}^n \mathbb P(b_i=0\vert t,\hat\theta)$$

# %% [markdown]
# $$Q_\alpha(\hat\theta)=-\sum_{j=1}^n\int_{t_j}^T\exp(\beta(t_j-t))dt+\frac{1}{\alpha}\sum_{i=2}^n \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)=0\implies \alpha=\frac{\sum_{i=2}^n \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)}{\sum_{j=1}^n\int_{t_j}^T\exp(\beta(t_j-t))dt}=\frac{\beta\sum_{i=2}^n \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)}{\sum_{j=1}^n1-\exp(\beta(t_j-T))}$$

# %% [markdown]
# $$Q_\beta(\hat\theta)=-\sum_{j=1}^n\int_{t_j}^T(t_j-t)\alpha\exp(\beta(t_j-t))dt+\sum_{i=2}^n \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)(t_j-t_i)=\alpha\sum_{j=1}^n\frac{1-(\beta(T-t_j)+1)\exp(\beta(t_j-T))}{\beta^2}+\sum_{i=2}^n \sum_{j=1}^{i-1}\mathbb P(b_i=j\vert t,\hat\theta)(t_j-t_i)$$

# %%
n = len(events)

print("E")
#E step
branching_matrix = np.array([[0 for _ in range(len(events)+1)]]+[[mu]+[alpha*np.exp(beta*(e2[0]-e[0])) if e2[0]<e[0] else 0 for e2 in events] for e in events])
c = branching_matrix.sum(axis=1)
c[0] = 1
branching_matrix /= c.reshape(-1,1)

# %%
plt.imshow(branching_matrix[:20,:20])

# %%
prev_intensity = 0
prev_time = 0
for i,e in enumerate(events):
    time = e[0]
    intensity[i,1] = prev_intensity * np.exp(-beta*(time-prev_time))
    prev_intensity = intensity[i,1] + alpha
    prev_time = time

print("Normalise")
intensity_total = intensity.copy()
c = intensity.sum(axis=1)
intensity /= c.reshape(-1,1)
print(intensity,intensity_total)

def q(logbeta):
    beta = jnp.exp(logbeta)
    alpha = beta * intensity[:,1].sum() / (1-jnp.exp(beta*(times-T))).sum()
    mu = (1/T) * intensity[:,0].sum()
    sum_residuals = mu*T + (alpha/beta)*(1-jnp.exp(beta*(times-T))).sum()
    #assert np.allclose([branching_matrix[i,0]+sum([branching_matrix[i,j] for j in range(1,i)]) for i in range(1,n+1)],1)
    sum_expected_event_ll = (intensity[:,0]*np.log(mu)).sum() + (intensity[:,1]*jnp.log(np.cumsum(alpha*jnp.exp(-beta*(times-np.append(0,times[:-1])))))).sum()
    print(mu,alpha,sum_residuals,sum_expected_event_ll,(intensity[:,0]*np.log(mu)).sum(),(intensity[:,1]*jnp.log(np.cumsum(alpha*jnp.exp(-beta*(times-np.append(0,times[:-1])))))).sum())
    return sum_expected_event_ll - sum_residuals
q(1)

def q(logbeta):
    beta = jnp.exp(logbeta)
    alpha = beta * branching_matrix[1:,1:].sum() / (1-jnp.exp(beta*(times-T))).sum()
    mu = (1/T) * branching_matrix[1:,0].sum()
    sum_residuals = mu*T + (alpha/beta)*(1-jnp.exp(beta*(times-T))).sum()
    #assert np.allclose([branching_matrix[i,0]+sum([branching_matrix[i,j] for j in range(1,i)]) for i in range(1,n+1)],1)
    sum_expected_event_ll = (branching_matrix[1:n+1,0]*np.log(mu)).sum() + (branching_matrix[1:,1:]*(jnp.log(alpha)+beta*(times-times.reshape(-1,1)))).sum()
    print(mu,alpha,sum_residuals,sum_expected_event_ll,(branching_matrix[1:n+1,0]*np.log(mu)).sum(),(branching_matrix[1:,1:]*(jnp.log(alpha)+beta*(times-times.reshape(-1,1)))).sum())
    return sum_expected_event_ll - sum_residuals
q(1)

# %%
x = np.log(np.linspace(1,3,100))
plt.plot(x, [q(x_) for x_ in x])
del x

# %%
branching_matrix[1:,1:].sum(axis=1)

# %%
intensity

# %%
n = len(events)
times = np.array([e[0] for e in events])
    
print("E")
#E step
intensity = np.zeros((n,2))
intensity[:,0] = mu

prev_intensity = 0
prev_time = 0
for i,e in enumerate(events):
    time = e[0]
    intensity[i,1] = prev_intensity * np.exp(-beta*(time-prev_time))
    prev_intensity = intensity[i,1] + alpha
    prev_time = time

print("Normalise")
c = intensity.sum(axis=1)
intensity /= c.reshape(-1,1)

plt.imshow(intensity[:10].T)
plt.show()

logbeta = np.log(beta)

print("M")
#M step
#@jax.jit
def q(logbeta):
    beta = jnp.exp(logbeta)
    alpha = beta * intensity[:,1].sum() / (1-jnp.exp(beta*(times-T))).sum()
    mu = (1/T) * intensity[:,0].sum()
    sum_residuals = mu*T + (alpha/beta)*(1-jnp.exp(beta*(times-T))).sum()
    #assert np.allclose([branching_matrix[i,0]+sum([branching_matrix[i,j] for j in range(1,i)]) for i in range(1,n+1)],1)
    
    intensity_new = np.zeros((n,2))
    prev_intensity = 0
    prev_time = 0
    for i,time in enumerate(times):
        intensity_new[i,0] = mu
        #print(prev_intensity * jnp.exp(-beta*(time-prev_time)))
        intensity_new[i,1] = prev_intensity * jnp.exp(-beta*(time-prev_time))
        prev_intensity = intensity_new[i,1] + alpha
        prev_time = time
        
    sum_expected_event_ll = jnp.where(intensity>0,intensity*jnp.log(intensity_new),0).sum()
    
    return sum_expected_event_ll - sum_residuals

x = np.log(np.linspace(1,3,100))
plt.plot(x, [q(x_) for x_ in x])
del x

# %%
jnp.tril(alpha*jnp.exp(beta*(times-times.reshape(-1,1))))

# %%
plt.imshow(jnp.tril(alpha*jnp.exp(beta*(times-times.reshape(-1,1)))))

# %%
n = len(times)
intensity = np.zeros((n,2))
intensity[:,0] = mu
prev_intensity = 0
prev_time = 0
for i,e in enumerate(events):
    time = e[0]
    intensity[i,1] = prev_intensity * np.exp(-beta*(time-prev_time))
    prev_intensity = intensity[i,1] + alpha
    prev_time = time

# %%
intensity[:,1]

# %%
def em(events, T, theta_guess = [0.5,0.5,0.5], steps=1000, learning_rate=0.01):
    mu,alpha,beta = theta_guess
    n = len(events)
    times = np.array([e[0] for e in events])
    
    momentum = 0
    loglikelihood_opt = None
    theta_opt = None
    for _ in range(steps):
        def intensity(alpha,beta,mu):
            branching_matrix = jnp.triu(alpha*jnp.exp(beta*(times.reshape(-1,1)-times.reshape(1,-1))), k=1)
            return jnp.stack([jnp.array([mu]*n),branching_matrix.sum(axis=0)]).T
        
        print("E")
        #E step
        print("Normalise")
        intensity_normal = intensity(alpha,beta,mu)
        print(intensity_normal)
        c = intensity_normal.sum(axis=1)
        intensity_normal /= c.reshape(-1,1)
        
        plt.imshow(intensity_normal[:10].T)
        plt.show()
        
        logbeta = np.log(beta)
        
        print("M")
        @jax.jit
        def sum_residuals(alpha,beta,mu):
            return mu*T + (alpha/beta)*(1-jnp.exp(beta*(times-T))).sum()
        
        @jax.jit
        def sum_expected_event_ll(alpha,beta,mu):
            intensity_new = intensity(alpha,beta,mu)
            return jnp.where(intensity_normal>0,intensity_normal*jnp.log(intensity_new),0).sum()
        
        #M step
        #@jax.jit
        def q(logbeta):
            beta = jnp.exp(logbeta)
            alpha = beta * intensity_normal[:,1].sum() / (1-jnp.exp(beta*(times-T))).sum()
            mu = (1/T) * intensity_normal[:,0].sum()
            #assert np.allclose([branching_matrix[i,0]+sum([branching_matrix[i,j] for j in range(1,i)]) for i in range(1,n+1)],1)

            return sum_expected_event_ll(alpha,beta,mu) - sum_residuals(alpha,beta,mu)
        
        logbeta = scipy.optimize.minimize(lambda logbeta : -q(logbeta), 1, args=(), method='Nelder-Mead').x
        
        print("q")
        loglikelihood = q(logbeta)
        print(loglikelihood)
#         gradient_step = np.array(jax.grad(q)(logbeta))
#         step_size = learning_rate * np.linalg.norm(gradient_step)**-2
#         logbeta += step_size * gradient_step

#         print("Newton Step")
#         print(jax.grad(q)(logbeta), jax.hessian(q)(logbeta))
#         newton_step = -jax.grad(q)(logbeta) / jax.hessian(q)(logbeta)
#         logbeta += newton_step
        
        print("Beta,mu,alpha")
        beta = np.exp(logbeta)
        mu = (1/T) * intensity_normal[:,0].sum()
        alpha = beta * intensity_normal[:,1].sum() / (1-jnp.exp(beta*(times-T))).sum()
        
        print("Update loglikelihood_opt")
        if loglikelihood_opt is None or loglikelihood > loglikelihood_opt:
            theta_opt = mu,alpha,beta
            loglikelihood_opt = loglikelihood
        
        #print(f'{loglikelihood=}\n{mu,alpha,beta=}\n{gradient_step*step_size=}\n')
        print(f'{loglikelihood=}\n{mu,alpha,beta=}\n')
        
        """
        newton_step = -np.linalg.solve(jax.hessian(q)([logalpha,beta]), jax.grad(q)([logalpha,beta]))
        gradient_step = np.array(jax.grad(q)([logalpha,beta]))
        print(f'{logalpha,beta=}, {newton_step=}, {gradient_step=}')
        if all((newton_step*gradient_step)>0):
            print('newton')
            logalpha,beta = np.array([logalpha,beta]) + newton_step
        else:
            print('gradient')
            logalpha,beta = np.array([logalpha,beta]) + step_size * gradient_step
        """
        
        
    return theta_opt

# %%
em(events,T,theta_guess=[0.5,0.5,0.5])
# Out:
# E
# Normalise
# [[0.5        0.        ]
#  [0.5        0.3670398 ]
#  [0.5        0.72331953]
#  ...
#  [0.5        4.832791  ]
#  [0.5        5.106716  ]
#  [0.5        4.785328  ]]
# M
# q
# [2450.0205]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2450.0205], dtype=float32)
# mu,alpha,beta=(Array(0.49615413, dtype=float32), Array([0.82171345], dtype=float32), array([0.8634019]))
#
# E
# Normalise
# [[0.49615413 0.        ]
#  [0.49615413 0.48182037]
#  [0.49615413 0.95325166]
#  ...
#  [0.49615413 3.826791  ]
#  [0.49615413 4.3134747 ]
#  [0.49615413 3.906229  ]]
# M
# q
# [2439.352]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2439.352], dtype=float32)
# mu,alpha,beta=(Array(0.5225279, dtype=float32), Array([0.85591465], dtype=float32), array([0.90201421]))
#
# E
# Normalise
# [[0.5225279  0.        ]
#  [0.5225279  0.49003527]
#  [0.5225279  0.9705902 ]
#  ...
#  [0.5225279  3.7721934 ]
#  [0.5225279  4.2802057 ]
#  [0.5225279  3.8594353 ]]
# M
# q
# [2425.2256]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2425.2256], dtype=float32)
# mu,alpha,beta=(Array(0.55032986, dtype=float32), Array([0.8586782], dtype=float32), array([0.90766946]))
#
# E
# Normalise
# [[0.55032986 0.        ]
#  [0.55032986 0.48990154]
#  [0.55032986 0.9704952 ]
#  ...
#  [0.55032986 3.7548952 ]
#  [0.55032986 4.2646737 ]
#  [0.55032986 3.8429484 ]]
# M
# q
# [2410.919]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2410.919], dtype=float32)
# mu,alpha,beta=(Array(0.57852596, dtype=float32), Array([0.86140597], dtype=float32), array([0.91336016]))
#
# E
# Normalise
# [[0.57852596 0.        ]
#  [0.57852596 0.48973167]
#  [0.57852596 0.97033244]
#  ...
#  [0.57852596 3.7375383 ]
#  [0.57852596 4.2490554 ]
#  [0.57852596 3.826375  ]]
# M
# q
# [2396.7275]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2396.7275], dtype=float32)
# mu,alpha,beta=(Array(0.60704726, dtype=float32), Array([0.86141497], dtype=float32), array([0.91621887]))
#
# E
# Normalise
# [[0.60704726 0.        ]
#  [0.60704726 0.48887193]
#  [0.60704726 0.96871716]
#  ...
#  [0.60704726 3.723041  ]
#  [0.60704726 4.2346206 ]
#  [0.60704726 3.81212   ]]
# M
# q
# [2382.704]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2382.704], dtype=float32)
# mu,alpha,beta=(Array(0.63572246, dtype=float32), Array([0.8640899], dtype=float32), array([0.92196317]))
#
# E
# Normalise
# [[0.63572246 0.        ]
#  [0.63572246 0.48865145]
#  [0.63572246 0.96845955]
#  ...
#  [0.63572246 3.7056527 ]
#  [0.63572246 4.2189293 ]
#  [0.63572246 3.795469  ]]
# M
# q
# [2368.8818]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2368.8818], dtype=float32)
# mu,alpha,beta=(Array(0.6645757, dtype=float32), Array([0.86405057], dtype=float32), array([0.92484881]))
#
# E
# Normalise
# [[0.6645757  0.        ]
#  [0.6645757  0.48775822]
#  [0.6645757  0.9667801 ]
#  ...
#  [0.6645757  3.691115  ]
#  [0.6645757  4.20442   ]
#  [0.6645757  3.7811477 ]]
# M
# q
# [2355.2842]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2355.2842], dtype=float32)
# mu,alpha,beta=(Array(0.6934273, dtype=float32), Array([0.86669993], dtype=float32), array([0.93064722]))
#
# E
# Normalise
# [[0.6934273  0.        ]
#  [0.6934273  0.48750296]
#  [0.6934273  0.9664589 ]
#  ...
#  [0.6934273  3.6738167 ]
#  [0.6934273  4.1887946 ]
#  [0.6934273  3.7645452 ]]
# M
# q
# [2341.9414]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2341.9414], dtype=float32)
# mu,alpha,beta=(Array(0.72230995, dtype=float32), Array([0.86664045], dtype=float32), array([0.93356004]))
#
# E
# Normalise
# [[0.72230995 0.        ]
#  [0.72230995 0.48659238]
#  [0.72230995 0.96474755]
#  ...
#  [0.72230995 3.6593616 ]
#  [0.72230995 4.174351  ]
#  [0.72230995 3.7502828 ]]
# M
# q
# [2328.871]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2328.871], dtype=float32)
# mu,alpha,beta=(Array(0.7510391, dtype=float32), Array([0.86929214], dtype=float32), array([0.93941306]))
#
# E
# Normalise
# [[0.7510391  0.        ]
#  [0.7510391  0.48631817]
#  [0.7510391  0.96439433]
#  ...
#  [0.7510391  3.6422737 ]
#  [0.7510391  4.158927  ]
#  [0.7510391  3.73385   ]]
# M
# q
# [2316.1008]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2316.1008], dtype=float32)
# mu,alpha,beta=(Array(0.77965903, dtype=float32), Array([0.86788654], dtype=float32), array([0.94088204]))
#
# E
# Normalise
# [[0.77965903 0.        ]
#  [0.77965903 0.48509106]
#  [0.77965903 0.962009  ]
#  ...
#  [0.77965903 3.6293678 ]
#  [0.77965903 4.1452065 ]
#  [0.77965903 3.7208853 ]]
# M
# q
# [2303.6484]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2303.6484], dtype=float32)
# mu,alpha,beta=(Array(0.80792344, dtype=float32), Array([0.8719275], dtype=float32), array([0.94826147]))
#
# E
# Normalise
# [[0.80792344 0.        ]
#  [0.80792344 0.4851312 ]
#  [0.80792344 0.9623333 ]
#  ...
#  [0.80792344 3.611276  ]
#  [0.80792344 4.1296144 ]
#  [0.80792344 3.7036426 ]]
# M
# q
# [2291.539]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2291.539], dtype=float32)
# mu,alpha,beta=(Array(0.83601195, dtype=float32), Array([0.87190974], dtype=float32), array([0.95122942]))
#
# E
# Normalise
# [[0.83601195 0.        ]
#  [0.83601195 0.48423192]
#  [0.83601195 0.96064895]
#  ...
#  [0.83601195 3.5973256 ]
#  [0.83601195 4.1156893 ]
#  [0.83601195 3.6898472 ]]
# M
# q
# [2279.747]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2279.747], dtype=float32)
# mu,alpha,beta=(Array(0.8636785, dtype=float32), Array([0.8719247], dtype=float32), array([0.95420667]))
#
# E
# Normalise
# [[0.8636785  0.        ]
#  [0.8636785  0.48334965]
#  [0.8636785  0.95899916]
#  ...
#  [0.8636785  3.5835772 ]
#  [0.8636785  4.101985  ]
#  [0.8636785  3.6762497 ]]
# M
# q
# [2268.333]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2268.333], dtype=float32)
# mu,alpha,beta=(Array(0.8908665, dtype=float32), Array([0.8719782], dtype=float32), array([0.95719323]))
#
# E
# Normalise
# [[0.8908665  0.        ]
#  [0.8908665  0.48248762]
#  [0.8908665  0.95739   ]
#  ...
#  [0.8908665  3.5700543 ]
#  [0.8908665  4.0885253 ]
#  [0.8908665  3.6628745 ]]
# M
# q
# [2257.3047]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2257.3047], dtype=float32)
# mu,alpha,beta=(Array(0.917525, dtype=float32), Array([0.873436], dtype=float32), array([0.9616906]))
#
# E
# Normalise
# [[0.917525   0.        ]
#  [0.917525   0.48195225]
#  [0.917525   0.9564815 ]
#  ...
#  [0.917525   3.555499  ]
#  [0.917525   4.0748825 ]
#  [0.917525   3.648674  ]]
# M
# q
# [2246.6577]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2246.6577], dtype=float32)
# mu,alpha,beta=(Array(0.9436763, dtype=float32), Array([0.87493867], dtype=float32), array([0.96620911]))
#
# E
# Normalise
# [[0.9436763  0.        ]
#  [0.9436763  0.48143452]
#  [0.9436763  0.9556103 ]
#  ...
#  [0.9436763  3.5412068 ]
#  [0.9436763  4.0615253 ]
#  [0.9436763  3.634726  ]]
# M
# q
# [2236.377]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2236.377], dtype=float32)
# mu,alpha,beta=(Array(0.9692814, dtype=float32), Array([0.8751256], dtype=float32), array([0.96923323]))
#
# E
# Normalise
# [[0.9692814 0.       ]
#  [0.9692814 0.4806379]
#  [0.9692814 0.9541342]
#  ...
#  [0.9692814 3.5284376]
#  [0.9692814 4.048892 ]
#  [0.9692814 3.6220899]]
# M
# q
# [2226.4702]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2226.4702], dtype=float32)
# mu,alpha,beta=(Array(0.9942365, dtype=float32), Array([0.8779319], dtype=float32), array([0.97511944]))
#
# E
# Normalise
# [[0.9942365  0.        ]
#  [0.9942365  0.48042753]
#  [0.9942365  0.9539238 ]
#  ...
#  [0.9942365  3.5136492 ]
#  [0.9942365  4.0358167 ]
#  [0.9942365  3.6078017 ]]
# M
# q
# [2216.942]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2216.942], dtype=float32)
# mu,alpha,beta=(Array(1.0186467, dtype=float32), Array([0.87532073], dtype=float32), array([0.97492901]))
#
# E
# Normalise
# [[1.0186467  0.        ]
#  [1.0186467  0.47905508]
#  [1.0186467  0.9511919 ]
#  ...
#  [1.0186467  3.5040345 ]
#  [1.0186467  4.0246477 ]
#  [1.0186467  3.5979013 ]]
# M
# q
# [2207.7812]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2207.7812], dtype=float32)
# mu,alpha,beta=(Array(1.0421995, dtype=float32), Array([0.8784257], dtype=float32), array([0.98104139]))
#
# E
# Normalise
# [[1.0421995  0.        ]
#  [1.0421995  0.478941  ]
#  [1.0421995  0.95118266]
#  ...
#  [1.0421995  3.4897535 ]
#  [1.0421995  4.0122514 ]
#  [1.0421995  3.5841312 ]]
# M
# q
# [2199.0332]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2199.0332], dtype=float32)
# mu,alpha,beta=(Array(1.0651805, dtype=float32), Array([0.8819371], dtype=float32), array([0.9875778]))
#
# E
# Normalise
# [[1.0651805  0.        ]
#  [1.0651805  0.4789161 ]
#  [1.0651805  0.95136917]
#  ...
#  [1.0651805  3.4754953 ]
#  [1.0651805  4.0001144 ]
#  [1.0651805  3.5704083 ]]
# M
# q
# [2190.6074]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2190.6074], dtype=float32)
# mu,alpha,beta=(Array(1.0875946, dtype=float32), Array([0.87966746], dtype=float32), array([0.9875778]))
#
# E
# Normalise
# [[1.0875946  0.        ]
#  [1.0875946  0.47768363]
#  [1.0875946  0.94892085]
#  ...
#  [1.0875946  3.4665513 ]
#  [1.0875946  3.9898202 ]
#  [1.0875946  3.5612202 ]]
# M
# q
# [2182.5176]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2182.5176], dtype=float32)
# mu,alpha,beta=(Array(1.1091106, dtype=float32), Array([0.8774888], dtype=float32), array([0.9875778]))
#
# E
# Normalise
# [[1.1091106  0.        ]
#  [1.1091106  0.47650057]
#  [1.1091106  0.94657063]
#  ...
#  [1.1091106  3.4579656 ]
#  [1.1091106  3.979939  ]
#  [1.1091106  3.5524    ]]
# M
# q
# [2174.8447]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2174.8447], dtype=float32)
# mu,alpha,beta=(Array(1.1297283, dtype=float32), Array([0.8808761], dtype=float32), array([0.99376949]))
#
# E
# Normalise
# [[1.1297283  0.        ]
#  [1.1297283  0.4765123 ]
#  [1.1297283  0.94681966]
#  ...
#  [1.1297283  3.4450634 ]
#  [1.1297283  3.9690745 ]
#  [1.1297283  3.5399802 ]]
# M
# q
# [2167.5547]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2167.5547], dtype=float32)
# mu,alpha,beta=(Array(1.1497585, dtype=float32), Array([0.88295454], dtype=float32), array([0.99843872]))
#
# E
# Normalise
# [[1.1497585  0.        ]
#  [1.1497585  0.47625977]
#  [1.1497585  0.94649   ]
#  ...
#  [1.1497585  3.4336245 ]
#  [1.1497585  3.9588845 ]
#  [1.1497585  3.5288355 ]]
# M
# q
# [2160.5542]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2160.5542], dtype=float32)
# mu,alpha,beta=(Array(1.1691247, dtype=float32), Array([0.8823462], dtype=float32), array([1.]))
#
# E
# Normalise
# [[1.1691247  0.        ]
#  [1.1691247  0.47547245]
#  [1.1691247  0.9449831 ]
#  ...
#  [1.1691247  3.4247727 ]
#  [1.1691247  3.9496741 ]
#  [1.1691247  3.5199382 ]]
# M
# q
# [2153.8667]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2153.8667], dtype=float32)
# mu,alpha,beta=(Array(1.1876756, dtype=float32), Array([0.8859511], dtype=float32), array([1.00626957]))
#
# E
# Normalise
# [[1.1876756  0.        ]
#  [1.1876756  0.47556803]
#  [1.1876756  0.9454076 ]
#  ...
#  [1.1876756  3.4128726 ]
#  [1.1876756  3.9399264 ]
#  [1.1876756  3.5084872 ]]
# M
# q
# [2147.5117]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2147.5117], dtype=float32)
# mu,alpha,beta=(Array(1.2056618, dtype=float32), Array([0.8847847], dtype=float32), array([1.00705603]))
#
# E
# Normalise
# [[1.2056618  0.        ]
#  [1.2056618  0.47471097]
#  [1.2056618  0.9437336 ]
#  ...
#  [1.2056618  3.405165  ]
#  [1.2056618  3.931525  ]
#  [1.2056618  3.5006595 ]]
# M
# q
# [2141.4238]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2141.4238], dtype=float32)
# mu,alpha,beta=(Array(1.2228111, dtype=float32), Array([0.8850811], dtype=float32), array([1.00941908]))
#
# E
# Normalise
# [[1.2228111  0.        ]
#  [1.2228111  0.47417673]
#  [1.2228111  0.94276065]
#  ...
#  [1.2228111  3.3966823 ]
#  [1.2228111  3.9232197 ]
#  [1.2228111  3.4922225 ]]
# M
# q
# [2135.668]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2135.668], dtype=float32)
# mu,alpha,beta=(Array(1.2392237, dtype=float32), Array([0.88614094], dtype=float32), array([1.01257845]))
#
# E
# Normalise
# [[1.2392237  0.        ]
#  [1.2392237  0.47381806]
#  [1.2392237  0.9421674 ]
#  ...
#  [1.2392237  3.3879573 ]
#  [1.2392237  3.915125  ]
#  [1.2392237  3.4836247 ]]
# M
# q
# [2130.2056]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2130.2056], dtype=float32)
# mu,alpha,beta=(Array(1.2549589, dtype=float32), Array([0.8845075], dtype=float32), array([1.01257845]))
#
# E
# Normalise
# [[1.2549589  0.        ]
#  [1.2549589  0.47294465]
#  [1.2549589  0.94043064]
#  ...
#  [1.2549589  3.381712  ]
#  [1.2549589  3.9079075 ]
#  [1.2549589  3.4772031 ]]
# M
# q
# [2125.0186]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2125.0186], dtype=float32)
# mu,alpha,beta=(Array(1.2698721, dtype=float32), Array([0.88571614], dtype=float32), array([1.01574771]))
#
# E
# Normalise
# [[1.2698721  0.        ]
#  [1.2698721  0.47266388]
#  [1.2698721  0.939993  ]
#  ...
#  [1.2698721  3.3736095 ]
#  [1.2698721  3.9005215 ]
#  [1.2698721  3.4692357 ]]
# M
# q
# [2120.1345]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2120.1345], dtype=float32)
# mu,alpha,beta=(Array(1.2841548, dtype=float32), Array([0.8876814], dtype=float32), array([1.01972323]))
#
# E
# Normalise
# [[1.2841548  0.        ]
#  [1.2841548  0.4725497 ]
#  [1.2841548  0.93991864]
#  ...
#  [1.2841548  3.3652422 ]
#  [1.2841548  3.8933182 ]
#  [1.2841548  3.461076  ]]
# M
# q
# [2115.4902]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2115.4902], dtype=float32)
# mu,alpha,beta=(Array(1.297869, dtype=float32), Array([0.8876303], dtype=float32), array([1.0213178]))
#
# E
# Normalise
# [[1.297869   0.        ]
#  [1.297869   0.47205684]
#  [1.297869   0.9389999 ]
#  ...
#  [1.297869   3.3587346 ]
#  [1.297869   3.886777  ]
#  [1.297869   3.4545586 ]]
# M
# q
# [2111.0674]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2111.0674], dtype=float32)
# mu,alpha,beta=(Array(1.3109099, dtype=float32), Array([0.8866104], dtype=float32), array([1.02171683]))
#
# E
# Normalise
# [[1.3109099  0.        ]
#  [1.3109099  0.47139812]
#  [1.3109099  0.9377049 ]
#  ...
#  [1.3109099  3.353301  ]
#  [1.3109099  3.8807354 ]
#  [1.3109099  3.4490137 ]]
# M
# q
# [2106.891]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2106.891], dtype=float32)
# mu,alpha,beta=(Array(1.3232406, dtype=float32), Array([0.8891222], dtype=float32), array([1.02611646]))
#
# E
# Normalise
# [[1.3232406  0.        ]
#  [1.3232406  0.47144946]
#  [1.3232406  0.9379778 ]
#  ...
#  [1.3232406  3.345499  ]
#  [1.3232406  3.8744164 ]
#  [1.3232406  3.4414585 ]]
# M
# q
# [2102.9614]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2102.9614], dtype=float32)
# mu,alpha,beta=(Array(1.3351007, dtype=float32), Array([0.8871826], dtype=float32), array([1.02531512]))
#
# E
# Normalise
# [[1.3351007  0.        ]
#  [1.3351007  0.47065413]
#  [1.3351007  0.93636423]
#  ...
#  [1.3351007  3.3413312 ]
#  [1.3351007  3.8690972 ]
#  [1.3351007  3.4370866 ]]
# M
# q
# [2099.212]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2099.212], dtype=float32)
# mu,alpha,beta=(Array(1.3462349, dtype=float32), Array([0.8867031], dtype=float32), array([1.02611646]))
#
# E
# Normalise
# [[1.3462349  0.        ]
#  [1.3462349  0.47016677]
#  [1.3462349  0.93542576]
#  ...
#  [1.3462349  3.3363967 ]
#  [1.3462349  3.863875  ]
#  [1.3462349  3.4320948 ]]
# M
# q
# [2095.7095]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2095.7095], dtype=float32)
# mu,alpha,beta=(Array(1.3567611, dtype=float32), Array([0.89044076], dtype=float32), array([1.03174341]))
#
# E
# Normalise
# [[1.3567611  0.        ]
#  [1.3567611  0.47050884]
#  [1.3567611  0.9363266 ]
#  ...
#  [1.3567611  3.3285735 ]
#  [1.3567611  3.8582559 ]
#  [1.3567611  3.4246252 ]]
# M
# q
# [2092.4116]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2092.4116], dtype=float32)
# mu,alpha,beta=(Array(1.3669626, dtype=float32), Array([0.89005524], dtype=float32), array([1.03254977]))
#
# E
# Normalise
# [[1.3669626  0.        ]
#  [1.3669626  0.47007075]
#  [1.3669626  0.93548656]
#  ...
#  [1.3669626  3.3240228 ]
#  [1.3669626  3.853472  ]
#  [1.3669626  3.4200232 ]]
# M
# q
# [2089.2368]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2089.2368], dtype=float32)
# mu,alpha,beta=(Array(1.3765973, dtype=float32), Array([0.88920856], dtype=float32), array([1.03275146]))
#
# E
# Normalise
# [[1.3765973  0.        ]
#  [1.3765973  0.46956503]
#  [1.3765973  0.93448806]
#  ...
#  [1.3765973  3.3200843 ]
#  [1.3765973  3.8490293 ]
#  [1.3765973  3.4159915 ]]
# M
# q
# [2086.2534]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2086.2534], dtype=float32)
# mu,alpha,beta=(Array(1.3856612, dtype=float32), Array([0.89015496], dtype=float32), array([1.03497265]))
#
# E
# Normalise
# [[1.3856612  0.        ]
#  [1.3856612  0.46941966]
#  [1.3856612  0.9342865 ]
#  ...
#  [1.3856612  3.3150864 ]
#  [1.3856612  3.8445845 ]
#  [1.3856612  3.411068  ]]
# M
# q
# [2083.458]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2083.458], dtype=float32)
# mu,alpha,beta=(Array(1.3942907, dtype=float32), Array([0.8892393], dtype=float32), array([1.03497265]))
#
# E
# Normalise
# [[1.3942907  0.        ]
#  [1.3942907  0.4689368 ]
#  [1.3942907  0.93332547]
#  ...
#  [1.3942907  3.3116765 ]
#  [1.3942907  3.8406296 ]
#  [1.3942907  3.4075592 ]]
# M
# q
# [2080.8096]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2080.8096], dtype=float32)
# mu,alpha,beta=(Array(1.4023895, dtype=float32), Array([0.891154], dtype=float32), array([1.038212]))
#
# E
# Normalise
# [[1.4023895  0.        ]
#  [1.4023895  0.46900624]
#  [1.4023895  0.933592  ]
#  ...
#  [1.4023895  3.3064342 ]
#  [1.4023895  3.836511  ]
#  [1.4023895  3.4024777 ]]
# M
# q
# [2078.3325]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2078.3325], dtype=float32)
# mu,alpha,beta=(Array(1.410159, dtype=float32), Array([0.8903706], dtype=float32), array([1.03826269]))
#
# E
# Normalise
# [[1.410159   0.        ]
#  [1.410159   0.4685793 ]
#  [1.410159   0.93274415]
#  ...
#  [1.410159   3.303335  ]
#  [1.410159   3.8329456 ]
#  [1.410159   3.399293  ]]
# M
# q
# [2075.967]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2075.967], dtype=float32)
# mu,alpha,beta=(Array(1.4174453, dtype=float32), Array([0.8895516], dtype=float32), array([1.038212]))
#
# E
# Normalise
# [[1.4174453  0.        ]
#  [1.4174453  0.4681629 ]
#  [1.4174453  0.93191326]
#  ...
#  [1.4174453  3.3004887 ]
#  [1.4174453  3.8296125 ]
#  [1.4174453  3.3963597 ]]
# M
# q
# [2073.7568]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2073.7568], dtype=float32)
# mu,alpha,beta=(Array(1.42427, dtype=float32), Array([0.8909061], dtype=float32), array([1.04064816]))
#
# E
# Normalise
# [[1.42427    0.        ]
#  [1.42427    0.46817008]
#  [1.42427    0.9320246 ]
#  ...
#  [1.42427    3.2962768 ]
#  [1.42427    3.8261929 ]
#  [1.42427    3.3922544 ]]
# M
# q
# [2071.6929]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2071.6929], dtype=float32)
# mu,alpha,beta=(Array(1.4307925, dtype=float32), Array([0.8894733], dtype=float32), array([1.0397847]))
#
# E
# Normalise
# [[1.4307925  0.        ]
#  [1.4307925  0.46766677]
#  [1.4307925  0.9309882 ]
#  ...
#  [1.4307925  3.294238  ]
#  [1.4307925  3.8233068 ]
#  [1.4307925  3.3900757 ]]
# M
# q
# [2069.7275]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2069.7275], dtype=float32)
# mu,alpha,beta=(Array(1.4368523, dtype=float32), Array([0.8923416], dtype=float32), array([1.04390527]))
#
# E
# Normalise
# [[1.4368523  0.        ]
#  [1.4368523  0.46798107]
#  [1.4368523  0.9317788 ]
#  ...
#  [1.4368523  3.2893038 ]
#  [1.4368523  3.820055  ]
#  [1.4368523  3.3853772 ]]
# M
# q
# [2067.906]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2067.906], dtype=float32)
# mu,alpha,beta=(Array(1.4427444, dtype=float32), Array([0.8927544], dtype=float32), array([1.04512932]))
#
# E
# Normalise
# [[1.4427444  0.        ]
#  [1.4427444  0.46784335]
#  [1.4427444  0.9315538 ]
#  ...
#  [1.4427444  3.2862322 ]
#  [1.4427444  3.8172212 ]
#  [1.4427444  3.3823261 ]]
# M
# q
# [2066.1406]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2066.1406], dtype=float32)
# mu,alpha,beta=(Array(1.4483218, dtype=float32), Array([0.89180905], dtype=float32), array([1.04472114]))
#
# E
# Normalise
# [[1.4483218 0.       ]
#  [1.4483218 0.4674659]
#  [1.4483218 0.9307858]
#  ...
#  [1.4483218 3.2842808]
#  [1.4483218 3.8147104]
#  [1.4483218 3.380281 ]]
# M
# q
# [2064.4746]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2064.4746], dtype=float32)
# mu,alpha,beta=(Array(1.4535154, dtype=float32), Array([0.8926433], dtype=float32), array([1.04635479]))
#
# E
# Normalise
# [[1.4535154  0.        ]
#  [1.4535154  0.46743083]
#  [1.4535154  0.93078166]
#  ...
#  [1.4535154  3.2812386 ]
#  [1.4535154  3.8121538 ]
#  [1.4535154  3.3772955 ]]
# M
# q
# [2062.927]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2062.927], dtype=float32)
# mu,alpha,beta=(Array(1.4584584, dtype=float32), Array([0.89072347], dtype=float32), array([1.04472114]))
#
# E
# Normalise
# [[1.4584584  0.        ]
#  [1.4584584  0.46689686]
#  [1.4584584  0.9296527 ]
#  ...
#  [1.4584584  3.280283  ]
#  [1.4584584  3.8100665 ]
#  [1.4584584  3.376166  ]]
# M
# q
# [2061.4585]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2061.4585], dtype=float32)
# mu,alpha,beta=(Array(1.4629893, dtype=float32), Array([0.8909758], dtype=float32), array([1.0455887]))
#
# E
# Normalise
# [[1.4629893  0.        ]
#  [1.4629893  0.46677867]
#  [1.4629893  0.92945224]
#  ...
#  [1.4629893  3.277968  ]
#  [1.4629893  3.8078964 ]
#  [1.4629893  3.3738616 ]]
# M
# q
# [2060.1143]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2060.1143], dtype=float32)
# mu,alpha,beta=(Array(1.4672688, dtype=float32), Array([0.89255846], dtype=float32), array([1.047991]))
#
# E
# Normalise
# [[1.4672688  0.        ]
#  [1.4672688  0.46691385]
#  [1.4672688  0.9298182 ]
#  ...
#  [1.4672688  3.2748282 ]
#  [1.4672688  3.8056815 ]
#  [1.4672688  3.370841  ]]
# M
# q
# [2058.8481]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2058.8481], dtype=float32)
# mu,alpha,beta=(Array(1.4713951, dtype=float32), Array([0.89281076], dtype=float32), array([1.04881006]))
#
# E
# Normalise
# [[1.4713951 0.       ]
#  [1.4713951 0.4668094]
#  [1.4713951 0.9296433]
#  ...
#  [1.4713951 3.272709 ]
#  [1.4713951 3.8037066]
#  [1.4713951 3.3687308]]
# M
# q
# [2057.6296]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2057.6296], dtype=float32)
# mu,alpha,beta=(Array(1.475292, dtype=float32), Array([0.8931095], dtype=float32), array([1.04965539]))
#
# E
# Normalise
# [[1.475292   0.        ]
#  [1.475292   0.46672156]
#  [1.475292   0.92950267]
#  ...
#  [1.475292   3.270667  ]
#  [1.475292   3.8018365 ]
#  [1.475292   3.366702  ]]
# M
# q
# [2056.481]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2056.481], dtype=float32)
# mu,alpha,beta=(Array(1.4789752, dtype=float32), Array([0.89130074], dtype=float32), array([1.047991]))
#
# E
# Normalise
# [[1.4789752  0.        ]
#  [1.4789752  0.4662559 ]
#  [1.4789752  0.92850804]
#  ...
#  [1.4789752  3.2702134 ]
#  [1.4789752  3.800319  ]
#  [1.4789752  3.3660913 ]]
# M
# q
# [2055.397]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2055.397], dtype=float32)
# mu,alpha,beta=(Array(1.4823223, dtype=float32), Array([0.89372325], dtype=float32), array([1.0512711]))
#
# E
# Normalise
# [[1.4823223 0.       ]
#  [1.4823223 0.466576 ]
#  [1.4823223 0.9292783]
#  ...
#  [1.4823223 3.2669322]
#  [1.4823223 3.7984552]
#  [1.4823223 3.3629951]]
# M
# q
# [2054.414]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2054.414], dtype=float32)
# mu,alpha,beta=(Array(1.485623, dtype=float32), Array([0.891976], dtype=float32), array([1.04962977]))
#
# E
# Normalise
# [[1.485623  0.       ]
#  [1.485623  0.4661366]
#  [1.485623  0.9283366]
#  ...
#  [1.485623  3.2666109]
#  [1.485623  3.7971063]
#  [1.485623  3.3625245]]
# M
# q
# [2053.446]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2053.446], dtype=float32)
# mu,alpha,beta=(Array(1.4886129, dtype=float32), Array([0.8933936], dtype=float32), array([1.05168183]))
#
# E
# Normalise
# [[1.4886129  0.        ]
#  [1.4886129  0.46628544]
#  [1.4886129  0.9287163 ]
#  ...
#  [1.4886129  3.264211  ]
#  [1.4886129  3.7955344 ]
#  [1.4886129  3.3602285 ]]
# M
# q
# [2052.5708]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2052.5708], dtype=float32)
# mu,alpha,beta=(Array(1.4915124, dtype=float32), Array([0.893429], dtype=float32), array([1.05209272]))
#
# E
# Normalise
# [[1.4915124  0.        ]
#  [1.4915124  0.46618548]
#  [1.4915124  0.928534  ]
#  ...
#  [1.4915124  3.2628245 ]
#  [1.4915124  3.7941663 ]
#  [1.4915124  3.3588362 ]]
# M
# q
# [2051.7231]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2051.7231], dtype=float32)
# mu,alpha,beta=(Array(1.4942385, dtype=float32), Array([0.8938315], dtype=float32), array([1.05291499]))
#
# E
# Normalise
# [[1.4942385  0.        ]
#  [1.4942385  0.46615848]
#  [1.4942385  0.9285135 ]
#  ...
#  [1.4942385  3.2612646 ]
#  [1.4942385  3.7928395 ]
#  [1.4942385  3.3572989 ]]
# M
# q
# [2050.9272]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2050.9272], dtype=float32)
# mu,alpha,beta=(Array(1.4968246, dtype=float32), Array([0.8951209], dtype=float32), array([1.05476745]))
#
# E
# Normalise
# [[1.4968246  0.        ]
#  [1.4968246  0.46629655]
#  [1.4968246  0.92886424]
#  ...
#  [1.4968246  3.2591558 ]
#  [1.4968246  3.791483  ]
#  [1.4968246  3.355281  ]]
# M
# q
# [2050.1736]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2050.1736], dtype=float32)
# mu,alpha,beta=(Array(1.4993359, dtype=float32), Array([0.8920636], dtype=float32), array([1.05147644]))
#
# E
# Normalise
# [[1.4993359  0.        ]
#  [1.4993359  0.46565047]
#  [1.4993359  0.92744327]
#  ...
#  [1.4993359  3.2601082 ]
#  [1.4993359  3.7906427 ]
#  [1.4993359  3.3559885 ]]
# M
# q
# [2049.441]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2049.441], dtype=float32)
# mu,alpha,beta=(Array(1.5014976, dtype=float32), Array([0.89165676], dtype=float32), array([1.0512711]))
#
# E
# Normalise
# [[1.5014976  0.        ]
#  [1.5014976  0.4654972 ]
#  [1.5014976  0.92712957]
#  ...
#  [1.5014976  3.2593784 ]
#  [1.5014976  3.7896724 ]
#  [1.5014976  3.3552194 ]]
# M
# q
# [2048.812]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2048.812], dtype=float32)
# mu,alpha,beta=(Array(1.5035009, dtype=float32), Array([0.8928317], dtype=float32), array([1.05291499]))
#
# E
# Normalise
# [[1.5035009  0.        ]
#  [1.5035009  0.46563706]
#  [1.5035009  0.927475  ]
#  ...
#  [1.5035009  3.2576168 ]
#  [1.5035009  3.7885969 ]
#  [1.5035009  3.3535435 ]]
# M
# q
# [2048.23]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2048.23], dtype=float32)
# mu,alpha,beta=(Array(1.5054568, dtype=float32), Array([0.8912301], dtype=float32), array([1.0512711]))
#
# E
# Normalise
# [[1.5054568  0.        ]
#  [1.5054568  0.46527445]
#  [1.5054568  0.9266859 ]
#  ...
#  [1.5054568  3.2578187 ]
#  [1.5054568  3.787859  ]
#  [1.5054568  3.3536139 ]]
# M
# q
# [2047.6615]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2047.6615], dtype=float32)
# mu,alpha,beta=(Array(1.5071896, dtype=float32), Array([0.89225966], dtype=float32), array([1.05270936]))
#
# E
# Normalise
# [[1.5071896  0.        ]
#  [1.5071896  0.46539786]
#  [1.5071896  0.9269903 ]
#  ...
#  [1.5071896  3.2562854 ]
#  [1.5071896  3.786927  ]
#  [1.5071896  3.352156  ]]
# M
# q
# [2047.1592]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2047.1592], dtype=float32)
# mu,alpha,beta=(Array(1.5088818, dtype=float32), Array([0.893643], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5088818  0.        ]
#  [1.5088818  0.46558595]
#  [1.5088818  0.9274404 ]
#  ...
#  [1.5088818  3.2545297 ]
#  [1.5088818  3.7859795 ]
#  [1.5088818  3.3505018 ]]
# M
# q
# [2046.6691]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2046.6691], dtype=float32)
# mu,alpha,beta=(Array(1.5105586, dtype=float32), Array([0.8948557], dtype=float32), array([1.0562105]))
#
# E
# Normalise
# [[1.5105586  0.        ]
#  [1.5105586  0.46574268]
#  [1.5105586  0.92781997]
#  ...
#  [1.5105586  3.2529051 ]
#  [1.5105586  3.785063  ]
#  [1.5105586  3.3489635 ]]
# M
# q
# [2046.1842]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2046.1842], dtype=float32)
# mu,alpha,beta=(Array(1.5122099, dtype=float32), Array([0.89327246], dtype=float32), array([1.05454858]))
#
# E
# Normalise
# [[1.5122099  0.        ]
#  [1.5122099  0.4653966 ]
#  [1.5122099  0.92706263]
#  ...
#  [1.5122099  3.253227  ]
#  [1.5122099  3.784457  ]
#  [1.5122099  3.3491597 ]]
# M
# q
# [2045.7057]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2045.7057], dtype=float32)
# mu,alpha,beta=(Array(1.5136569, dtype=float32), Array([0.8933009], dtype=float32), array([1.05476745]))
#
# E
# Normalise
# [[1.5136569  0.        ]
#  [1.5136569  0.46534845]
#  [1.5136569  0.92697567]
#  ...
#  [1.5136569  3.2525291 ]
#  [1.5136569  3.783774  ]
#  [1.5136569  3.3484588 ]]
# M
# q
# [2045.2867]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2045.2867], dtype=float32)
# mu,alpha,beta=(Array(1.5150162, dtype=float32), Array([0.8954087], dtype=float32), array([1.05743606]))
#
# E
# Normalise
# [[1.5150162  0.        ]
#  [1.5150162  0.4656775 ]
#  [1.5150162  0.92774045]
#  ...
#  [1.5150162  3.250439  ]
#  [1.5150162  3.782915  ]
#  [1.5150162  3.3465223 ]]
# M
# q
# [2044.8951]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2044.8951], dtype=float32)
# mu,alpha,beta=(Array(1.5164269, dtype=float32), Array([0.89456886], dtype=float32), array([1.05662316]))
#
# E
# Normalise
# [[1.5164269  0.        ]
#  [1.5164269  0.4654746 ]
#  [1.5164269  0.92730296]
#  ...
#  [1.5164269  3.2503552 ]
#  [1.5164269  3.7823389 ]
#  [1.5164269  3.3463714 ]]
# M
# q
# [2044.4874]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2044.4874], dtype=float32)
# mu,alpha,beta=(Array(1.5176961, dtype=float32), Array([0.8926928], dtype=float32), array([1.05456468]))
#
# E
# Normalise
# [[1.5176961 0.       ]
#  [1.5176961 0.46509  ]
#  [1.5176961 0.9264525]
#  ...
#  [1.5176961 3.251057 ]
#  [1.5176961 3.7819421]
#  [1.5176961 3.3469274]]
# M
# q
# [2044.1198]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2044.1198], dtype=float32)
# mu,alpha,beta=(Array(1.5187657, dtype=float32), Array([0.89274853], dtype=float32), array([1.05476745]))
#
# E
# Normalise
# [[1.5187657  0.        ]
#  [1.5187657  0.4650607 ]
#  [1.5187657  0.92640245]
#  ...
#  [1.5187657  3.250518  ]
#  [1.5187657  3.7814343 ]
#  [1.5187657  3.3463883 ]]
# M
# q
# [2043.8114]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.8114], dtype=float32)
# mu,alpha,beta=(Array(1.5197722, dtype=float32), Array([0.8950784], dtype=float32), array([1.05765552]))
#
# E
# Normalise
# [[1.5197722  0.        ]
#  [1.5197722  0.46544257]
#  [1.5197722  0.92728144]
#  ...
#  [1.5197722  3.2484398 ]
#  [1.5197722  3.7807183 ]
#  [1.5197722  3.344482  ]]
# M
# q
# [2043.5226]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.5226], dtype=float32)
# mu,alpha,beta=(Array(1.520866, dtype=float32), Array([0.8925214], dtype=float32), array([1.05476745]))
#
# E
# Normalise
# [[1.520866   0.        ]
#  [1.520866   0.46494237]
#  [1.520866   0.9261668 ]
#  ...
#  [1.520866   3.2496908 ]
#  [1.520866   3.7804723 ]
#  [1.520866   3.3455372 ]]
# M
# q
# [2043.2056]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.2056], dtype=float32)
# mu,alpha,beta=(Array(1.5217271, dtype=float32), Array([0.8934724], dtype=float32), array([1.05600423]))
#
# E
# Normalise
# [[1.5217271  0.        ]
#  [1.5217271  0.46508205]
#  [1.5217271  0.92649543]
#  ...
#  [1.5217271  3.2486298 ]
#  [1.5217271  3.7799666 ]
#  [1.5217271  3.3445451 ]]
# M
# q
# [2042.9585]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.9585], dtype=float32)
# mu,alpha,beta=(Array(1.5225956, dtype=float32), Array([0.89492476], dtype=float32), array([1.05783629]))
#
# E
# Normalise
# [[1.5225956  0.        ]
#  [1.5225956  0.46531066]
#  [1.5225956  0.92702603]
#  ...
#  [1.5225956  3.2472239 ]
#  [1.5225956  3.779409  ]
#  [1.5225956  3.3432443 ]]
# M
# q
# [2042.709]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.709], dtype=float32)
# mu,alpha,beta=(Array(1.5235037, dtype=float32), Array([0.8934541], dtype=float32), array([1.0562105]))
#
# E
# Normalise
# [[1.5235037  0.        ]
#  [1.5235037  0.46501318]
#  [1.5235037  0.9263668 ]
#  ...
#  [1.5235037  3.2478104 ]
#  [1.5235037  3.7791345 ]
#  [1.5235037  3.343718  ]]
# M
# q
# [2042.4469]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.4469], dtype=float32)
# mu,alpha,beta=(Array(1.5242602, dtype=float32), Array([0.89476603], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5242602  0.        ]
#  [1.5242602  0.46522072]
#  [1.5242602  0.92684793]
#  ...
#  [1.5242602  3.2465537 ]
#  [1.5242602  3.7786443 ]
#  [1.5242602  3.3425565 ]]
# M
# q
# [2042.2301]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.2301], dtype=float32)
# mu,alpha,beta=(Array(1.525054, dtype=float32), Array([0.89398295], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.525054   0.        ]
#  [1.525054   0.46505105]
#  [1.525054   0.926476  ]
#  ...
#  [1.525054   3.2467206 ]
#  [1.525054   3.7783525 ]
#  [1.525054   3.3426628 ]]
# M
# q
# [2042.0012]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.0012], dtype=float32)
# mu,alpha,beta=(Array(1.5257473, dtype=float32), Array([0.8946048], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5257473 0.       ]
#  [1.5257473 0.4651369]
#  [1.5257473 0.9266809]
#  ...
#  [1.5257473 3.2459686]
#  [1.5257473 3.7779632]
#  [1.5257473 3.3419542]]
# M
# q
# [2041.8024]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.8024], dtype=float32)
# mu,alpha,beta=(Array(1.5264376, dtype=float32), Array([0.8945299], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5264376  0.        ]
#  [1.5264376  0.46509793]
#  [1.5264376  0.9266033 ]
#  ...
#  [1.5264376  3.2456965 ]
#  [1.5264376  3.7776468 ]
#  [1.5264376  3.3416743 ]]
# M
# q
# [2041.604]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.604], dtype=float32)
# mu,alpha,beta=(Array(1.52708, dtype=float32), Array([0.8937633], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.52708   0.       ]
#  [1.52708   0.4649368]
#  [1.52708   0.9262483]
#  ...
#  [1.52708   3.2459233]
#  [1.52708   3.7774243]
#  [1.52708   3.3418412]]
# M
# q
# [2041.419]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.419], dtype=float32)
# mu,alpha,beta=(Array(1.5276326, dtype=float32), Array([0.8937469], dtype=float32), array([1.0570876]))
#
# E
# Normalise
# [[1.5276326  0.        ]
#  [1.5276326  0.4649134 ]
#  [1.5276326  0.92620397]
#  ...
#  [1.5276326  3.2456753 ]
#  [1.5276326  3.7771668 ]
#  [1.5276326  3.3415904 ]]
# M
# q
# [2041.2601]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.2601], dtype=float32)
# mu,alpha,beta=(Array(1.5281495, dtype=float32), Array([0.89432245], dtype=float32), array([1.05783629]))
#
# E
# Normalise
# [[1.5281495 0.       ]
#  [1.5281495 0.4649975]
#  [1.5281495 0.9264021]
#  ...
#  [1.5281495 3.2450383]
#  [1.5281495 3.7768652]
#  [1.5281495 3.3409946]]
# M
# q
# [2041.112]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.112], dtype=float32)
# mu,alpha,beta=(Array(1.5286713, dtype=float32), Array([0.8942877], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5286713  0.        ]
#  [1.5286713  0.46497202]
#  [1.5286713  0.92635244]
#  ...
#  [1.5286713  3.244818  ]
#  [1.5286713  3.7766242 ]
#  [1.5286713  3.3407698 ]]
# M
# q
# [2040.9625]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.9625], dtype=float32)
# mu,alpha,beta=(Array(1.5291579, dtype=float32), Array([0.8940716], dtype=float32), array([1.05766843]))
#
# E
# Normalise
# [[1.5291579  0.        ]
#  [1.5291579  0.46491528]
#  [1.5291579  0.9262315 ]
#  ...
#  [1.5291579  3.2447386 ]
#  [1.5291579  3.7764182 ]
#  [1.5291579  3.3406723 ]]
# M
# q
# [2040.8225]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.8225], dtype=float32)
# mu,alpha,beta=(Array(1.5295999, dtype=float32), Array([0.8934903], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5295999  0.        ]
#  [1.5295999  0.46479478]
#  [1.5295999  0.9259654 ]
#  ...
#  [1.5295999  3.2449317 ]
#  [1.5295999  3.7762704 ]
#  [1.5295999  3.3408206 ]]
# M
# q
# [2040.6954]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.6954], dtype=float32)
# mu,alpha,beta=(Array(1.5299765, dtype=float32), Array([0.8934494], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5299765  0.        ]
#  [1.5299765  0.46477354]
#  [1.5299765  0.92592305]
#  ...
#  [1.5299765  3.2447832 ]
#  [1.5299765  3.7760983 ]
#  [1.5299765  3.3406677 ]]
# M
# q
# [2040.587]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.587], dtype=float32)
# mu,alpha,beta=(Array(1.530327, dtype=float32), Array([0.89393395], dtype=float32), array([1.05765552]))
#
# E
# Normalise
# [[1.530327   0.        ]
#  [1.530327   0.46484745]
#  [1.530327   0.92609584]
#  ...
#  [1.530327   3.2442863 ]
#  [1.530327   3.775884  ]
#  [1.530327   3.3402057 ]]
# M
# q
# [2040.4872]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.4872], dtype=float32)
# mu,alpha,beta=(Array(1.5306867, dtype=float32), Array([0.8937208], dtype=float32), array([1.05744897]))
#
# E
# Normalise
# [[1.5306867  0.        ]
#  [1.5306867  0.46479595]
#  [1.5306867  0.92598474]
#  ...
#  [1.5306867  3.2442644 ]
#  [1.5306867  3.7757368 ]
#  [1.5306867  3.3401668 ]]
# M
# q
# [2040.3835]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.3835], dtype=float32)
# mu,alpha,beta=(Array(1.5310099, dtype=float32), Array([0.8936857], dtype=float32), array([1.05744897]))
#
# E
# Normalise
# [[1.5310099 0.       ]
#  [1.5310099 0.4647777]
#  [1.5310099 0.9259484]
#  ...
#  [1.5310099 3.2441368]
#  [1.5310099 3.775589 ]
#  [1.5310099 3.3400357]]
# M
# q
# [2040.2911]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.2911], dtype=float32)
# mu,alpha,beta=(Array(1.5313107, dtype=float32), Array([0.893479], dtype=float32), array([1.05724246]))
#
# E
# Normalise
# [[1.5313107  0.        ]
#  [1.5313107  0.46472952]
#  [1.5313107  0.92584395]
#  ...
#  [1.5313107  3.2441387 ]
#  [1.5313107  3.775469  ]
#  [1.5313107  3.3400207 ]]
# M
# q
# [2040.2045]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.2045], dtype=float32)
# mu,alpha,beta=(Array(1.5315793, dtype=float32), Array([0.89397234], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5315793  0.        ]
#  [1.5315793  0.46480805]
#  [1.5315793  0.92602575]
#  ...
#  [1.5315793  3.2436738 ]
#  [1.5315793  3.7752924 ]
#  [1.5315793  3.3395917 ]]
# M
# q
# [2040.1278]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.1278], dtype=float32)
# mu,alpha,beta=(Array(1.5318627, dtype=float32), Array([0.89533633], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5318627  0.        ]
#  [1.5318627  0.46504137]
#  [1.5318627  0.9265586 ]
#  ...
#  [1.5318627  3.2426078 ]
#  [1.5318627  3.7750235 ]
#  [1.5318627  3.338625  ]]
# M
# q
# [2040.0475]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.0475], dtype=float32)
# mu,alpha,beta=(Array(1.5322167, dtype=float32), Array([0.89494896], dtype=float32), array([1.05910253]))
#
# E
# Normalise
# [[1.5322167  0.        ]
#  [1.5322167  0.4649591 ]
#  [1.5322167  0.92637765]
#  ...
#  [1.5322167  3.2427068 ]
#  [1.5322167  3.7748957 ]
#  [1.5322167  3.338694  ]]
# M
# q
# [2039.9458]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.9458], dtype=float32)
# mu,alpha,beta=(Array(1.5325233, dtype=float32), Array([0.8942183], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5325233  0.        ]
#  [1.5325233  0.46481714]
#  [1.5325233  0.9260609 ]
#  ...
#  [1.5325233  3.2430634 ]
#  [1.5325233  3.7748246 ]
#  [1.5325233  3.3389957 ]]
# M
# q
# [2039.8574]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.8574], dtype=float32)
# mu,alpha,beta=(Array(1.5327634, dtype=float32), Array([0.89454085], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5327634  0.        ]
#  [1.5327634  0.46486595]
#  [1.5327634  0.9261751 ]
#  ...
#  [1.5327634  3.24273   ]
#  [1.5327634  3.77468   ]
#  [1.5327634  3.3386853 ]]
# M
# q
# [2039.7891]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.7891], dtype=float32)
# mu,alpha,beta=(Array(1.5330092, dtype=float32), Array([0.8938608], dtype=float32), array([1.05791377]))
#
# E
# Normalise
# [[1.5330092 0.       ]
#  [1.5330092 0.4647352]
#  [1.5330092 0.9258828]
#  ...
#  [1.5330092 3.2430813]
#  [1.5330092 3.7746334]
#  [1.5330092 3.3389857]]
# M
# 2024-04-09 13:01:25.133087: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:133] The operation took 2m17.544653s
#
# ********************************
# [Compiling module jit_sum_expected_event_ll] Very slow compile?  If you want to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ********************************
# q
# [2039.7183]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.7183], dtype=float32)
# mu,alpha,beta=(Array(1.5331953, dtype=float32), Array([0.89390594], dtype=float32), array([1.05799126]))
#
# E
# Normalise
# [[1.5331953 0.       ]
#  [1.5331953 0.4647364]
#  [1.5331953 0.9258883]
#  ...
#  [1.5331953 3.242963 ]
#  [1.5331953 3.7745411]
#  [1.5331953 3.3388703]]
# M
# q
# [2039.6646]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.6646], dtype=float32)
# mu,alpha,beta=(Array(1.5333728, dtype=float32), Array([0.89377785], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5333728  0.        ]
#  [1.5333728  0.46470693]
#  [1.5333728  0.9258243 ]
#  ...
#  [1.5333728  3.2429678 ]
#  [1.5333728  3.7744713 ]
#  [1.5333728  3.338865  ]]
# M
# q
# [2039.614]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.614], dtype=float32)
# mu,alpha,beta=(Array(1.5335306, dtype=float32), Array([0.8934125], dtype=float32), array([1.05744897]))
#
# E
# Normalise
# [[1.5335306  0.        ]
#  [1.5335306  0.4646356 ]
#  [1.5335306  0.92566526]
#  ...
#  [1.5335306  3.243145  ]
#  [1.5335306  3.7744343 ]
#  [1.5335306  3.3390145 ]]
# M
# q
# [2039.5686]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.5686], dtype=float32)
# mu,alpha,beta=(Array(1.5336549, dtype=float32), Array([0.8930508], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5336549  0.        ]
#  [1.5336549  0.46456614]
#  [1.5336549  0.9255099 ]
#  ...
#  [1.5336549  3.2433355 ]
#  [1.5336549  3.7744129 ]
#  [1.5336549  3.3391774 ]]
# M
# q
# [2039.5325]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.5325], dtype=float32)
# mu,alpha,beta=(Array(1.5337481, dtype=float32), Array([0.89234483], dtype=float32), array([1.0562105]))
#
# E
# Normalise
# [[1.5337481  0.        ]
#  [1.5337481  0.46443588]
#  [1.5337481  0.9252167 ]
#  ...
#  [1.5337481  3.2437782 ]
#  [1.5337481  3.774443  ]
#  [1.5337481  3.3395667 ]]
# M
# q
# [2039.5051]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.5051], dtype=float32)
# mu,alpha,beta=(Array(1.5337898, dtype=float32), Array([0.89234024], dtype=float32), array([1.0562105]))
#
# E
# Normalise
# [[1.5337898  0.        ]
#  [1.5337898  0.46443346]
#  [1.5337898  0.9252119 ]
#  ...
#  [1.5337898  3.243761  ]
#  [1.5337898  3.7744234 ]
#  [1.5337898  3.3395493 ]]
# M
# q
# [2039.4932]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4932], dtype=float32)
# mu,alpha,beta=(Array(1.5338285, dtype=float32), Array([0.8930321], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5338285  0.        ]
#  [1.5338285  0.46455643]
#  [1.5338285  0.92549056]
#  ...
#  [1.5338285  3.2432673 ]
#  [1.5338285  3.774334  ]
#  [1.5338285  3.3391073 ]]
# M
# q
# [2039.4827]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4827], dtype=float32)
# mu,alpha,beta=(Array(1.5339093, dtype=float32), Array([0.8937197], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5339093  0.        ]
#  [1.5339093  0.46467668]
#  [1.5339093  0.925764  ]
#  ...
#  [1.5339093  3.2427573 ]
#  [1.5339093  3.7742252 ]
#  [1.5339093  3.338648  ]]
# M
# q
# [2039.4602]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4602], dtype=float32)
# mu,alpha,beta=(Array(1.5340295, dtype=float32), Array([0.8928362], dtype=float32), array([1.05682955]))
#
# E
# Normalise
# [[1.5340295  0.        ]
#  [1.5340295  0.46451375]
#  [1.5340295  0.9253972 ]
#  ...
#  [1.5340295  3.2433076 ]
#  [1.5340295  3.7742593 ]
#  [1.5340295  3.339132  ]]
# M
# q
# [2039.4249]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4249], dtype=float32)
# mu,alpha,beta=(Array(1.534085, dtype=float32), Array([0.8938747], dtype=float32), array([1.05806875]))
#
# E
# Normalise
# [[1.534085   0.        ]
#  [1.534085   0.46469787]
#  [1.534085   0.9258148 ]
#  ...
#  [1.534085   3.2425683 ]
#  [1.534085   3.7741268 ]
#  [1.534085   3.3384697 ]]
# M
# q
# [2039.4102]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4102], dtype=float32)
# mu,alpha,beta=(Array(1.5342044, dtype=float32), Array([0.89290434], dtype=float32), array([1.05693276]))
#
# E
# Normalise
# [[1.5342044  0.        ]
#  [1.5342044  0.46451956]
#  [1.5342044  0.925413  ]
#  ...
#  [1.5342044  3.243179  ]
#  [1.5342044  3.7741709 ]
#  [1.5342044  3.3390083 ]]
# M
# q
# [2039.375]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.375], dtype=float32)
# mu,alpha,beta=(Array(1.5342532, dtype=float32), Array([0.89507526], dtype=float32), array([1.0595147]))
#
# E
# Normalise
# [[1.5342532 0.       ]
#  [1.5342532 0.4649062]
#  [1.5342532 0.9262893]
#  ...
#  [1.5342532 3.2416682]
#  [1.5342532 3.7739289]
#  [1.5342532 3.337657 ]]
# M
# q
# [2039.3627]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3627], dtype=float32)
# mu,alpha,beta=(Array(1.5344397, dtype=float32), Array([0.8938471], dtype=float32), array([1.05808167]))
#
# E
# Normalise
# [[1.5344397  0.        ]
#  [1.5344397  0.46467987]
#  [1.5344397  0.92577934]
#  ...
#  [1.5344397  3.2424212 ]
#  [1.5344397  3.7739632 ]
#  [1.5344397  3.338319  ]]
# M
# q
# [2039.3083]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3083], dtype=float32)
# mu,alpha,beta=(Array(1.5345349, dtype=float32), Array([0.8929989], dtype=float32), array([1.0570876]))
#
# E
# Normalise
# [[1.5345349 0.       ]
#  [1.5345349 0.4645243]
#  [1.5345349 0.9254287]
#  ...
#  [1.5345349 3.242959 ]
#  [1.5345349 3.7740054]
#  [1.5345349 3.3387935]]
# M
# q
# [2039.2805]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2805], dtype=float32)
# mu,alpha,beta=(Array(1.5345694, dtype=float32), Array([0.8943449], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5345694  0.        ]
#  [1.5345694  0.46476412]
#  [1.5345694  0.9259722 ]
#  ...
#  [1.5345694  3.24202   ]
#  [1.5345694  3.773853  ]
#  [1.5345694  3.337954  ]]
# M
# q
# [2039.2717]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2717], dtype=float32)
# mu,alpha,beta=(Array(1.5346887, dtype=float32), Array([0.89346105], dtype=float32), array([1.05765552]))
#
# E
# Normalise
# [[1.5346887  0.        ]
#  [1.5346887  0.46460155]
#  [1.5346887  0.9256059 ]
#  ...
#  [1.5346887  3.24257   ]
#  [1.5346887  3.7738864 ]
#  [1.5346887  3.338439  ]]
# M
# q
# [2039.2368]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2368], dtype=float32)
# mu,alpha,beta=(Array(1.534743, dtype=float32), Array([0.89362925], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.534743   0.        ]
#  [1.534743   0.46462968]
#  [1.534743   0.9256704 ]
#  ...
#  [1.534743   3.242429  ]
#  [1.534743   3.7738435 ]
#  [1.534743   3.33831   ]]
# M
# q
# [2039.2214]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2214], dtype=float32)
# mu,alpha,beta=(Array(1.5348049, dtype=float32), Array([0.8936226], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5348049 0.       ]
#  [1.5348049 0.4646262]
#  [1.5348049 0.9256635]
#  ...
#  [1.5348049 3.2424047]
#  [1.5348049 3.7738152]
#  [1.5348049 3.338285 ]]
# M
# q
# [2039.2035]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2035], dtype=float32)
# mu,alpha,beta=(Array(1.5348623, dtype=float32), Array([0.89440024], dtype=float32), array([1.05879229]))
#
# E
# Normalise
# [[1.5348623 0.       ]
#  [1.5348623 0.4647632]
#  [1.5348623 0.9259745]
#  ...
#  [1.5348623 3.2418447]
#  [1.5348623 3.77371  ]
#  [1.5348623 3.337782 ]]
# M
# q
# [2039.1877]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1877], dtype=float32)
# mu,alpha,beta=(Array(1.5349666, dtype=float32), Array([0.89377904], dtype=float32), array([1.05806875]))
#
# E
# Normalise
# [[1.5349666  0.        ]
#  [1.5349666  0.46464816]
#  [1.5349666  0.9257157 ]
#  ...
#  [1.5349666  3.2422214 ]
#  [1.5349666  3.773723  ]
#  [1.5349666  3.338112  ]]
# M
# q
# [2039.1573]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1573], dtype=float32)
# mu,alpha,beta=(Array(1.5350243, dtype=float32), Array([0.8939471], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5350243  0.        ]
#  [1.5350243  0.46467617]
#  [1.5350243  0.92578006]
#  ...
#  [1.5350243  3.24208   ]
#  [1.5350243  3.7736802 ]
#  [1.5350243  3.3379831 ]]
# M
# q
# [2039.1411]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1411], dtype=float32)
# mu,alpha,beta=(Array(1.5350889, dtype=float32), Array([0.89376587], dtype=float32), array([1.05806875]))
#
# E
# Normalise
# [[1.5350889  0.        ]
#  [1.5350889  0.4646413 ]
#  [1.5350889  0.92570204]
#  ...
#  [1.5350889  3.2421734 ]
#  [1.5350889  3.7736673 ]
#  [1.5350889  3.338063  ]]
# M
# q
# [2039.1226]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1226], dtype=float32)
# mu,alpha,beta=(Array(1.5351379, dtype=float32), Array([0.8946755], dtype=float32), array([1.05915424]))
#
# E
# Normalise
# [[1.5351379  0.        ]
#  [1.5351379  0.46480218]
#  [1.5351379  0.9260671 ]
#  ...
#  [1.5351379  3.2415283 ]
# ...
# loglikelihood=Array([2038.8583], dtype=float32)
# mu,alpha,beta=(Array(1.5359848, dtype=float32), Array([0.89340746], dtype=float32), array([1.05775881]))
#
# E
# Normalise
# [[1.5359848  0.        ]
#  [1.5359848  0.46454403]
#  [1.5359848  0.9254955 ]
#  ...
#  [1.5359848  3.242     ]
#  [1.5359848  3.7732832 ]
#  [1.5359848  3.3378599 ]]
# M
# q
# [2038.8656]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8656], dtype=float32)
# mu,alpha,beta=(Array(1.535954, dtype=float32), Array([0.89489186], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.535954   0.        ]
#  [1.535954   0.46481052]
#  [1.535954   0.92609864]
#  ...
#  [1.535954   3.2409983 ]
#  [1.535954   3.7731497 ]
#  [1.535954   3.3369675 ]]
# M
# q
# [2038.8756]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8756], dtype=float32)
# mu,alpha,beta=(Array(1.5360212, dtype=float32), Array([0.8962808], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5360212  0.        ]
#  [1.5360212  0.46505532]
#  [1.5360212  0.9266548 ]
#  ...
#  [1.5360212  3.240022  ]
#  [1.5360212  3.7729847 ]
#  [1.5360212  3.3360908 ]]
# M
# q
# [2038.8575]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8575], dtype=float32)
# mu,alpha,beta=(Array(1.5361743, dtype=float32), Array([0.893561], dtype=float32), array([1.05796543]))
#
# E
# Normalise
# [[1.5361743  0.        ]
#  [1.5361743  0.46456453]
#  [1.5361743  0.92554486]
#  ...
#  [1.5361743  3.241806  ]
#  [1.5361743  3.773179  ]
#  [1.5361743  3.3376765 ]]
# M
# q
# [2038.8115]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8115], dtype=float32)
# mu,alpha,beta=(Array(1.5361415, dtype=float32), Array([0.8934776], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5361415  0.        ]
#  [1.5361415  0.46455082]
#  [1.5361415  0.9255133 ]
#  ...
#  [1.5361415  3.2418787 ]
#  [1.5361415  3.7732031 ]
#  [1.5361415  3.3377438 ]]
# M
# q
# [2038.8212]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8212], dtype=float32)
# mu,alpha,beta=(Array(1.5361052, dtype=float32), Array([0.8941783], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5361052 0.       ]
#  [1.5361052 0.4646775]
#  [1.5361052 0.9257996]
#  ...
#  [1.5361052 3.2414157]
#  [1.5361052 3.77315  ]
#  [1.5361052 3.3373318]]
# M
# q
# [2038.8322]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8322], dtype=float32)
# mu,alpha,beta=(Array(1.5361166, dtype=float32), Array([0.8935673], dtype=float32), array([1.05796543]))
#
# E
# Normalise
# [[1.5361166 0.       ]
#  [1.5361166 0.4645678]
#  [1.5361166 0.9255514]
#  ...
#  [1.5361166 3.2418287]
#  [1.5361166 3.7732055]
#  [1.5361166 3.3377001]]
# M
# q
# [2038.8282]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8282], dtype=float32)
# mu,alpha,beta=(Array(1.5360878, dtype=float32), Array([0.8934834], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5360878  0.        ]
#  [1.5360878  0.46455383]
#  [1.5360878  0.92551935]
#  ...
#  [1.5360878  3.2419    ]
#  [1.5360878  3.7732277 ]
#  [1.5360878  3.337765  ]]
# M
# q
# [2038.8362]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8362], dtype=float32)
# mu,alpha,beta=(Array(1.5360552, dtype=float32), Array([0.8962772], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5360552  0.        ]
#  [1.5360552  0.46505344]
#  [1.5360552  0.926651  ]
#  ...
#  [1.5360552  3.240009  ]
#  [1.5360552  3.7729695 ]
#  [1.5360552  3.3360772 ]]
# M
# q
# [2038.8477]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8477], dtype=float32)
# mu,alpha,beta=(Array(1.5362058, dtype=float32), Array([0.8962608], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5362058  0.        ]
#  [1.5362058  0.46504492]
#  [1.5362058  0.9266341 ]
#  ...
#  [1.5362058  3.23995   ]
#  [1.5362058  3.7729003 ]
#  [1.5362058  3.336016  ]]
# M
# q
# [2038.8048]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8048], dtype=float32)
# mu,alpha,beta=(Array(1.5363458, dtype=float32), Array([0.8934555], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5363458  0.        ]
#  [1.5363458  0.46453932]
#  [1.5363458  0.9254904 ]
#  ...
#  [1.5363458  3.2417984 ]
#  [1.5363458  3.7731097 ]
#  [1.5363458  3.3376608 ]]
# M
# q
# [2038.7625]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7625], dtype=float32)
# mu,alpha,beta=(Array(1.5362952, dtype=float32), Array([0.8941576], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5362952  0.        ]
#  [1.5362952  0.46466678]
#  [1.5362952  0.92577827]
#  ...
#  [1.5362952  3.2413406 ]
#  [1.5362952  3.7730627 ]
#  [1.5362952  3.337255  ]]
# M
# q
# [2038.7778]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7778], dtype=float32)
# mu,alpha,beta=(Array(1.5362933, dtype=float32), Array([0.8941578], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5362933 0.       ]
#  [1.5362933 0.4646669]
#  [1.5362933 0.9257785]
#  ...
#  [1.5362933 3.2413418]
#  [1.5362933 3.7730634]
#  [1.5362933 3.337256 ]]
# M
# q
# [2038.7784]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7784], dtype=float32)
# mu,alpha,beta=(Array(1.5362915, dtype=float32), Array([0.8952042], dtype=float32), array([1.05993027]))
#
# E
# Normalise
# [[1.5362915  0.        ]
#  [1.5362915  0.46485373]
#  [1.5362915  0.9262018 ]
#  ...
#  [1.5362915  3.240628  ]
#  [1.5362915  3.7729614 ]
#  [1.5362915  3.3366184 ]]
# M
# q
# [2038.7797]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7797], dtype=float32)
# mu,alpha,beta=(Array(1.5363574, dtype=float32), Array([0.89476097], dtype=float32), array([1.05941285]))
#
# E
# Normalise
# [[1.5363574  0.        ]
#  [1.5363574  0.46477222]
#  [1.5363574  0.9260181 ]
#  ...
#  [1.5363574  3.2408998 ]
#  [1.5363574  3.7729738 ]
#  [1.5363574  3.3368578 ]]
# M
# q
# [2038.7601]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7601], dtype=float32)
# mu,alpha,beta=(Array(1.5363907, dtype=float32), Array([0.89624065], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5363907  0.        ]
#  [1.5363907  0.46503446]
#  [1.5363907  0.9266132 ]
#  ...
#  [1.5363907  3.239877  ]
#  [1.5363907  3.7728155 ]
#  [1.5363907  3.335941  ]]
# M
# q
# [2038.7517]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7517], dtype=float32)
# mu,alpha,beta=(Array(1.5365176, dtype=float32), Array([0.8962269], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5365176  0.        ]
#  [1.5365176  0.46502733]
#  [1.5365176  0.926599  ]
#  ...
#  [1.5365176  3.2398274 ]
#  [1.5365176  3.7727575 ]
#  [1.5365176  3.3358898 ]]
# M
# q
# [2038.7156]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7156], dtype=float32)
# mu,alpha,beta=(Array(1.5366355, dtype=float32), Array([0.8955157], dtype=float32), array([1.06034439]))
#
# E
# Normalise
# [[1.5366355  0.        ]
#  [1.5366355  0.46489647]
#  [1.5366355  0.926304  ]
#  ...
#  [1.5366355  3.240255  ]
#  [1.5366355  3.77277   ]
#  [1.5366355  3.3362663 ]]
# M
# q
# [2038.6814]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.6814], dtype=float32)
# mu,alpha,beta=(Array(1.5367001, dtype=float32), Array([0.89341694], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5367001  0.        ]
#  [1.5367001  0.4645193 ]
#  [1.5367001  0.92545044]
#  ...
#  [1.5367001  3.2416584 ]
#  [1.5367001  3.7729468 ]
#  [1.5367001  3.3375168 ]]
# M
# q
# [2038.6613]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.6613], dtype=float32)
# mu,alpha,beta=(Array(1.5366247, dtype=float32), Array([0.892729], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5366247  0.        ]
#  [1.5366247  0.46439874]
#  [1.5366247  0.9251765 ]
#  ...
#  [1.5366247  3.2421668 ]
#  [1.5366247  3.773053  ]
#  [1.5366247  3.3379738 ]]
# M
# q
# [2038.6824]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.6824], dtype=float32)
# mu,alpha,beta=(Array(1.5365095, dtype=float32), Array([0.8935682], dtype=float32), array([1.05801709]))
#
# E
# Normalise
# [[1.5365095  0.        ]
#  [1.5365095  0.46455342]
#  [1.5365095  0.92552483]
#  ...
#  [1.5365095  3.2416441 ]
#  [1.5365095  3.7730212 ]
#  [1.5365095  3.3375142 ]]
# M
# q
# [2038.7161]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7161], dtype=float32)
# mu,alpha,beta=(Array(1.536456, dtype=float32), Array([0.89414006], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.536456   0.        ]
#  [1.536456   0.46465766]
#  [1.536456   0.92576015]
#  ...
#  [1.536456   3.2412775 ]
#  [1.536456   3.7729888 ]
#  [1.536456   3.3371894 ]]
# M
# q
# [2038.7316]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7316], dtype=float32)
# mu,alpha,beta=(Array(1.536443, dtype=float32), Array([0.8934449], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.536443  0.       ]
#  [1.536443  0.4645338]
#  [1.536443  0.9254794]
#  ...
#  [1.536443  3.24176  ]
#  [1.536443  3.7730649]
#  [1.536443  3.3376215]]
# M
# q
# [2038.7346]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7346], dtype=float32)
# mu,alpha,beta=(Array(1.5363854, dtype=float32), Array([0.89484507], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5363854  0.        ]
#  [1.5363854  0.4647862 ]
#  [1.5363854  0.92605025]
#  ...
#  [1.5363854  3.240829  ]
#  [1.5363854  3.772952  ]
#  [1.5363854  3.336793  ]]
# M
# q
# [2038.7527]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7527], dtype=float32)
# mu,alpha,beta=(Array(1.5364223, dtype=float32), Array([0.89362127], dtype=float32), array([1.05806875]))
#
# E
# Normalise
# [[1.5364223  0.        ]
#  [1.5364223  0.46456614]
#  [1.5364223  0.92555225]
#  ...
#  [1.5364223  3.2416487 ]
#  [1.5364223  3.7730572 ]
#  [1.5364223  3.3375232 ]]
# M
# q
# [2038.7411]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7411], dtype=float32)
# mu,alpha,beta=(Array(1.5363775, dtype=float32), Array([0.8943338], dtype=float32), array([1.05890862]))
#
# E
# Normalise
# [[1.5363775  0.        ]
#  [1.5363775  0.46469522]
#  [1.5363775  0.92584395]
#  ...
#  [1.5363775  3.2411816 ]
#  [1.5363775  3.7730062 ]
#  [1.5363775  3.3371081 ]]
# M
# q
# [2038.7543]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7543], dtype=float32)
# mu,alpha,beta=(Array(1.5363818, dtype=float32), Array([0.8934515], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5363818  0.        ]
#  [1.5363818  0.46453726]
#  [1.5363818  0.92548627]
#  ...
#  [1.5363818  3.241784  ]
#  [1.5363818  3.773093  ]
#  [1.5363818  3.337646  ]]
# M
# q
# [2038.7523]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7523], dtype=float32)
# mu,alpha,beta=(Array(1.5363287, dtype=float32), Array([0.89362055], dtype=float32), array([1.05805583]))
#
# E
# Normalise
# [[1.5363287  0.        ]
#  [1.5363287  0.46456948]
#  [1.5363287  0.92555845]
#  ...
#  [1.5363287  3.241693  ]
#  [1.5363287  3.773101  ]
#  [1.5363287  3.3375673 ]]
# M
# q
# [2038.7676]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7676], dtype=float32)
# mu,alpha,beta=(Array(1.5362899, dtype=float32), Array([0.8934615], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5362899  0.        ]
#  [1.5362899  0.46454245]
#  [1.5362899  0.9254967 ]
#  ...
#  [1.5362899  3.2418203 ]
#  [1.5362899  3.7731352 ]
#  [1.5362899  3.3376834 ]]
# M
# q
# [2038.7787]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7787], dtype=float32)
# mu,alpha,beta=(Array(1.5362432, dtype=float32), Array([0.8941196], dtype=float32), array([1.0586372]))
#
# E
# Normalise
# [[1.5362432  0.        ]
#  [1.5362432  0.46466187]
#  [1.5362432  0.92576635]
#  ...
#  [1.5362432  3.2413905 ]
#  [1.5362432  3.7730904 ]
#  [1.5362432  3.3373024 ]]
# M
# q
# [2038.7925]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7925], dtype=float32)
# mu,alpha,beta=(Array(1.5362421, dtype=float32), Array([0.8934667], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5362421  0.        ]
#  [1.5362421  0.46454516]
#  [1.5362421  0.925502  ]
#  ...
#  [1.5362421  3.2418392 ]
#  [1.5362421  3.7731571 ]
#  [1.5362421  3.3377028 ]]
# M
# q
# [2038.7924]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7924], dtype=float32)
# mu,alpha,beta=(Array(1.5361987, dtype=float32), Array([0.8935584], dtype=float32), array([1.05796543]))
#
# E
# Normalise
# [[1.5361987  0.        ]
#  [1.5361987  0.46456316]
#  [1.5361987  0.9255421 ]
#  ...
#  [1.5361987  3.2417963 ]
#  [1.5361987  3.7731678 ]
#  [1.5361987  3.3376665 ]]
# M
# q
# [2038.8049]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8049], dtype=float32)
# mu,alpha,beta=(Array(1.5361642, dtype=float32), Array([0.89362735], dtype=float32), array([1.05804292]))
#
# E
# Normalise
# [[1.5361642  0.        ]
#  [1.5361642  0.46457675]
#  [1.5361642  0.9255723 ]
#  ...
#  [1.5361642  3.2417648 ]
#  [1.5361642  3.7731771 ]
#  [1.5361642  3.3376403 ]]
# M
# q
# [2038.8146]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8146], dtype=float32)
# mu,alpha,beta=(Array(1.5361364, dtype=float32), Array([0.89487207], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5361364  0.        ]
#  [1.5361364  0.46480024]
#  [1.5361364  0.9260782 ]
#  ...
#  [1.5361364  3.2409265 ]
#  [1.5361364  3.7730663 ]
#  [1.5361364  3.3368936 ]]
# M
# q
# [2038.8235]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8235], dtype=float32)
# mu,alpha,beta=(Array(1.5361909, dtype=float32), Array([0.8948662], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5361909 0.       ]
#  [1.5361909 0.4647972]
#  [1.5361909 0.9260721]
#  ...
#  [1.5361909 3.2409053]
#  [1.5361909 3.773042 ]
#  [1.5361909 3.3368719]]
# M
# q
# [2038.8079]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.8079], dtype=float32)
# mu,alpha,beta=(Array(1.5362414, dtype=float32), Array([0.8962569], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5362414  0.        ]
#  [1.5362414  0.46504292]
#  [1.5362414  0.9266301 ]
#  ...
#  [1.5362414  3.2399359 ]
#  [1.5362414  3.772884  ]
#  [1.5362414  3.3360014 ]]
# M
# q
# [2038.7944]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7944], dtype=float32)
# mu,alpha,beta=(Array(1.5363787, dtype=float32), Array([0.893626], dtype=float32), array([1.05806875]))
#
# E
# Normalise
# [[1.5363787  0.        ]
#  [1.5363787  0.4645686 ]
#  [1.5363787  0.92555714]
#  ...
#  [1.5363787  3.2416656 ]
#  [1.5363787  3.7730768 ]
#  [1.5363787  3.3375406 ]]
# M
# q
# [2038.7533]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7533], dtype=float32)
# mu,alpha,beta=(Array(1.5363371, dtype=float32), Array([0.89441454], dtype=float32), array([1.0589991]))
#
# E
# Normalise
# [[1.5363371  0.        ]
#  [1.5363371  0.46471116]
#  [1.5363371  0.9258795 ]
#  ...
#  [1.5363371  3.2411458 ]
#  [1.5363371  3.7730174 ]
#  [1.5363371  3.3370786 ]]
# M
# q
# [2038.7662]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7662], dtype=float32)
# mu,alpha,beta=(Array(1.5363492, dtype=float32), Array([0.8937598], dtype=float32), array([1.05822375]))
#
# E
# Normalise
# [[1.5363492  0.        ]
#  [1.5363492  0.46459365]
#  [1.5363492  0.9256134 ]
#  ...
#  [1.5363492  3.2415879 ]
#  [1.5363492  3.773077  ]
#  [1.5363492  3.3374727 ]]
# M
# q
# [2038.7618]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7618], dtype=float32)
# mu,alpha,beta=(Array(1.5363182, dtype=float32), Array([0.89489603], dtype=float32), array([1.05956805]))
#
# E
# Normalise
# [[1.5363182  0.        ]
#  [1.5363182  0.4647978 ]
#  [1.5363182  0.92607546]
#  ...
#  [1.5363182  3.2408257 ]
#  [1.5363182  3.772979  ]
#  [1.5363182  3.336794  ]]
# M
# q
# [2038.7716]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7716], dtype=float32)
# mu,alpha,beta=(Array(1.5363625, dtype=float32), Array([0.89310545], dtype=float32), array([1.05744897]))
#
# E
# Normalise
# [[1.5363625  0.        ]
#  [1.5363625  0.46447593]
#  [1.5363625  0.9253472 ]
#  ...
#  [1.5363625  3.2420306 ]
#  [1.5363625  3.7731376 ]
#  [1.5363625  3.3378673 ]]
# M
# q
# [2038.7574]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7574], dtype=float32)
# mu,alpha,beta=(Array(1.5362881, dtype=float32), Array([0.8948556], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5362881  0.        ]
#  [1.5362881  0.4647917 ]
#  [1.5362881  0.92606115]
#  ...
#  [1.5362881  3.2408671 ]
#  [1.5362881  3.7729967 ]
#  [1.5362881  3.3368323 ]]
# M
# q
# [2038.7803]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.7803], dtype=float32)
# mu,alpha,beta=(Array(1.5363319, dtype=float32), Array([0.8948509], dtype=float32), array([1.05951632]))
# (Array(0.49615413, dtype=float32),
#  Array([0.82171345], dtype=float32),
#  array([0.8634019]))

# %%
em(events,T,theta_guess=[1,1,1.2])
# Out:
# E
# Normalise
# [[1.         0.        ]
#  [1.         0.47619364]
#  [1.         0.95552516]
#  ...
#  [1.         3.135165  ]
#  [1.         3.7268515 ]
#  [1.         3.231912  ]]
# M
# q
# [2187.4404]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2187.4404], dtype=float32)
# mu,alpha,beta=(Array(1.103592, dtype=float32), Array([0.91151834], dtype=float32), array([1.02531512]))
#
# E
# Normalise
# [[1.103592   0.        ]
#  [1.103592   0.48356432]
#  [1.103592   0.962049  ]
#  ...
#  [1.103592   3.432985  ]
#  [1.103592   3.9752278 ]
#  [1.103592   3.5313673 ]]
# M
# q
# [2176.6562]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2176.6562], dtype=float32)
# mu,alpha,beta=(Array(1.1263114, dtype=float32), Array([0.8867358], dtype=float32), array([1.]))
#
# E
# Normalise
# [[1.1263114 0.       ]
#  [1.1263114 0.4778379]
#  [1.1263114 0.9496843]
#  ...
#  [1.1263114 3.4418106]
#  [1.1263114 3.9693232]
#  [1.1263114 3.5374494]]
# M
# q
# [2168.7314]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2168.7314], dtype=float32)
# mu,alpha,beta=(Array(1.1468005, dtype=float32), Array([0.8846351], dtype=float32), array([1.]))
#
# E
# Normalise
# [[1.1468005  0.        ]
#  [1.1468005  0.47670588]
#  [1.1468005  0.94743454]
#  ...
#  [1.1468005  3.433657  ]
#  [1.1468005  3.9599197 ]
#  [1.1468005  3.529069  ]]
# M
# q
# [2161.5762]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2161.5762], dtype=float32)
# mu,alpha,beta=(Array(1.1663789, dtype=float32), Array([0.88331586], dtype=float32), array([1.00078156]))
#
# E
# Normalise
# [[1.1663789 0.       ]
#  [1.1663789 0.475765 ]
#  [1.1663789 0.9455937]
#  ...
#  [1.1663789 3.4252958]
#  [1.1663789 3.9507751]
#  [1.1663789 3.5205748]]
# M
# q
# [2154.8079]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2154.8079], dtype=float32)
# mu,alpha,beta=(Array(1.1850973, dtype=float32), Array([0.8848367], dtype=float32), array([1.0046985]))
#
# E
# Normalise
# [[1.1850973  0.        ]
#  [1.1850973  0.47543132]
#  [1.1850973  0.94507694]
#  ...
#  [1.1850973  3.4150212 ]
#  [1.1850973  3.9414105 ]
#  [1.1850973  3.5105033 ]]
# M
# q
# [2148.393]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2148.393], dtype=float32)
# mu,alpha,beta=(Array(1.2031279, dtype=float32), Array([0.88366795], dtype=float32), array([1.00548373]))
#
# E
# Normalise
# [[1.2031279  0.        ]
#  [1.2031279  0.47457293]
#  [1.2031279  0.9434    ]
#  ...
#  [1.2031279  3.4072921 ]
#  [1.2031279  3.9329865 ]
#  [1.2031279  3.5026543 ]]
# M
# q
# [2142.2817]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2142.2817], dtype=float32)
# mu,alpha,beta=(Array(1.220322, dtype=float32), Array([0.8853388], dtype=float32), array([1.00941908]))
#
# E
# Normalise
# [[1.220322   0.        ]
#  [1.220322   0.47431478]
#  [1.220322   0.9430351 ]
#  ...
#  [1.220322   3.397671  ]
#  [1.220322   3.9243617 ]
#  [1.220322   3.4932392 ]]
# M
# q
# [2136.4995]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2136.4995], dtype=float32)
# mu,alpha,beta=(Array(1.2368603, dtype=float32), Array([0.88362724], dtype=float32), array([1.00941908]))
#
# E
# Normalise
# [[1.2368603  0.        ]
#  [1.2368603  0.47339785]
#  [1.2368603  0.941212  ]
#  ...
#  [1.2368603  3.3911028 ]
#  [1.2368603  3.9167752 ]
#  [1.2368603  3.4864862 ]]
# M
# q
# [2130.9956]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2130.9956], dtype=float32)
# mu,alpha,beta=(Array(1.2525555, dtype=float32), Array([0.88510174], dtype=float32), array([1.01297407]))
#
# E
# Normalise
# [[1.2525555  0.        ]
#  [1.2525555  0.47314665]
#  [1.2525555  0.9408474 ]
#  ...
#  [1.2525555  3.3823912 ]
#  [1.2525555  3.9089403 ]
#  [1.2525555  3.477947  ]]
# M
# q
# [2125.8071]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2125.8071], dtype=float32)
# mu,alpha,beta=(Array(1.2676159, dtype=float32), Array([0.88319343], dtype=float32), array([1.01257845]))
#
# E
# Normalise
# [[1.2676159  0.        ]
#  [1.2676159  0.47224203]
#  [1.2676159  0.9390335 ]
#  ...
#  [1.2676159  3.376688  ]
#  [1.2676159  3.902102  ]
#  [1.2676159  3.4720373 ]]
# M
# q
# [2120.8762]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2120.8762], dtype=float32)
# mu,alpha,beta=(Array(1.2818557, dtype=float32), Array([0.8868843], dtype=float32), array([1.01852894]))
#
# E
# Normalise
# [[1.2818557  0.        ]
#  [1.2818557  0.47247407]
#  [1.2818557  0.93972224]
#  ...
#  [1.2818557  3.366962  ]
#  [1.2818557  3.894565  ]
#  [1.2818557  3.4627123 ]]
# M
# q
# [2116.2363]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2116.2363], dtype=float32)
# mu,alpha,beta=(Array(1.2956336, dtype=float32), Array([0.8857907], dtype=float32), array([1.01892689]))
#
# E
# Normalise
# [[1.2956336  0.        ]
#  [1.2956336  0.47177544]
#  [1.2956336  0.93834794]
#  ...
#  [1.2956336  3.3612306 ]
#  [1.2956336  3.8881829 ]
#  [1.2956336  3.4568624 ]]
# M
# q
# [2111.7896]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2111.7896], dtype=float32)
# mu,alpha,beta=(Array(1.308674, dtype=float32), Array([0.8871902], dtype=float32), array([1.02211601]))
#
# E
# Normalise
# [[1.308674   0.        ]
#  [1.308674   0.47159   ]
#  [1.308674   0.93810207]
#  ...
#  [1.308674   3.35392   ]
#  [1.308674   3.8816984 ]
#  [1.308674   3.4496932 ]]
# M
# q
# [2107.6045]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2107.6045], dtype=float32)
# mu,alpha,beta=(Array(1.3211517, dtype=float32), Array([0.8879566], dtype=float32), array([1.02451441]))
#
# E
# Normalise
# [[1.3211517  0.        ]
#  [1.3211517  0.47129804]
#  [1.3211517  0.9376141 ]
#  ...
#  [1.3211517  3.3473833 ]
#  [1.3211517  3.8756118 ]
#  [1.3211517  3.4432275 ]]
# M
# q
# [2103.6267]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2103.6267], dtype=float32)
# mu,alpha,beta=(Array(1.3330472, dtype=float32), Array([0.88739854], dtype=float32), array([1.02531512]))
#
# E
# Normalise
# [[1.3330472 0.       ]
#  [1.3330472 0.4707687]
#  [1.3330472 0.9365922]
#  ...
#  [1.3330472 3.3421445]
#  [1.3330472 3.870039 ]
#  [1.3330472 3.4379232]]
# M
# q
# [2099.8599]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2099.8599], dtype=float32)
# mu,alpha,beta=(Array(1.3443004, dtype=float32), Array([0.88759804], dtype=float32), array([1.02691843]))
#
# E
# Normalise
# [[1.3443004 0.       ]
#  [1.3443004 0.470408 ]
#  [1.3443004 0.9359369]
#  ...
#  [1.3443004 3.336636 ]
#  [1.3443004 3.8646443]
#  [1.3443004 3.4324248]]
# M
# q
# [2096.3154]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2096.3154], dtype=float32)
# mu,alpha,beta=(Array(1.3549824, dtype=float32), Array([0.8878565], dtype=float32), array([1.02852424]))
#
# E
# Normalise
# [[1.3549824 0.       ]
#  [1.3549824 0.470078 ]
#  [1.3549824 0.935343 ]
#  ...
#  [1.3549824 3.3313613]
#  [1.3549824 3.8595176]
#  [1.3549824 3.427165 ]]
# M
# q
# [2092.97]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2092.97], dtype=float32)
# mu,alpha,beta=(Array(1.3651191, dtype=float32), Array([0.8881711], dtype=float32), array([1.03013257]))
#
# E
# Normalise
# [[1.3651191  0.        ]
#  [1.3651191  0.46977723]
#  [1.3651191  0.9348074 ]
#  ...
#  [1.3651191  3.3263078 ]
#  [1.3651191  3.8546462 ]
#  [1.3651191  3.4221308 ]]
# M
# q
# [2089.8115]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2089.8115], dtype=float32)
# mu,alpha,beta=(Array(1.3747365, dtype=float32), Array([0.89133584], dtype=float32), array([1.03499792]))
#
# E
# Normalise
# [[1.3747365  0.        ]
#  [1.3747365  0.47003508]
#  [1.3747365  0.93551224]
#  ...
#  [1.3747365  3.3193872 ]
#  [1.3747365  3.8495877 ]
#  [1.3747365  3.4154963 ]]
# M
# q
# [2086.8262]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2086.8262], dtype=float32)
# mu,alpha,beta=(Array(1.3840324, dtype=float32), Array([0.89032775], dtype=float32), array([1.03497265]))
#
# E
# Normalise
# [[1.3840324 0.       ]
#  [1.3840324 0.4695108]
#  [1.3840324 0.9344678]
#  ...
#  [1.3840324 3.3157299]
#  [1.3840324 3.8453312]
#  [1.3840324 3.4117303]]
# M
# q
# [2083.959]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2083.959], dtype=float32)
# mu,alpha,beta=(Array(1.3927615, dtype=float32), Array([0.88940156], dtype=float32), array([1.03497265]))
#
# E
# Normalise
# [[1.3927615  0.        ]
#  [1.3927615  0.46902236]
#  [1.3927615  0.93349576]
#  ...
#  [1.3927615  3.3122807 ]
#  [1.3927615  3.8413305 ]
#  [1.3927615  3.4081814 ]]
# M
# q
# [2081.2783]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2081.2783], dtype=float32)
# mu,alpha,beta=(Array(1.4009547, dtype=float32), Array([0.8899185], dtype=float32), array([1.03659106]))
#
# E
# Normalise
# [[1.4009547  0.        ]
#  [1.4009547  0.46882564]
#  [1.4009547  0.93316823]
#  ...
#  [1.4009547  3.3080206 ]
#  [1.4009547  3.8373702 ]
#  [1.4009547  3.4039545 ]]
# M
# q
# [2078.7715]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2078.7715], dtype=float32)
# mu,alpha,beta=(Array(1.4087266, dtype=float32), Array([0.89032775], dtype=float32), array([1.03803458]))
#
# E
# Normalise
# [[1.4087266  0.        ]
#  [1.4087266  0.4686228 ]
#  [1.4087266  0.93282175]
#  ...
#  [1.4087266  3.3040433 ]
#  [1.4087266  3.8336291 ]
#  [1.4087266  3.4       ]]
# M
# q
# [2076.4028]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2076.4028], dtype=float32)
# mu,alpha,beta=(Array(1.4160906, dtype=float32), Array([0.89108396], dtype=float32), array([1.03983547]))
#
# E
# Normalise
# [[1.4160906  0.        ]
#  [1.4160906  0.4684989 ]
#  [1.4160906  0.93264675]
#  ...
#  [1.4160906  3.300011  ]
#  [1.4160906  3.8300378 ]
#  [1.4160906  3.396021  ]]
# M
# q
# [2074.166]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2074.166], dtype=float32)
# mu,alpha,beta=(Array(1.4230876, dtype=float32), Array([0.888951], dtype=float32), array([1.038212]))
#
# E
# Normalise
# [[1.4230876 0.       ]
#  [1.4230876 0.4678468]
#  [1.4230876 0.9312841]
#  ...
#  [1.4230876 3.2982602]
#  [1.4230876 3.8270268]
#  [1.4230876 3.3940666]]
# M
# q
# [2072.0503]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2072.0503], dtype=float32)
# mu,alpha,beta=(Array(1.4295548, dtype=float32), Array([0.88964856], dtype=float32), array([1.03983547]))
#
# E
# Normalise
# [[1.4295548  0.        ]
#  [1.4295548  0.46774423]
#  [1.4295548  0.93114436]
#  ...
#  [1.4295548  3.2946951 ]
#  [1.4295548  3.823868  ]
#  [1.4295548  3.3905504 ]]
# M
# q
# [2070.1003]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2070.1003], dtype=float32)
# mu,alpha,beta=(Array(1.4356965, dtype=float32), Array([0.89042413], dtype=float32), array([1.04151234]))
#
# E
# Normalise
# [[1.4356965  0.        ]
#  [1.4356965  0.4676669 ]
#  [1.4356965  0.93105733]
#  ...
#  [1.4356965  3.2912319 ]
#  [1.4356965  3.8208566 ]
#  [1.4356965  3.3871427 ]]
# M
# q
# [2068.2534]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2068.2534], dtype=float32)
# mu,alpha,beta=(Array(1.4415344, dtype=float32), Array([0.8911456], dtype=float32), array([1.04309004]))
#
# E
# Normalise
# [[1.4415344  0.        ]
#  [1.4415344  0.46758944]
#  [1.4415344  0.93096626]
#  ...
#  [1.4415344  3.2879567 ]
#  [1.4415344  3.8180013 ]
#  [1.4415344  3.3839166 ]]
# M
# q
# [2066.5032]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2066.5032], dtype=float32)
# mu,alpha,beta=(Array(1.4470806, dtype=float32), Array([0.8905526], dtype=float32), array([1.04309004]))
#
# E
# Normalise
# [[1.4470806 0.       ]
#  [1.4470806 0.4672783]
#  [1.4470806 0.9303468]
#  ...
#  [1.4470806 3.2857685]
#  [1.4470806 3.8154604]
#  [1.4470806 3.3816645]]
# M
# q
# [2064.8455]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2064.8455], dtype=float32)
# mu,alpha,beta=(Array(1.4522673, dtype=float32), Array([0.891734], dtype=float32), array([1.04512932]))
#
# E
# Normalise
# [[1.4522673  0.        ]
#  [1.4522673  0.46730864]
#  [1.4522673  0.93048906]
#  ...
#  [1.4522673  3.2824762 ]
#  [1.4522673  3.8128583 ]
#  [1.4522673  3.37846   ]]
# M
# q
# [2063.2988]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2063.2988], dtype=float32)
# mu,alpha,beta=(Array(1.4572256, dtype=float32), Array([0.89085543], dtype=float32), array([1.04472114]))
#
# E
# Normalise
# [[1.4572256  0.        ]
#  [1.4572256  0.46696603]
#  [1.4572256  0.9297905 ]
#  ...
#  [1.4572256  3.2807689 ]
#  [1.4572256  3.8106315 ]
#  [1.4572256  3.3766663 ]]
# M
# q
# [2061.8242]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2061.8242], dtype=float32)
# mu,alpha,beta=(Array(1.4618374, dtype=float32), Array([0.8903615], dtype=float32), array([1.04472114]))
#
# E
# Normalise
# [[1.4618374  0.        ]
#  [1.4618374  0.46670714]
#  [1.4618374  0.9292749 ]
#  ...
#  [1.4618374  3.27895   ]
#  [1.4618374  3.8085182 ]
#  [1.4618374  3.3747945 ]]
# M
# q
# [2060.4556]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2060.4556], dtype=float32)
# mu,alpha,beta=(Array(1.4661462, dtype=float32), Array([0.8899001], dtype=float32), array([1.04472114]))
#
# E
# Normalise
# [[1.4661462  0.        ]
#  [1.4661462  0.46646526]
#  [1.4661462  0.9287934 ]
#  ...
#  [1.4661462  3.2772508 ]
#  [1.4661462  3.8065445 ]
#  [1.4661462  3.3730452 ]]
# M
# q
# [2059.18]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2059.18], dtype=float32)
# mu,alpha,beta=(Array(1.4701704, dtype=float32), Array([0.8925944], dtype=float32), array([1.04840045]))
#
# E
# Normalise
# [[1.4701704  0.        ]
#  [1.4701704  0.4668145 ]
#  [1.4701704  0.92963684]
#  ...
#  [1.4701704  3.273437  ]
#  [1.4701704  3.8043096 ]
#  [1.4701704  3.3694448 ]]
# M
# q
# [2057.9907]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2057.9907], dtype=float32)
# mu,alpha,beta=(Array(1.4741266, dtype=float32), Array([0.8918216], dtype=float32), array([1.047991]))
#
# E
# Normalise
# [[1.4741266 0.       ]
#  [1.4741266 0.4665284]
#  [1.4741266 0.9290506]
#  ...
#  [1.4741266 3.2721248]
#  [1.4741266 3.80254  ]
#  [1.4741266 3.368058 ]]
# M
# q
# [2056.8242]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2056.8242], dtype=float32)
# mu,alpha,beta=(Array(1.4777975, dtype=float32), Array([0.89281803], dtype=float32), array([1.04962977]))
#
# E
# Normalise
# [[1.4777975  0.        ]
#  [1.4777975  0.46657664]
#  [1.4777975  0.92921305]
#  ...
#  [1.4777975  3.2696943 ]
#  [1.4777975  3.800691  ]
#  [1.4777975  3.3656986 ]]
# M
# q
# [2055.7437]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2055.7437], dtype=float32)
# mu,alpha,beta=(Array(1.4813123, dtype=float32), Array([0.8924399], dtype=float32), array([1.04962977]))
#
# E
# Normalise
# [[1.4813123  0.        ]
#  [1.4813123  0.46637905]
#  [1.4813123  0.9288194 ]
#  ...
#  [1.4813123  3.2683098 ]
#  [1.4813123  3.799081  ]
#  [1.4813123  3.364273  ]]
# M
# q
# [2054.711]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2054.711], dtype=float32)
# mu,alpha,beta=(Array(1.4845916, dtype=float32), Array([0.8933917], dtype=float32), array([1.05116844]))
#
# E
# Normalise
# [[1.4845916 0.       ]
#  [1.4845916 0.4664325]
#  [1.4845916 0.9289884]
#  ...
#  [1.4845916 3.2661   ]
#  [1.4845916 3.7974262]
#  [1.4845916 3.3621294]]
# M
# q
# [2053.7488]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2053.7488], dtype=float32)
# mu,alpha,beta=(Array(1.4877343, dtype=float32), Array([0.8930531], dtype=float32), array([1.05116844]))
#
# E
# Normalise
# [[1.4877343  0.        ]
#  [1.4877343  0.46625572]
#  [1.4877343  0.92863625]
#  ...
#  [1.4877343  3.2648616 ]
#  [1.4877343  3.7959867 ]
#  [1.4877343  3.3608553 ]]
# M
# q
# [2052.8281]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2052.8281], dtype=float32)
# mu,alpha,beta=(Array(1.4906654, dtype=float32), Array([0.89334637], dtype=float32), array([1.05188726]))
#
# E
# Normalise
# [[1.4906654  0.        ]
#  [1.4906654  0.46620157]
#  [1.4906654  0.9285577 ]
#  ...
#  [1.4906654  3.26328   ]
#  [1.4906654  3.7945745 ]
#  [1.4906654  3.3592882 ]]
# M
# q
# [2051.9707]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2051.9707], dtype=float32)
# mu,alpha,beta=(Array(1.4934378, dtype=float32), Array([0.89252543], dtype=float32), array([1.0512711]))
#
# E
# Normalise
# [[1.4934378 0.       ]
#  [1.4934378 0.4659507]
#  [1.4934378 0.9280328]
#  ...
#  [1.4934378 3.2625535]
#  [1.4934378 3.7933645]
#  [1.4934378 3.3584883]]
# M
# q
# [2051.1606]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2051.1606], dtype=float32)
# mu,alpha,beta=(Array(1.4959891, dtype=float32), Array([0.8922505], dtype=float32), array([1.0512711]))
#
# E
# Normalise
# [[1.4959891  0.        ]
#  [1.4959891  0.46580714]
#  [1.4959891  0.9277469 ]
#  ...
#  [1.4959891  3.2615485 ]
#  [1.4959891  3.7921956 ]
#  [1.4959891  3.3574533 ]]
# M
# q
# [2050.416]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2050.416], dtype=float32)
# mu,alpha,beta=(Array(1.4983673, dtype=float32), Array([0.8919941], dtype=float32), array([1.0512711]))
#
# E
# Normalise
# [[1.4983673  0.        ]
#  [1.4983673  0.46567333]
#  [1.4983673  0.9274804 ]
#  ...
#  [1.4983673  3.2606118 ]
#  [1.4983673  3.7911062 ]
#  [1.4983673  3.3564887 ]]
# M
# q
# [2049.7231]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2049.7231], dtype=float32)
# mu,alpha,beta=(Array(1.5005839, dtype=float32), Array([0.8917986], dtype=float32), array([1.05132243]))
#
# E
# Normalise
# [[1.5005839  0.        ]
#  [1.5005839  0.4655564 ]
#  [1.5005839  0.92724967]
#  ...
#  [1.5005839  3.259708  ]
#  [1.5005839  3.7900856 ]
#  [1.5005839  3.3555627 ]]
# M
# q
# [2049.0776]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2049.0776], dtype=float32)
# mu,alpha,beta=(Array(1.5026525, dtype=float32), Array([0.8929233], dtype=float32), array([1.05291499]))
#
# E
# Normalise
# [[1.5026525  0.        ]
#  [1.5026525  0.46568483]
#  [1.5026525  0.9275701 ]
#  ...
#  [1.5026525  3.257951  ]
#  [1.5026525  3.7889857 ]
#  [1.5026525  3.3538878 ]]
# M
# q
# [2048.4766]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2048.4766], dtype=float32)
# mu,alpha,beta=(Array(1.5046662, dtype=float32), Array([0.8940988], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5046662  0.        ]
#  [1.5046662  0.46582344]
#  [1.5046662  0.9279134 ]
#  ...
#  [1.5046662  3.2561893 ]
#  [1.5046662  3.787911  ]
#  [1.5046662  3.3522105 ]]
# M
# q
# [2047.8922]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2047.8922], dtype=float32)
# mu,alpha,beta=(Array(1.5066315, dtype=float32), Array([0.8924937], dtype=float32), array([1.05291499]))
#
# E
# Normalise
# [[1.5066315  0.        ]
#  [1.5066315  0.46546078]
#  [1.5066315  0.9271239 ]
#  ...
#  [1.5066315  3.2563834 ]
#  [1.5066315  3.787163  ]
#  [1.5066315  3.3522742 ]]
# M
# q
# [2047.321]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2047.321], dtype=float32)
# mu,alpha,beta=(Array(1.5083733, dtype=float32), Array([0.89230585], dtype=float32), array([1.05291499]))
#
# E
# Normalise
# [[1.5083733  0.        ]
#  [1.5083733  0.46536282]
#  [1.5083733  0.92692876]
#  ...
#  [1.5083733  3.2556982 ]
#  [1.5083733  3.7863657 ]
#  [1.5083733  3.3515685 ]]
# M
# q
# [2046.816]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2046.816], dtype=float32)
# mu,alpha,beta=(Array(1.5099953, dtype=float32), Array([0.89369684], dtype=float32), array([1.05476745]))
#
# E
# Normalise
# [[1.5099953 0.       ]
#  [1.5099953 0.4655547]
#  [1.5099953 0.9273865]
#  ...
#  [1.5099953 3.2539706]
#  [1.5099953 3.7854512]
#  [1.5099953 3.3499432]]
# M
# q
# [2046.3467]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2046.3467], dtype=float32)
# mu,alpha,beta=(Array(1.5116066, dtype=float32), Array([0.89334846], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5116066 0.       ]
#  [1.5116066 0.4654325]
#  [1.5116066 0.9271347]
#  ...
#  [1.5116066 3.2534568]
#  [1.5116066 3.7847314]
#  [1.5116066 3.3493974]]
# M
# q
# [2045.8801]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2045.8801], dtype=float32)
# mu,alpha,beta=(Array(1.513096, dtype=float32), Array([0.893884], dtype=float32), array([1.05538566]))
#
# E
# Normalise
# [[1.513096   0.        ]
#  [1.513096   0.46547425]
#  [1.513096   0.9272516 ]
#  ...
#  [1.513096   3.2523882 ]
#  [1.513096   3.7839751 ]
#  [1.513096   3.3483644 ]]
# M
# q
# [2045.4492]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2045.4492], dtype=float32)
# mu,alpha,beta=(Array(1.5145276, dtype=float32), Array([0.8958216], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5145276  0.        ]
#  [1.5145276  0.46576953]
#  [1.5145276  0.9279413 ]
#  ...
#  [1.5145276  3.2503834 ]
#  [1.5145276  3.783102  ]
#  [1.5145276  3.3464997 ]]
# M
# q
# [2045.0366]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2045.0366], dtype=float32)
# mu,alpha,beta=(Array(1.5159953, dtype=float32), Array([0.8933962], dtype=float32), array([1.05517955]))
#
# E
# Normalise
# [[1.5159953  0.        ]
#  [1.5159953  0.46527952]
#  [1.5159953  0.9268552 ]
#  ...
#  [1.5159953  3.2513676 ]
#  [1.5159953  3.7826655 ]
#  [1.5159953  3.3472967 ]]
# M
# q
# [2044.6113]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2044.6113], dtype=float32)
# mu,alpha,beta=(Array(1.5172157, dtype=float32), Array([0.8927421], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5172157  0.        ]
#  [1.5172157  0.4651166 ]
#  [1.5172157  0.92650545]
#  ...
#  [1.5172157  3.2512484 ]
#  [1.5172157  3.7821627 ]
#  [1.5172157  3.3471239 ]]
# M
# q
# [2044.2585]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2044.2585], dtype=float32)
# mu,alpha,beta=(Array(1.5183183, dtype=float32), Array([0.8926229], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5183183  0.        ]
#  [1.5183183  0.46505448]
#  [1.5183183  0.9263817 ]
#  ...
#  [1.5183183  3.2508142 ]
#  [1.5183183  3.7816577 ]
#  [1.5183183  3.3466768 ]]
# M
# q
# [2043.9404]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.9404], dtype=float32)
# mu,alpha,beta=(Array(1.5193448, dtype=float32), Array([0.89242494], dtype=float32), array([1.05445848]))
#
# E
# Normalise
# [[1.5193448  0.        ]
#  [1.5193448  0.46498096]
#  [1.5193448  0.926231  ]
#  ...
#  [1.5193448  3.2504706 ]
#  [1.5193448  3.7811968 ]
#  [1.5193448  3.3463147 ]]
# M
# q
# [2043.6442]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.6442], dtype=float32)
# mu,alpha,beta=(Array(1.5202944, dtype=float32), Array([0.89519614], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5202944  0.        ]
#  [1.5202944  0.46544436]
#  [1.5202944  0.9272934 ]
#  ...
#  [1.5202944  3.2481143 ]
#  [1.5202944  3.7804606 ]
#  [1.5202944  3.3441634 ]]
# M
# q
# [2043.3722]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.3722], dtype=float32)
# mu,alpha,beta=(Array(1.5213635, dtype=float32), Array([0.8930764], dtype=float32), array([1.05548873]))
#
# E
# Normalise
# [[1.5213635  0.        ]
#  [1.5213635  0.46502408]
#  [1.5213635  0.92635894]
#  ...
#  [1.5213635  3.2490728 ]
#  [1.5213635  3.7801788 ]
#  [1.5213635  3.3449602 ]]
# M
# q
# [2043.0627]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2043.0627], dtype=float32)
# mu,alpha,beta=(Array(1.5222294, dtype=float32), Array([0.8939404], dtype=float32), array([1.05662316]))
#
# E
# Normalise
# [[1.5222294  0.        ]
#  [1.5222294  0.46514758]
#  [1.5222294  0.9266515 ]
#  ...
#  [1.5222294  3.2480717 ]
#  [1.5222294  3.779682  ]
#  [1.5222294  3.3440204 ]]
# M
# q
# [2042.814]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.814], dtype=float32)
# mu,alpha,beta=(Array(1.5230969, dtype=float32), Array([0.8948923], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5230969  0.        ]
#  [1.5230969  0.46528634]
#  [1.5230969  0.9269787 ]
#  ...
#  [1.5230969  3.2470114 ]
#  [1.5230969  3.7791772 ]
#  [1.5230969  3.3430283 ]]
# M
# q
# [2042.565]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.565], dtype=float32)
# mu,alpha,beta=(Array(1.5239716, dtype=float32), Array([0.8920335], dtype=float32), array([1.0545872]))
#
# E
# Normalise
# [[1.5239716  0.        ]
#  [1.5239716  0.46474004]
#  [1.5239716  0.92575634]
#  ...
#  [1.5239716  3.2485738 ]
#  [1.5239716  3.7790666 ]
#  [1.5239716  3.3443723 ]]
# M
# q
# [2042.3113]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.3113], dtype=float32)
# mu,alpha,beta=(Array(1.5246072, dtype=float32), Array([0.89403135], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5246072  0.        ]
#  [1.5246072  0.46507624]
#  [1.5246072  0.9265261 ]
#  ...
#  [1.5246072  3.2468965 ]
#  [1.5246072  3.7785573 ]
#  [1.5246072  3.3428435 ]]
# M
# q
# [2042.13]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2042.13], dtype=float32)
# mu,alpha,beta=(Array(1.5253319, dtype=float32), Array([0.89360297], dtype=float32), array([1.05662155]))
#
# E
# Normalise
# [[1.5253319 0.       ]
#  [1.5253319 0.4649725]
#  [1.5253319 0.9263025]
#  ...
#  [1.5253319 3.2468514]
#  [1.5253319 3.778261 ]
#  [1.5253319 3.3427641]]
# M
# q
# [2041.9214]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.9214], dtype=float32)
# mu,alpha,beta=(Array(1.5259836, dtype=float32), Array([0.89387935], dtype=float32), array([1.05703276]))
#
# E
# Normalise
# [[1.5259836  0.        ]
#  [1.5259836  0.46499807]
#  [1.5259836  0.9263703 ]
#  ...
#  [1.5259836  3.246356  ]
#  [1.5259836  3.7779264 ]
#  [1.5259836  3.3422873 ]]
# M
# q
# [2041.7338]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.7338], dtype=float32)
# mu,alpha,beta=(Array(1.5266124, dtype=float32), Array([0.89381397], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5266124  0.        ]
#  [1.5266124  0.46496317]
#  [1.5266124  0.9263009 ]
#  ...
#  [1.5266124  3.2461069 ]
#  [1.5266124  3.7776382 ]
#  [1.5266124  3.342031  ]]
# M
# q
# [2041.5532]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.5532], dtype=float32)
# mu,alpha,beta=(Array(1.5271975, dtype=float32), Array([0.89479625], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5271975  0.        ]
#  [1.5271975  0.46511754]
#  [1.5271975  0.92665935]
#  ...
#  [1.5271975  3.245159  ]
#  [1.5271975  3.777264  ]
#  [1.5271975  3.3411534 ]]
# M
# q
# [2041.3856]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.3856], dtype=float32)
# mu,alpha,beta=(Array(1.5278094, dtype=float32), Array([0.8942069], dtype=float32), array([1.05765552]))
#
# E
# Normalise
# [[1.5278094  0.        ]
#  [1.5278094  0.46498936]
#  [1.5278094  0.92637855]
#  ...
#  [1.5278094  3.2452767 ]
#  [1.5278094  3.777037  ]
#  [1.5278094  3.3412254 ]]
# M
# q
# [2041.2097]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.2097], dtype=float32)
# mu,alpha,beta=(Array(1.528345, dtype=float32), Array([0.8936263], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.528345   0.        ]
#  [1.528345   0.4648655 ]
#  [1.528345   0.92610633]
#  ...
#  [1.528345   3.2454255 ]
#  [1.528345   3.7768452 ]
#  [1.528345   3.3413289 ]]
# M
# q
# [2041.0555]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2041.0555], dtype=float32)
# mu,alpha,beta=(Array(1.5288093, dtype=float32), Array([0.89340174], dtype=float32), array([1.05682955]))
#
# E
# Normalise
# [[1.5288093 0.       ]
#  [1.5288093 0.464808 ]
#  [1.5288093 0.9259834]
#  ...
#  [1.5288093 3.245362 ]
#  [1.5288093 3.77665  ]
#  [1.5288093 3.341247 ]]
# M
# q
# [2040.9219]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.9219], dtype=float32)
# mu,alpha,beta=(Array(1.52923, dtype=float32), Array([0.89422715], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.52923    0.        ]
#  [1.52923    0.46494055]
#  [1.52923    0.92628974]
#  ...
#  [1.52923    3.2445984 ]
#  [1.52923    3.7763681 ]
#  [1.52923    3.3405435 ]]
# M
# q
# [2040.8014]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.8014], dtype=float32)
# mu,alpha,beta=(Array(1.5296775, dtype=float32), Array([0.8913948], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5296775  0.        ]
#  [1.5296775  0.46441463]
#  [1.5296775  0.9251071 ]
#  ...
#  [1.5296775  3.2463417 ]
#  [1.5296775  3.7764552 ]
#  [1.5296775  3.3420727 ]]
# M
# q
# [2040.6711]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.6711], dtype=float32)
# mu,alpha,beta=(Array(1.5299143, dtype=float32), Array([0.8934562], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5299143  0.        ]
#  [1.5299143  0.46477705]
#  [1.5299143  0.92593014]
#  ...
#  [1.5299143  3.2448077 ]
#  [1.5299143  3.7761266 ]
#  [1.5299143  3.3406932 ]]
# M
# q
# [2040.605]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.605], dtype=float32)
# mu,alpha,beta=(Array(1.530269, dtype=float32), Array([0.89481163], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.530269   0.        ]
#  [1.530269   0.46500665]
#  [1.530269   0.92645544]
#  ...
#  [1.530269   3.2437115 ]
#  [1.530269   3.7758224 ]
#  [1.530269   3.3396962 ]]
# M
# q
# [2040.5043]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.5043], dtype=float32)
# mu,alpha,beta=(Array(1.5306892, dtype=float32), Array([0.8941995], dtype=float32), array([1.05801709]))
#
# E
# Normalise
# [[1.5306892 0.       ]
#  [1.5306892 0.4648816]
#  [1.5306892 0.9261787]
#  ...
#  [1.5306892 3.2439346]
#  [1.5306892 3.7756867]
#  [1.5306892 3.3398721]]
# M
# q
# [2040.3833]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.3833], dtype=float32)
# mu,alpha,beta=(Array(1.5310434, dtype=float32), Array([0.89416385], dtype=float32), array([1.05802032]))
#
# E
# Normalise
# [[1.5310434  0.        ]
#  [1.5310434  0.4648621 ]
#  [1.5310434  0.92613995]
#  ...
#  [1.5310434  3.2437935 ]
#  [1.5310434  3.7755244 ]
#  [1.5310434  3.3397272 ]]
# M
# q
# [2040.2815]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.2815], dtype=float32)
# mu,alpha,beta=(Array(1.5313729, dtype=float32), Array([0.89399475], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5313729 0.       ]
#  [1.5313729 0.4648197]
#  [1.5313729 0.926049 ]
#  ...
#  [1.5313729 3.243755 ]
#  [1.5313729 3.775387 ]
#  [1.5313729 3.3396752]]
# M
# q
# [2040.187]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.187], dtype=float32)
# mu,alpha,beta=(Array(1.5316708, dtype=float32), Array([0.8953572], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5316708  0.        ]
#  [1.5316708  0.46505222]
#  [1.5316708  0.9265802 ]
#  ...
#  [1.5316708  3.2426832 ]
#  [1.5316708  3.7751117 ]
#  [1.5316708  3.3387024 ]]
# M
# q
# [2040.1027]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2040.1027], dtype=float32)
# mu,alpha,beta=(Array(1.5320381, dtype=float32), Array([0.89383537], dtype=float32), array([1.05775881]))
#
# E
# Normalise
# [[1.5320381  0.        ]
#  [1.5320381  0.4647665 ]
#  [1.5320381  0.92593884]
#  ...
#  [1.5320381  3.2435524 ]
#  [1.5320381  3.7750907 ]
#  [1.5320381  3.339459  ]]
# M
# q
# [2039.9965]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.9965], dtype=float32)
# mu,alpha,beta=(Array(1.5322839, dtype=float32), Array([0.8935257], dtype=float32), array([1.05742315]))
#
# E
# Normalise
# [[1.5322839  0.        ]
#  [1.5322839  0.46470195]
#  [1.5322839  0.9257964 ]
#  ...
#  [1.5322839  3.2436502 ]
#  [1.5322839  3.775007  ]
#  [1.5322839  3.3395324 ]]
# M
# q
# [2039.9255]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.9255], dtype=float32)
# mu,alpha,beta=(Array(1.5324942, dtype=float32), Array([0.8953114], dtype=float32), array([1.05956805]))
#
# E
# Normalise
# [[1.5324942  0.        ]
#  [1.5324942  0.46501353]
#  [1.5324942  0.9265053 ]
#  ...
#  [1.5324942  3.24233   ]
#  [1.5324942  3.7747307 ]
#  [1.5324942  3.3383424 ]]
# M
# q
# [2039.8666]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.8666], dtype=float32)
# mu,alpha,beta=(Array(1.5328066, dtype=float32), Array([0.89227295], dtype=float32), array([1.05600423]))
#
# E
# Normalise
# [[1.5328066 0.       ]
#  [1.5328066 0.4644577]
#  [1.5328066 0.9252517]
#  ...
#  [1.5328066 3.244269 ]
#  [1.5328066 3.7748926]
#  [1.5328066 3.3400557]]
# M
# q
# [2039.7749]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.7749], dtype=float32)
# mu,alpha,beta=(Array(1.532903, dtype=float32), Array([0.8931323], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.532903   0.        ]
#  [1.532903   0.46460858]
#  [1.532903   0.92559445]
#  ...
#  [1.532903   3.2436314 ]
#  [1.532903   3.7747576 ]
#  [1.532903   3.339482  ]]
# M
# q
# [2039.7477]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.7477], dtype=float32)
# mu,alpha,beta=(Array(1.5330486, dtype=float32), Array([0.8948586], dtype=float32), array([1.05910253]))
#
# E
# Normalise
# [[1.5330486  0.        ]
#  [1.5330486  0.46491218]
#  [1.5330486  0.9262841 ]
#  ...
#  [1.5330486  3.2423794 ]
#  [1.5330486  3.7745144 ]
#  [1.5330486  3.3383572 ]]
# M
# q
# [2039.7074]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.7074], dtype=float32)
# mu,alpha,beta=(Array(1.5332971, dtype=float32), Array([0.89387316], dtype=float32), array([1.05796543]))
#
# E
# Normalise
# [[1.5332971  0.        ]
#  [1.5332971  0.4647268 ]
#  [1.5332971  0.92586815]
#  ...
#  [1.5332971  3.242938  ]
#  [1.5332971  3.7744973 ]
#  [1.5332971  3.3388424 ]]
# M
# q
# [2039.6357]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.6357], dtype=float32)
# mu,alpha,beta=(Array(1.5334659, dtype=float32), Array([0.8947262], dtype=float32), array([1.0589991]))
#
# E
# Normalise
# [[1.5334659  0.        ]
#  [1.5334659  0.4648731 ]
#  [1.5334659  0.92620206]
#  ...
#  [1.5334659  3.2422752 ]
#  [1.5334659  3.7743323 ]
#  [1.5334659  3.3382413 ]]
# M
# q
# [2039.588]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.588], dtype=float32)
# mu,alpha,beta=(Array(1.5336794, dtype=float32), Array([0.8930482], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5336794  0.        ]
#  [1.5336794  0.46456483]
#  [1.5336794  0.9255073 ]
#  ...
#  [1.5336794  3.243326  ]
#  [1.5336794  3.774402  ]
#  [1.5336794  3.3391678 ]]
# M
# q
# [2039.5254]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.5254], dtype=float32)
# mu,alpha,beta=(Array(1.5337707, dtype=float32), Array([0.8951291], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5337707  0.        ]
#  [1.5337707  0.46493372]
#  [1.5337707  0.92634416]
#  ...
#  [1.5337707  3.2418575 ]
#  [1.5337707  3.77415   ]
#  [1.5337707  3.337852  ]]
# M
# q
# [2039.5007]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.5007], dtype=float32)
# mu,alpha,beta=(Array(1.5339909, dtype=float32), Array([0.89353657], dtype=float32), array([1.05765552]))
#
# E
# Normalise
# [[1.5339909  0.        ]
#  [1.5339909  0.4646408 ]
#  [1.5339909  0.92568415]
#  ...
#  [1.5339909  3.242844  ]
#  [1.5339909  3.7742054 ]
#  [1.5339909  3.338721  ]]
# M
# q
# [2039.4365]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4365], dtype=float32)
# mu,alpha,beta=(Array(1.5340943, dtype=float32), Array([0.8936996], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5340943  0.        ]
#  [1.5340943  0.46466625]
#  [1.5340943  0.9257432 ]
#  ...
#  [1.5340943  3.2426841 ]
#  [1.5340943  3.7741406 ]
#  [1.5340943  3.3385727 ]]
# M
# q
# [2039.4072]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.4072], dtype=float32)
# mu,alpha,beta=(Array(1.5342017, dtype=float32), Array([0.89368796], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5342017 0.       ]
#  [1.5342017 0.4646602]
#  [1.5342017 0.9257312]
#  ...
#  [1.5342017 3.242642 ]
#  [1.5342017 3.7740915]
#  [1.5342017 3.3385296]]
# M
# q
# [2039.3763]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3763], dtype=float32)
# mu,alpha,beta=(Array(1.5343014, dtype=float32), Array([0.89359], dtype=float32), array([1.05775881]))
#
# E
# Normalise
# [[1.5343014  0.        ]
#  [1.5343014  0.46463892]
#  [1.5343014  0.9256846 ]
#  ...
#  [1.5343014  3.242662  ]
#  [1.5343014  3.7740543 ]
#  [1.5343014  3.3385417 ]]
# M
# q
# [2039.3478]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3478], dtype=float32)
# mu,alpha,beta=(Array(1.5343887, dtype=float32), Array([0.89331937], dtype=float32), array([1.05744897]))
#
# E
# Normalise
# [[1.5343887  0.        ]
#  [1.5343887  0.46458718]
#  [1.5343887  0.9255688 ]
#  ...
#  [1.5343887  3.2428071 ]
#  [1.5343887  3.774041  ]
#  [1.5343887  3.3386667 ]]
# M
# q
# [2039.3225]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3225], dtype=float32)
# mu,alpha,beta=(Array(1.534453, dtype=float32), Array([0.89296436], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.534453  0.       ]
#  [1.534453  0.4645212]
#  [1.534453  0.9254204]
#  ...
#  [1.534453  3.2430215]
#  [1.534453  3.7740479]
#  [1.534453  3.3388543]]
# M
# q
# [2039.3038]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3038], dtype=float32)
# mu,alpha,beta=(Array(1.5344903, dtype=float32), Array([0.8929603], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5344903  0.        ]
#  [1.5344903  0.46451908]
#  [1.5344903  0.9254162 ]
#  ...
#  [1.5344903  3.2430067 ]
#  [1.5344903  3.7740302 ]
#  [1.5344903  3.338839  ]]
# M
# q
# [2039.2931]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2931], dtype=float32)
# mu,alpha,beta=(Array(1.5345249, dtype=float32), Array([0.89295655], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5345249  0.        ]
#  [1.5345249  0.46451712]
#  [1.5345249  0.9254123 ]
#  ...
#  [1.5345249  3.2429934 ]
#  [1.5345249  3.7740145 ]
#  [1.5345249  3.338825  ]]
# M
# q
# [2039.283]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.283], dtype=float32)
# mu,alpha,beta=(Array(1.5345571, dtype=float32), Array([0.89086735], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5345571  0.        ]
#  [1.5345571  0.46413985]
#  [1.5345571  0.9245597 ]
#  ...
#  [1.5345571  3.244421  ]
#  [1.5345571  3.7742202 ]
#  [1.5345571  3.340095  ]]
# M
# q
# [2039.2726]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2726], dtype=float32)
# mu,alpha,beta=(Array(1.5344522, dtype=float32), Array([0.89279586], dtype=float32), array([1.056836]))
#
# E
# Normalise
# [[1.5344522  0.        ]
#  [1.5344522  0.46449095]
#  [1.5344522  0.925352  ]
#  ...
#  [1.5344522  3.2431376 ]
#  [1.5344522  3.7740653 ]
#  [1.5344522  3.3389575 ]]
# M
# q
# [2039.3037]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3037], dtype=float32)
# mu,alpha,beta=(Array(1.5344785, dtype=float32), Array([0.89088666], dtype=float32), array([1.05457433]))
#
# E
# Normalise
# [[1.5344785  0.        ]
#  [1.5344785  0.46414626]
#  [1.5344785  0.92457294]
#  ...
#  [1.5344785  3.2444441 ]
#  [1.5344785  3.774255  ]
#  [1.5344785  3.34012   ]]
# M
# q
# [2039.2949]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2949], dtype=float32)
# mu,alpha,beta=(Array(1.5343798, dtype=float32), Array([0.8936251], dtype=float32), array([1.05781046]))
#
# E
# Normalise
# [[1.5343798  0.        ]
#  [1.5343798  0.46464232]
#  [1.5343798  0.9256935 ]
#  ...
#  [1.5343798  3.2426019 ]
#  [1.5343798  3.7740142 ]
#  [1.5343798  3.3384836 ]]
# M
# q
# [2039.3252]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3252], dtype=float32)
# mu,alpha,beta=(Array(1.5344644, dtype=float32), Array([0.8936595], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5344644 0.       ]
#  [1.5344644 0.4646454]
#  [1.5344644 0.9257017]
#  ...
#  [1.5344644 3.2425385]
#  [1.5344644 3.773971 ]
#  [1.5344644 3.338423 ]]
# M
# q
# [2039.3014]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.3014], dtype=float32)
# mu,alpha,beta=(Array(1.5345459, dtype=float32), Array([0.8943038], dtype=float32), array([1.0586372]))
#
# E
# Normalise
# [[1.5345459  0.        ]
#  [1.5345459  0.46475756]
#  [1.5345459  0.9259571 ]
#  ...
#  [1.5345459  3.2420583 ]
#  [1.5345459  3.7738676 ]
#  [1.5345459  3.3379898 ]]
# M
# q
# [2039.2783]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2783], dtype=float32)
# mu,alpha,beta=(Array(1.5346639, dtype=float32), Array([0.8936378], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5346639 0.       ]
#  [1.5346639 0.4646341]
#  [1.5346639 0.9256792]
#  ...
#  [1.5346639 3.24246  ]
#  [1.5346639 3.7738795]
#  [1.5346639 3.3383417]]
# M
# q
# [2039.2439]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2439], dtype=float32)
# mu,alpha,beta=(Array(1.5347314, dtype=float32), Array([0.89310825], dtype=float32), array([1.05724246]))
#
# E
# Normalise
# [[1.5347314 0.       ]
#  [1.5347314 0.4645367]
#  [1.5347314 0.9254598]
#  ...
#  [1.5347314 3.2427924]
#  [1.5347314 3.7739022]
#  [1.5347314 3.3386347]]
# M
# q
# [2039.2242]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2242], dtype=float32)
# mu,alpha,beta=(Array(1.5347602, dtype=float32), Array([0.89362735], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5347602  0.        ]
#  [1.5347602  0.46462867]
#  [1.5347602  0.9256684 ]
#  ...
#  [1.5347602  3.242422  ]
#  [1.5347602  3.7738354 ]
#  [1.5347602  3.3383029 ]]
# M
# q
# [2039.2162]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.2162], dtype=float32)
# mu,alpha,beta=(Array(1.5348208, dtype=float32), Array([0.8936208], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5348208  0.        ]
#  [1.5348208  0.46462527]
#  [1.5348208  0.9256616 ]
#  ...
#  [1.5348208  3.2423983 ]
#  [1.5348208  3.773808  ]
#  [1.5348208  3.3382783 ]]
# M
# q
# [2039.1987]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1987], dtype=float32)
# mu,alpha,beta=(Array(1.5348773, dtype=float32), Array([0.8922226], dtype=float32), array([1.0562105]))
#
# E
# Normalise
# [[1.5348773  0.        ]
#  [1.5348773  0.46437225]
#  [1.5348773  0.92508996]
#  ...
#  [1.5348773  3.2433336 ]
#  [1.5348773  3.7739253 ]
#  [1.5348773  3.3391097 ]]
# M
# q
# [2039.1818]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1818], dtype=float32)
# mu,alpha,beta=(Array(1.5348397, dtype=float32), Array([0.8937058], dtype=float32), array([1.05796543]))
#
# E
# Normalise
# [[1.5348397  0.        ]
#  [1.5348397  0.46463978]
#  [1.5348397  0.9256948 ]
#  ...
#  [1.5348397  3.2423313 ]
#  [1.5348397  3.7737904 ]
#  [1.5348397  3.3382175 ]]
# M
# q
# [2039.1937]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1937], dtype=float32)
# mu,alpha,beta=(Array(1.5349007, dtype=float32), Array([0.8936122], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5349007  0.        ]
#  [1.5349007  0.4646208 ]
#  [1.5349007  0.92565274]
#  ...
#  [1.5349007  3.242367  ]
#  [1.5349007  3.7737715 ]
#  [1.5349007  3.3382463 ]]
# M
# q
# [2039.1763]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1763], dtype=float32)
# mu,alpha,beta=(Array(1.5349514, dtype=float32), Array([0.8937808], dtype=float32), array([1.05806875]))
#
# E
# Normalise
# [[1.5349514  0.        ]
#  [1.5349514  0.46464908]
#  [1.5349514  0.9257176 ]
#  ...
#  [1.5349514  3.2422276 ]
#  [1.5349514  3.7737305 ]
#  [1.5349514  3.338119  ]]
# M
# q
# [2039.1619]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1619], dtype=float32)
# mu,alpha,beta=(Array(1.53501, dtype=float32), Array([0.894297], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.53501    0.        ]
#  [1.53501    0.46473923]
#  [1.53501    0.92592263]
#  ...
#  [1.53501    3.2418463 ]
#  [1.53501    3.7736511 ]
#  [1.53501    3.3377752 ]]
# M
# q
# [2039.1455]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1455], dtype=float32)
# mu,alpha,beta=(Array(1.5350984, dtype=float32), Array([0.8939391], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5350984 0.       ]
#  [1.5350984 0.464672 ]
#  [1.5350984 0.9257717]
#  ...
#  [1.5350984 3.2420506]
#  [1.5350984 3.7736456]
#  [1.5350984 3.337953 ]]
# M
# q
# [2039.1199]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1199], dtype=float32)
# mu,alpha,beta=(Array(1.5351578, dtype=float32), Array([0.8949783], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5351578 0.       ]
#  [1.5351578 0.4648554]
#  [1.5351578 0.9261881]
#  ...
#  [1.5351578 3.241311 ]
#  [1.5351578 3.773514 ]
#  [1.5351578 3.3372898]]
# M
# q
# [2039.1035]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.1035], dtype=float32)
# mu,alpha,beta=(Array(1.5352811, dtype=float32), Array([0.89496505], dtype=float32), array([1.05951632]))
#
# E
# Normalise
# [[1.5352811  0.        ]
#  [1.5352811  0.46484852]
#  [1.5352811  0.9261744 ]
#  ...
#  [1.5352811  3.2412634 ]
#  [1.5352811  3.7734582 ]
#  [1.5352811  3.3372405 ]]
# M
# q
# [2039.0684]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.0684], dtype=float32)
# mu,alpha,beta=(Array(1.5353955, dtype=float32), Array([0.8935585], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5353955  0.        ]
#  [1.5353955  0.46459287]
#  [1.5353955  0.9255971 ]
#  ...
#  [1.5353955  3.2421722 ]
#  [1.5353955  3.7735445 ]
#  [1.5353955  3.3380456 ]]
# M
# q
# [2039.0344]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.0344], dtype=float32)
# mu,alpha,beta=(Array(1.5354116, dtype=float32), Array([0.8963472], dtype=float32), array([1.06117311]))
#
# E
# Normalise
# [[1.5354116  0.        ]
#  [1.5354116  0.46508977]
#  [1.5354116  0.9267234 ]
#  ...
#  [1.5354116  3.2402623 ]
#  [1.5354116  3.7732642 ]
#  [1.5354116  3.336338  ]]
# M
# q
# [2039.0321]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2039.0321], dtype=float32)
# mu,alpha,beta=(Array(1.5356072, dtype=float32), Array([0.8937314], dtype=float32), array([1.05809458]))
#
# E
# Normalise
# [[1.5356072  0.        ]
#  [1.5356072  0.46461597]
#  [1.5356072  0.9256527 ]
#  ...
#  [1.5356072  3.2419543 ]
#  [1.5356072  3.773428  ]
#  [1.5356072  3.3378396 ]]
# M
# q
# [2038.9742]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9742], dtype=float32)
# mu,alpha,beta=(Array(1.5356212, dtype=float32), Array([0.8938824], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5356212  0.        ]
#  [1.5356212  0.46464252]
#  [1.5356212  0.925713  ]
#  ...
#  [1.5356212  3.241845  ]
#  [1.5356212  3.7734065 ]
#  [1.5356212  3.3377414 ]]
# M
# q
# [2038.9702]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9702], dtype=float32)
# mu,alpha,beta=(Array(1.5356439, dtype=float32), Array([0.89422816], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5356439  0.        ]
#  [1.5356439  0.46470344]
#  [1.5356439  0.92585135]
#  ...
#  [1.5356439  3.2415965 ]
#  [1.5356439  3.7733607 ]
#  [1.5356439  3.3375185 ]]
# M
# q
# [2038.9639]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9639], dtype=float32)
# mu,alpha,beta=(Array(1.5356878, dtype=float32), Array([0.8950081], dtype=float32), array([1.05961979]))
#
# E
# Normalise
# [[1.5356878  0.        ]
#  [1.5356878  0.46484113]
#  [1.5356878  0.9261639 ]
#  ...
#  [1.5356878  3.2410438 ]
#  [1.5356878  3.7732635 ]
#  [1.5356878  3.3370223 ]]
# M
# q
# [2038.9521]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9521], dtype=float32)
# mu,alpha,beta=(Array(1.5357792, dtype=float32), Array([0.8935169], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5357792  0.        ]
#  [1.5357792  0.46457124]
#  [1.5357792  0.92555404]
#  ...
#  [1.5357792  3.2420216 ]
#  [1.5357792  3.773369  ]
#  [1.5357792  3.3378901 ]]
# M
# q
# [2038.9247]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9247], dtype=float32)
# mu,alpha,beta=(Array(1.5357684, dtype=float32), Array([0.8938664], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5357684  0.        ]
#  [1.5357684  0.4646342 ]
#  [1.5357684  0.92569643]
#  ...
#  [1.5357684  3.2417872 ]
#  [1.5357684  3.7733393 ]
#  [1.5357684  3.3376818 ]]
# M
# q
# [2038.9282]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9282], dtype=float32)
# mu,alpha,beta=(Array(1.5357809, dtype=float32), Array([0.8928204], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5357809  0.        ]
#  [1.5357809  0.4644463 ]
#  [1.5357809  0.92527115]
#  ...
#  [1.5357809  3.2424986 ]
#  [1.5357809  3.7734392 ]
#  [1.5357809  3.338316  ]]
# M
# q
# [2038.9236]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9236], dtype=float32)
# mu,alpha,beta=(Array(1.5357251, dtype=float32), Array([0.89282656], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5357251 0.       ]
#  [1.5357251 0.4644495]
#  [1.5357251 0.9252776]
#  ...
#  [1.5357251 3.242521 ]
#  [1.5357251 3.7734652]
#  [1.5357251 3.338339 ]]
# M
# q
# [2038.9397]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9397], dtype=float32)
# mu,alpha,beta=(Array(1.5356729, dtype=float32), Array([0.89283216], dtype=float32), array([1.05703598]))
#
# E
# Normalise
# [[1.5356729  0.        ]
#  [1.5356729  0.46445242]
#  [1.5356729  0.92528343]
#  ...
#  [1.5356729  3.2425413 ]
#  [1.5356729  3.7734888 ]
#  [1.5356729  3.3383598 ]]
# M
# q
# [2038.9545]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9545], dtype=float32)
# mu,alpha,beta=(Array(1.5356245, dtype=float32), Array([0.8935336], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5356245  0.        ]
#  [1.5356245  0.46457994]
#  [1.5356245  0.9255713 ]
#  ...
#  [1.5356245  3.2420816 ]
#  [1.5356245  3.7734394 ]
#  [1.5356245  3.3379526 ]]
# M
# q
# [2038.969]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.969], dtype=float32)
# mu,alpha,beta=(Array(1.5356246, dtype=float32), Array([0.89423037], dtype=float32), array([1.05868889]))
#
# E
# Normalise
# [[1.5356246 0.       ]
#  [1.5356246 0.4647046]
#  [1.5356246 0.9258536]
#  ...
#  [1.5356246 3.2416046]
#  [1.5356246 3.7733698]
#  [1.5356246 3.3375266]]
# M
# q
# [2038.9697]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9697], dtype=float32)
# mu,alpha,beta=(Array(1.5356698, dtype=float32), Array([0.89368105], dtype=float32), array([1.05804292]))
#
# E
# Normalise
# [[1.5356698  0.        ]
#  [1.5356698  0.46460468]
#  [1.5356698  0.92562795]
#  ...
#  [1.5356698  3.2419596 ]
#  [1.5356698  3.7734034 ]
#  [1.5356698  3.3378413 ]]
# M
# q
# [2038.9562]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9562], dtype=float32)
# mu,alpha,beta=(Array(1.5356767, dtype=float32), Array([0.89352804], dtype=float32), array([1.05786212]))
#
# E
# Normalise
# [[1.5356767  0.        ]
#  [1.5356767  0.46457705]
#  [1.5356767  0.92556554]
#  ...
#  [1.5356767  3.2420616 ]
#  [1.5356767  3.773416  ]
#  [1.5356767  3.337932  ]]
# M
# q
# [2038.9541]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9541], dtype=float32)
# mu,alpha,beta=(Array(1.535673, dtype=float32), Array([0.8927017], dtype=float32), array([1.05688116]))
#
# E
# Normalise
# [[1.535673  0.       ]
#  [1.535673  0.464429 ]
#  [1.535673  0.9252303]
#  ...
#  [1.535673  3.2426312]
#  [1.535673  3.7735026]
#  [1.535673  3.3384395]]
# M
# q
# [2038.9545]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9545], dtype=float32)
# mu,alpha,beta=(Array(1.5356162, dtype=float32), Array([0.8938828], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5356162  0.        ]
#  [1.5356162  0.46464273]
#  [1.5356162  0.9257134 ]
#  ...
#  [1.5356162  3.2418463 ]
#  [1.5356162  3.7734082 ]
#  [1.5356162  3.3377428 ]]
# M
# q
# [2038.9718]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9718], dtype=float32)
# mu,alpha,beta=(Array(1.5356394, dtype=float32), Array([0.8938803], dtype=float32), array([1.05827542]))
#
# E
# Normalise
# [[1.5356394  0.        ]
#  [1.5356394  0.46464145]
#  [1.5356394  0.9257108 ]
#  ...
#  [1.5356394  3.2418373 ]
#  [1.5356394  3.7733982 ]
#  [1.5356394  3.3377337 ]]
# M
# q
# [2038.9652]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.9652], dtype=float32)
# mu,alpha,beta=(Array(1.535661, dtype=float32), Array([0.89317065], dtype=float32), array([1.05743606]))
#
# E
# Normalise
# [[1.535661   0.        ]
#  [1.535661   0.46451357]
#  [1.535661   0.9254216 ]
#  ...
#  [1.535661   3.242314  ]
#  [1.535661   3.7734601 ]
#  [1.535661   3.3381581 ]]
# M
# q
# [2038.958]
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array([2038.958], dtype=float32)
# mu,alpha,beta=(Array(1.5356352, dtype=float32), Array([0.89075077], dtype=float32), array([1.05456146]))
#
# E
# Normalise
# [[1.5356352 0.       ]
#  [1.5356352 0.4640791]
#  [1.5356352 0.9244388]
#  ...
#  [1.5356352 3.2439961]
#  [1.5356352 3.7737265]
#  [1.5356352 3.3396578]]
# M
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt

# %%
def em(events, T, theta_guess = [0.5,0.5,0.5], steps=1000, learning_rate=0.01):
    mu,alpha,beta = theta_guess
    n = len(events)
    times = np.array([e[0] for e in events])
    
    momentum = 0
    loglikelihood_opt = None
    theta_opt = None
    for _ in range(steps):
        print("E")
        #E step
        branching_matrix = np.array([[0 for _ in range(len(events)+1)]]+[[mu]+[alpha*np.exp(beta*(e2[0]-e[0])) if e2[0]<e[0] else 0 for e2 in events] for e in events])
        print("Normalise")
        c = branching_matrix.sum(axis=1)
        c[0] = 1
        branching_matrix /= c.reshape(-1,1)
        
        plt.imshow(branching_matrix[:30,:30])
        plt.show()
        
        logbeta = np.log(beta)
        
        print("M")
        #M step
        @jax.jit
        def q(logbeta):
            beta = jnp.exp(logbeta)
            alpha = beta * branching_matrix[1:,1:].sum() / (1-jnp.exp(beta*(times-T))).sum()
            mu = (1/T) * branching_matrix[1:,0].sum()
            sum_residuals = mu*T + (alpha/beta)*(1-jnp.exp(beta*(times-T))).sum()
            #assert np.allclose([branching_matrix[i,0]+sum([branching_matrix[i,j] for j in range(1,i)]) for i in range(1,n+1)],1)
            sum_expected_event_ll = (branching_matrix[1:n+1,0]*np.log(mu)).sum() + (branching_matrix[1:,1:]*(jnp.log(alpha)+beta*(times.reshape(-1,1)-times.reshape(1,-1)))).sum()
            return sum_expected_event_ll - sum_residuals
        
        print("q")
        loglikelihood = q(logbeta)
#         gradient_step = np.array(jax.grad(q)(logbeta))
#         step_size = learning_rate * np.linalg.norm(gradient_step)**-2
#         logbeta += step_size * gradient_step

        print("Newton Step")
        newton_step = -jax.grad(q)(logbeta) / jax.hessian(q)(logbeta)
        logbeta += newton_step
        
        print("Beta,mu,alpha")
        beta = np.exp(logbeta)
        mu = (1/T) * branching_matrix[1:,0].sum()
        alpha = beta * branching_matrix[1:,1:].sum() / (1-jnp.exp(beta*(times-T))).sum()
        
        print("Update loglikelihood_opt")
        if loglikelihood_opt is None or loglikelihood > loglikelihood_opt:
            theta_opt = mu,alpha,beta
            loglikelihood_opt = loglikelihood
        
        #print(f'{loglikelihood=}\n{mu,alpha,beta=}\n{gradient_step*step_size=}\n')
        print(f'{loglikelihood=}\n{mu,alpha,beta=}\n{newton_step=}\n')
        
        """
        newton_step = -np.linalg.solve(jax.hessian(q)([logalpha,beta]), jax.grad(q)([logalpha,beta]))
        gradient_step = np.array(jax.grad(q)([logalpha,beta]))
        print(f'{logalpha,beta=}, {newton_step=}, {gradient_step=}')
        if all((newton_step*gradient_step)>0):
            print('newton')
            logalpha,beta = np.array([logalpha,beta]) + newton_step
        else:
            print('gradient')
            logalpha,beta = np.array([logalpha,beta]) + step_size * gradient_step
        """
        
        
    return theta_opt

# %%
mu,alpha,beta
# Out:
# (1, 1, 1.1)

# %%
em(events,T,theta_guess=[1,1,1.1])
# Out:
# E
# Normalise
# M
# q
# Newton Step
# Beta,mu,alpha
# Update loglikelihood_opt
# loglikelihood=Array(-3139.2756, dtype=float32)
# mu,alpha,beta=(0.9923247001107299, Array(0.97055316, dtype=float32), 1.1016262)
# newton_step=Array(0.00147724, dtype=float32)
#
# E
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /var/folders/5l/jdr1h_pn3x3_7nt8kgthzmv00000gn/T/ipykernel_68354/122524364.py in <module>
# ----> 1 em(events,T,theta_guess=[1,1,1.1])
#
# /var/folders/5l/jdr1h_pn3x3_7nt8kgthzmv00000gn/T/ipykernel_68354/3786705338.py in em(events, T, theta_guess, steps, learning_rate)
#      11         #E step
# ---> 12         branching_matrix = np.array([[0 for _ in range(len(events)+1)]]+[[mu]+[alpha*np.exp(beta*(e2[0]-e[0])) if e2[0]<e[0] else 0 for e2 in events] for e in events])
#      13         print("Normalise")
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/array.py in __array__(self, dtype, context)
#     340   def __array__(self, dtype=None, context=None):
# --> 341     return np.asarray(self._value, dtype=dtype)
#     342
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/array.py in _value(self)
#     482   def _value(self) -> np.ndarray:
# --> 483     self._check_if_deleted()
#     484
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/array.py in _check_if_deleted(self)
#     457   def _check_if_deleted(self):
# --> 458     if self.is_deleted():
#     459       raise RuntimeError("Array has been deleted.")
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
def gradient_steps(events, T, theta_guess = np.array([0.5,0.5,0.5]), steps=1000, learning_rate=100):
    theta = theta_guess
    n = len(events)
    
    loglikelihood_opt = None
    theta_opt = None
    for _ in range(steps):
        logtheta = np.log(theta)
        #M step
        @jax.jit
        def q(logtheta):
            mu, alpha, beta = jnp.exp(logtheta)
            sum_residuals = mu*T + (alpha/beta)*(1-jnp.exp(beta*(times-T))).sum()
            sum_event_ll = jnp.log(mu+alpha*jnp.exp(beta*(times-times.reshape(-1,1)))).sum()
            return sum_event_ll - sum_residuals
        
        loglikelihood = q(logtheta)
        gradient_step = np.array(jax.grad(q)(logtheta))
        print(gradient_step)
        step_size = learning_rate * np.linalg.norm(gradient_step)**-2
        logtheta += step_size * gradient_step
        
        theta = np.exp(logtheta)
        
        if loglikelihood_opt is None or loglikelihood > loglikelihood_opt:
            theta_opt = theta
            loglikelihood_opt = loglikelihood
        
        #print(f'{loglikelihood=}\n{mu,alpha,beta=}\n{gradient_step*step_size=}\n')
        print(f'{loglikelihood=}\n{theta=}\n{step_size * gradient_step=}\n')
        
    return theta_opt

# %%
gradient_steps(events,T,theta_guess = [0.5,0.5,0.5])

# %%
gradient_steps(events,T,theta_guess = [1,1,1.1])
# Out:
# loglikelihood=Array(-1867.9996, dtype=float32)
# theta=array([1.00001368, 1.00001368, 1.10000001])
# step_size * gradient_step=array([1.3683576e-05, 1.3677852e-05, 6.3930514e-09], dtype=float32)
#
# loglikelihood=Array(-1754.776, dtype=float32)
# theta=array([1.00002737, 1.00002736, 1.10000001])
# step_size * gradient_step=array([1.3683576e-05, 1.3677852e-05, 6.3931402e-09], dtype=float32)
#
# loglikelihood=Array(-1674.49, dtype=float32)
# theta=array([1.00004105, 1.00004103, 1.10000002])
# step_size * gradient_step=array([1.3683576e-05, 1.3677852e-05, 6.3932277e-09], dtype=float32)
#
# loglikelihood=Array(-1592.5789, dtype=float32)
# theta=array([1.00005474, 1.00005471, 1.10000003])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3933157e-09], dtype=float32)
#
# loglikelihood=Array(-1472.2928, dtype=float32)
# theta=array([1.00006842, 1.00006839, 1.10000004])
# step_size * gradient_step=array([1.3683576e-05, 1.3677852e-05, 6.3934040e-09], dtype=float32)
#
# loglikelihood=Array(-1373.3192, dtype=float32)
# theta=array([1.0000821 , 1.00008207, 1.10000004])
# step_size * gradient_step=array([1.36835779e-05, 1.36778535e-05, 6.39349373e-09], dtype=float32)
#
# loglikelihood=Array(-1279.033, dtype=float32)
# theta=array([1.00009579, 1.00009575, 1.10000005])
# step_size * gradient_step=array([1.3683576e-05, 1.3677852e-05, 6.3935799e-09], dtype=float32)
#
# loglikelihood=Array(-1205.9343, dtype=float32)
# theta=array([1.00010947, 1.00010943, 1.10000006])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3936683e-09], dtype=float32)
#
# loglikelihood=Array(-1122.8982, dtype=float32)
# theta=array([1.00012316, 1.00012311, 1.10000006])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3937566e-09], dtype=float32)
#
# loglikelihood=Array(-1019.2998, dtype=float32)
# theta=array([1.00013685, 1.00013679, 1.10000007])
# step_size * gradient_step=array([1.3683576e-05, 1.3677852e-05, 6.3938455e-09], dtype=float32)
#
# loglikelihood=Array(-916.76355, dtype=float32)
# theta=array([1.00015053, 1.00015047, 1.10000008])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3939329e-09], dtype=float32)
#
# loglikelihood=Array(-815.47754, dtype=float32)
# theta=array([1.00016422, 1.00016415, 1.10000008])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3940209e-09], dtype=float32)
#
# loglikelihood=Array(-698.62866, dtype=float32)
# theta=array([1.0001779 , 1.00017783, 1.10000009])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3941088e-09], dtype=float32)
#
# loglikelihood=Array(-608.405, dtype=float32)
# theta=array([1.00019159, 1.00019151, 1.1000001 ])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3941976e-09], dtype=float32)
#
# loglikelihood=Array(-510.4314, dtype=float32)
# theta=array([1.00020527, 1.00020519, 1.10000011])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3942847e-09], dtype=float32)
#
# loglikelihood=Array(-436.45776, dtype=float32)
# theta=array([1.00021896, 1.00021887, 1.10000011])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3943735e-09], dtype=float32)
#
# loglikelihood=Array(-332.98438, dtype=float32)
# theta=array([1.00023265, 1.00023255, 1.10000012])
# step_size * gradient_step=array([1.3683578e-05, 1.3677853e-05, 6.3944636e-09], dtype=float32)
#
# loglikelihood=Array(-252.76074, dtype=float32)
# theta=array([1.00024633, 1.00024623, 1.10000013])
# step_size * gradient_step=array([1.3683576e-05, 1.3677851e-05, 6.3945502e-09], dtype=float32)
#
# loglikelihood=Array(-146.34973, dtype=float32)
# theta=array([1.00026002, 1.00025991, 1.10000013])
# step_size * gradient_step=array([1.3683578e-05, 1.3677853e-05, 6.3946404e-09], dtype=float32)
#
# loglikelihood=Array(-37.625854, dtype=float32)
# theta=array([1.00027371, 1.00027359, 1.10000014])
# step_size * gradient_step=array([1.3683579e-05, 1.3677853e-05, 6.3947274e-09], dtype=float32)
#
# loglikelihood=Array(54.28528, dtype=float32)
# theta=array([1.0002874 , 1.00028728, 1.10000015])
# step_size * gradient_step=array([1.3683579e-05, 1.3677853e-05, 6.3948158e-09], dtype=float32)
#
# loglikelihood=Array(167.69629, dtype=float32)
# theta=array([1.00030108, 1.00030096, 1.10000015])
# step_size * gradient_step=array([1.3683578e-05, 1.3677853e-05, 6.3949046e-09], dtype=float32)
#
# loglikelihood=Array(253.16992, dtype=float32)
# theta=array([1.00031477, 1.00031464, 1.10000016])
# step_size * gradient_step=array([1.3683579e-05, 1.3677853e-05, 6.3949925e-09], dtype=float32)
#
# loglikelihood=Array(351.39343, dtype=float32)
# theta=array([1.00032846, 1.00032832, 1.10000017])
# step_size * gradient_step=array([1.3683578e-05, 1.3677853e-05, 6.3950800e-09], dtype=float32)
#
# loglikelihood=Array(491.05457, dtype=float32)
# theta=array([1.00034215, 1.000342  , 1.10000018])
# step_size * gradient_step=array([1.3683579e-05, 1.3677853e-05, 6.3951684e-09], dtype=float32)
#
# loglikelihood=Array(578.0281, dtype=float32)
# theta=array([1.00035584, 1.00035569, 1.10000018])
# step_size * gradient_step=array([1.3683579e-05, 1.3677852e-05, 6.3952572e-09], dtype=float32)
#
# loglikelihood=Array(667.5017, dtype=float32)
# theta=array([1.00036952, 1.00036937, 1.10000019])
# step_size * gradient_step=array([1.36835815e-05, 1.36778544e-05, 6.39534692e-09], dtype=float32)
#
# loglikelihood=Array(730.22534, dtype=float32)
# theta=array([1.00038321, 1.00038305, 1.1000002 ])
# step_size * gradient_step=array([1.3683579e-05, 1.3677853e-05, 6.3954335e-09], dtype=float32)
#
# loglikelihood=Array(850.8241, dtype=float32)
# theta=array([1.0003969 , 1.00039674, 1.1000002 ])
# step_size * gradient_step=array([1.3683579e-05, 1.3677852e-05, 6.3955214e-09], dtype=float32)
#
# loglikelihood=Array(969.29785, dtype=float32)
# theta=array([1.00041059, 1.00041042, 1.10000021])
# step_size * gradient_step=array([1.36835815e-05, 1.36778544e-05, 6.39561026e-09], dtype=float32)
#
# loglikelihood=Array(1078.2087, dtype=float32)
# theta=array([1.00042428, 1.0004241 , 1.10000022])
# step_size * gradient_step=array([1.3683579e-05, 1.3677853e-05, 6.3956977e-09], dtype=float32)
#
# loglikelihood=Array(1164.6199, dtype=float32)
# theta=array([1.00043797, 1.00043779, 1.10000023])
# step_size * gradient_step=array([1.3683579e-05, 1.3677852e-05, 6.3957852e-09], dtype=float32)
#
# loglikelihood=Array(1285.0311, dtype=float32)
# theta=array([1.00045166, 1.00045147, 1.10000023])
# step_size * gradient_step=array([1.36835815e-05, 1.36778544e-05, 6.39587494e-09], dtype=float32)
#
# loglikelihood=Array(1379.0673, dtype=float32)
# theta=array([1.00046535, 1.00046516, 1.10000024])
# step_size * gradient_step=array([1.3683579e-05, 1.3677852e-05, 6.3959615e-09], dtype=float32)
#
# loglikelihood=Array(1494.3533, dtype=float32)
# theta=array([1.00047904, 1.00047884, 1.10000025])
# step_size * gradient_step=array([1.3683579e-05, 1.3677852e-05, 6.3960499e-09], dtype=float32)
#
# loglikelihood=Array(1577.9518, dtype=float32)
# theta=array([1.00049273, 1.00049252, 1.10000025])
# step_size * gradient_step=array([1.36835815e-05, 1.36778544e-05, 6.39613962e-09], dtype=float32)
#
# loglikelihood=Array(1687.3629, dtype=float32)
# theta=array([1.00050642, 1.00050621, 1.10000026])
# step_size * gradient_step=array([1.3683579e-05, 1.3677852e-05, 6.3962267e-09], dtype=float32)
#
# loglikelihood=Array(1751.274, dtype=float32)
# theta=array([1.00052011, 1.00051989, 1.10000027])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39631548e-09], dtype=float32)
#
# loglikelihood=Array(1865.3102, dtype=float32)
# theta=array([1.0005338 , 1.00053358, 1.10000027])
# step_size * gradient_step=array([1.36835815e-05, 1.36778544e-05, 6.39640430e-09], dtype=float32)
#
# loglikelihood=Array(1963.1587, dtype=float32)
# theta=array([1.00054749, 1.00054726, 1.10000028])
# step_size * gradient_step=array([1.36835815e-05, 1.36778544e-05, 6.39649178e-09], dtype=float32)
#
# loglikelihood=Array(2053.3198, dtype=float32)
# theta=array([1.00056118, 1.00056095, 1.10000029])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39658104e-09], dtype=float32)
#
# loglikelihood=Array(2160.356, dtype=float32)
# theta=array([1.00057488, 1.00057463, 1.1000003 ])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39666942e-09], dtype=float32)
#
# loglikelihood=Array(2262.3296, dtype=float32)
# theta=array([1.00058857, 1.00058832, 1.1000003 ])
# step_size * gradient_step=array([1.36835815e-05, 1.36778535e-05, 6.39675646e-09], dtype=float32)
# loglikelihood=Array(2387.8657, dtype=float32)
# theta=array([1.00060226, 1.00060201, 1.10000031])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39684528e-09], dtype=float32)
#
# loglikelihood=Array(2487.6519, dtype=float32)
# theta=array([1.00061595, 1.00061569, 1.10000032])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39693321e-09], dtype=float32)
#
# loglikelihood=Array(2550.4377, dtype=float32)
# theta=array([1.00062964, 1.00062938, 1.10000032])
# step_size * gradient_step=array([1.36835815e-05, 1.36778535e-05, 6.39702202e-09], dtype=float32)
#
# loglikelihood=Array(2644.1616, dtype=float32)
# theta=array([1.00064334, 1.00064307, 1.10000033])
# step_size * gradient_step=array([1.36835815e-05, 1.36778535e-05, 6.39710951e-09], dtype=float32)
#
# loglikelihood=Array(2723.8853, dtype=float32)
# theta=array([1.00065703, 1.00065675, 1.10000034])
# step_size * gradient_step=array([1.36835815e-05, 1.36778526e-05, 6.39719699e-09], dtype=float32)
#
# loglikelihood=Array(2823.9214, dtype=float32)
# theta=array([1.00067072, 1.00067044, 1.10000034])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3972858e-09], dtype=float32)
#
# loglikelihood=Array(2930.77, dtype=float32)
# theta=array([1.00068441, 1.00068413, 1.10000035])
# step_size * gradient_step=array([1.36835815e-05, 1.36778535e-05, 6.39737374e-09], dtype=float32)
#
# loglikelihood=Array(3037.4937, dtype=float32)
# theta=array([1.00069811, 1.00069781, 1.10000036])
# step_size * gradient_step=array([1.36835815e-05, 1.36778535e-05, 6.39746212e-09], dtype=float32)
#
# loglikelihood=Array(3124.9045, dtype=float32)
# theta=array([1.0007118 , 1.0007115 , 1.10000037])
# step_size * gradient_step=array([1.36835815e-05, 1.36778526e-05, 6.39755049e-09], dtype=float32)
#
# loglikelihood=Array(3224.0654, dtype=float32)
# theta=array([1.00072549, 1.00072519, 1.10000037])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3976389e-09], dtype=float32)
#
# loglikelihood=Array(3298.6643, dtype=float32)
# theta=array([1.00073919, 1.00073888, 1.10000038])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3977259e-09], dtype=float32)
#
# loglikelihood=Array(3409.2004, dtype=float32)
# theta=array([1.00075288, 1.00075256, 1.10000039])
# step_size * gradient_step=array([1.36835815e-05, 1.36778526e-05, 6.39781472e-09], dtype=float32)
#
# loglikelihood=Array(3510.9863, dtype=float32)
# theta=array([1.00076657, 1.00076625, 1.10000039])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39790354e-09], dtype=float32)
#
# loglikelihood=Array(3591.085, dtype=float32)
# theta=array([1.00078027, 1.00077994, 1.1000004 ])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.3979915e-09], dtype=float32)
#
# loglikelihood=Array(3689.996, dtype=float32)
# theta=array([1.00079396, 1.00079363, 1.10000041])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.3980798e-09], dtype=float32)
#
# loglikelihood=Array(3789.7822, dtype=float32)
# theta=array([1.00080766, 1.00080732, 1.10000042])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3981669e-09], dtype=float32)
#
# loglikelihood=Array(3902.5684, dtype=float32)
# theta=array([1.00082135, 1.00082101, 1.10000042])
# step_size * gradient_step=array([1.36835815e-05, 1.36778526e-05, 6.39825615e-09], dtype=float32)
#
# loglikelihood=Array(3991.1045, dtype=float32)
# theta=array([1.00083505, 1.0008347 , 1.10000043])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39834496e-09], dtype=float32)
#
# loglikelihood=Array(4108.0156, dtype=float32)
# theta=array([1.00084874, 1.00084839, 1.10000044])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39843334e-09], dtype=float32)
#
# loglikelihood=Array(4255.3643, dtype=float32)
# theta=array([1.00086244, 1.00086208, 1.10000044])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39852127e-09], dtype=float32)
#
# loglikelihood=Array(4349.713, dtype=float32)
# theta=array([1.00087613, 1.00087577, 1.10000045])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39861009e-09], dtype=float32)
#
# loglikelihood=Array(4444.124, dtype=float32)
# theta=array([1.00088983, 1.00088946, 1.10000046])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.3986962e-09], dtype=float32)
#
# loglikelihood=Array(4530.9727, dtype=float32)
# theta=array([1.00090352, 1.00090315, 1.10000046])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39878506e-09], dtype=float32)
#
# loglikelihood=Array(4606.509, dtype=float32)
# theta=array([1.00091722, 1.00091684, 1.10000047])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3988734e-09], dtype=float32)
#
# loglikelihood=Array(4701.795, dtype=float32)
# theta=array([1.00093092, 1.00093053, 1.10000048])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3989618e-09], dtype=float32)
#
# loglikelihood=Array(4817.8936, dtype=float32)
# theta=array([1.00094461, 1.00094422, 1.10000049])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3990502e-09], dtype=float32)
#
# loglikelihood=Array(4942.1167, dtype=float32)
# theta=array([1.00095831, 1.00095791, 1.10000049])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3991386e-09], dtype=float32)
#
# loglikelihood=Array(5026.3403, dtype=float32)
# theta=array([1.00097201, 1.0009716 , 1.1000005 ])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3992265e-09], dtype=float32)
#
# loglikelihood=Array(5139.064, dtype=float32)
# theta=array([1.0009857 , 1.00098529, 1.10000051])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39931441e-09], dtype=float32)
#
# loglikelihood=Array(5239.5376, dtype=float32)
# theta=array([1.0009994 , 1.00099898, 1.10000051])
# step_size * gradient_step=array([1.36835824e-05, 1.36778535e-05, 6.39940279e-09], dtype=float32)
#
# loglikelihood=Array(5355.8237, dtype=float32)
# theta=array([1.0010131 , 1.00101267, 1.10000052])
# step_size * gradient_step=array([1.3683583e-05, 1.3677853e-05, 6.3994916e-09], dtype=float32)
#
# loglikelihood=Array(5453.9224, dtype=float32)
# theta=array([1.0010268 , 1.00102637, 1.10000053])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3995791e-09], dtype=float32)
#
# loglikelihood=Array(5545.4585, dtype=float32)
# theta=array([1.00104049, 1.00104006, 1.10000053])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.3996684e-09], dtype=float32)
#
# loglikelihood=Array(5620.744, dtype=float32)
# theta=array([1.00105419, 1.00105375, 1.10000054])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.3997563e-09], dtype=float32)
#
# loglikelihood=Array(5721.656, dtype=float32)
# theta=array([1.00106789, 1.00106744, 1.10000055])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3998438e-09], dtype=float32)
#
# loglikelihood=Array(5824.0664, dtype=float32)
# theta=array([1.00108159, 1.00108113, 1.10000056])
# step_size * gradient_step=array([1.3683582e-05, 1.3677853e-05, 6.3999326e-09], dtype=float32)
#
# loglikelihood=Array(5912.4155, dtype=float32)
# theta=array([1.00109529, 1.00109483, 1.10000056])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4000196e-09], dtype=float32)
#
# loglikelihood=Array(6027.639, dtype=float32)
# theta=array([1.00110898, 1.00110852, 1.10000057])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4001084e-09], dtype=float32)
#
# loglikelihood=Array(6155.5503, dtype=float32)
# theta=array([1.00112268, 1.00112221, 1.10000058])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4001959e-09], dtype=float32)
#
# loglikelihood=Array(6277.461, dtype=float32)
# theta=array([1.00113638, 1.00113591, 1.10000058])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4002852e-09], dtype=float32)
#
# loglikelihood=Array(6373.497, dtype=float32)
# theta=array([1.00115008, 1.0011496 , 1.10000059])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4003731e-09], dtype=float32)
#
# loglikelihood=Array(6460.9707, dtype=float32)
# theta=array([1.00116378, 1.00116329, 1.1000006 ])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4004615e-09], dtype=float32)
#
# loglikelihood=Array(6534.757, dtype=float32)
# theta=array([1.00117748, 1.00117699, 1.10000061])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4005490e-09], dtype=float32)
# loglikelihood=Array(6641.668, dtype=float32)
# theta=array([1.00119118, 1.00119068, 1.10000061])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4006374e-09], dtype=float32)
#
# loglikelihood=Array(6720.3916, dtype=float32)
# theta=array([1.00120488, 1.00120438, 1.10000062])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4007262e-09], dtype=float32)
#
# loglikelihood=Array(6836.115, dtype=float32)
# theta=array([1.00121858, 1.00121807, 1.10000063])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4008145e-09], dtype=float32)
#
# loglikelihood=Array(6912.0264, dtype=float32)
# theta=array([1.00123228, 1.00123176, 1.10000063])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4009025e-09], dtype=float32)
#
# loglikelihood=Array(7022.375, dtype=float32)
# theta=array([1.00124598, 1.00124546, 1.10000064])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4009913e-09], dtype=float32)
#
# loglikelihood=Array(7128.4736, dtype=float32)
# theta=array([1.00125968, 1.00125915, 1.10000065])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4010792e-09], dtype=float32)
#
# loglikelihood=Array(7221.447, dtype=float32)
# theta=array([1.00127338, 1.00127285, 1.10000065])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4011694e-09], dtype=float32)
#
# loglikelihood=Array(7320.3584, dtype=float32)
# theta=array([1.00128708, 1.00128655, 1.10000066])
# step_size * gradient_step=array([1.3683582e-05, 1.3677852e-05, 6.4012555e-09], dtype=float32)
#
# loglikelihood=Array(7391.769, dtype=float32)
# theta=array([1.00130079, 1.00130024, 1.10000067])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4013457e-09], dtype=float32)
#
# loglikelihood=Array(7480.93, dtype=float32)
# theta=array([1.00131449, 1.00131394, 1.10000068])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4014336e-09], dtype=float32)
#
# loglikelihood=Array(7566.529, dtype=float32)
# theta=array([1.00132819, 1.00132763, 1.10000068])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4015220e-09], dtype=float32)
#
# loglikelihood=Array(7682.1274, dtype=float32)
# theta=array([1.00134189, 1.00134133, 1.10000069])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4016099e-09], dtype=float32)
#
# loglikelihood=Array(7762.476, dtype=float32)
# theta=array([1.00135559, 1.00135502, 1.1000007 ])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4016983e-09], dtype=float32)
#
# loglikelihood=Array(7898.0747, dtype=float32)
# theta=array([1.00136929, 1.00136872, 1.1000007 ])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4017867e-09], dtype=float32)
#
# loglikelihood=Array(7991.236, dtype=float32)
# theta=array([1.001383  , 1.00138242, 1.10000071])
# step_size * gradient_step=array([1.3683586e-05, 1.3677854e-05, 6.4018750e-09], dtype=float32)
#
# loglikelihood=Array(8077.6465, dtype=float32)
# theta=array([1.0013967 , 1.00139611, 1.10000072])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40196340e-09], dtype=float32)
#
# loglikelihood=Array(8182.683, dtype=float32)
# theta=array([1.0014104 , 1.00140981, 1.10000072])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40205089e-09], dtype=float32)
#
# loglikelihood=Array(8291.594, dtype=float32)
# theta=array([1.00142411, 1.00142351, 1.10000073])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40213971e-09], dtype=float32)
#
# loglikelihood=Array(8392.13, dtype=float32)
# theta=array([1.00143781, 1.00143721, 1.10000074])
# step_size * gradient_step=array([1.3683588e-05, 1.3677856e-05, 6.4022294e-09], dtype=float32)
#
# loglikelihood=Array(8498.854, dtype=float32)
# theta=array([1.00145151, 1.0014509 , 1.10000075])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40231645e-09], dtype=float32)
#
# loglikelihood=Array(8581.702, dtype=float32)
# theta=array([1.00146522, 1.0014646 , 1.10000075])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40240483e-09], dtype=float32)
#
# loglikelihood=Array(8694.051, dtype=float32)
# theta=array([1.00147892, 1.0014783 , 1.10000076])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4024945e-09], dtype=float32)
#
# loglikelihood=Array(8820.087, dtype=float32)
# theta=array([1.00149262, 1.001492  , 1.10000077])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40258113e-09], dtype=float32)
#
# loglikelihood=Array(8943.623, dtype=float32)
# theta=array([1.00150633, 1.0015057 , 1.10000077])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40266995e-09], dtype=float32)
#
# loglikelihood=Array(9024.659, dtype=float32)
# theta=array([1.00152003, 1.00151939, 1.10000078])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40275788e-09], dtype=float32)
#
# loglikelihood=Array(9145.32, dtype=float32)
# theta=array([1.00153374, 1.00153309, 1.10000079])
# step_size * gradient_step=array([1.36835861e-05, 1.36778535e-05, 6.40284670e-09], dtype=float32)
#
# loglikelihood=Array(9240.169, dtype=float32)
# theta=array([1.00154744, 1.00154679, 1.1000008 ])
# step_size * gradient_step=array([1.3683588e-05, 1.3677855e-05, 6.4029355e-09], dtype=float32)
#
# loglikelihood=Array(9336.58, dtype=float32)
# theta=array([1.00156115, 1.00156049, 1.1000008 ])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4030226e-09], dtype=float32)
#
# loglikelihood=Array(9428.554, dtype=float32)
# theta=array([1.00157485, 1.00157419, 1.10000081])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4031109e-09], dtype=float32)
#
# loglikelihood=Array(9533.652, dtype=float32)
# theta=array([1.00158856, 1.00158789, 1.10000082])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4031993e-09], dtype=float32)
#
# loglikelihood=Array(9598.251, dtype=float32)
# theta=array([1.00160226, 1.00160159, 1.10000082])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4032872e-09], dtype=float32)
#
# loglikelihood=Array(9707.787, dtype=float32)
# theta=array([1.00161597, 1.00161529, 1.10000083])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4033761e-09], dtype=float32)
#
# loglikelihood=Array(9847.822, dtype=float32)
# theta=array([1.00162967, 1.00162899, 1.10000084])
# step_size * gradient_step=array([1.3683588e-05, 1.3677855e-05, 6.4034644e-09], dtype=float32)
#
# loglikelihood=Array(9951.109, dtype=float32)
# theta=array([1.00164338, 1.00164269, 1.10000084])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4035528e-09], dtype=float32)
#
# loglikelihood=Array(10054.52, dtype=float32)
# theta=array([1.00165708, 1.00165639, 1.10000085])
# step_size * gradient_step=array([1.3683589e-05, 1.3677854e-05, 6.4036407e-09], dtype=float32)
#
# loglikelihood=Array(10162.681, dtype=float32)
# theta=array([1.00167079, 1.00167009, 1.10000086])
# step_size * gradient_step=array([1.3683589e-05, 1.3677854e-05, 6.4037295e-09], dtype=float32)
#
# loglikelihood=Array(10270.529, dtype=float32)
# theta=array([1.0016845 , 1.00168379, 1.10000087])
# step_size * gradient_step=array([1.3683589e-05, 1.3677855e-05, 6.4038175e-09], dtype=float32)
#
# loglikelihood=Array(10348.19, dtype=float32)
# theta=array([1.0016982 , 1.00169749, 1.10000087])
# step_size * gradient_step=array([1.3683588e-05, 1.3677855e-05, 6.4039063e-09], dtype=float32)
#
# loglikelihood=Array(10453.914, dtype=float32)
# theta=array([1.00171191, 1.00171119, 1.10000088])
# step_size * gradient_step=array([1.3683589e-05, 1.3677854e-05, 6.4039938e-09], dtype=float32)
#
# loglikelihood=Array(10521.263, dtype=float32)
# theta=array([1.00172562, 1.0017249 , 1.10000089])
# step_size * gradient_step=array([1.3683589e-05, 1.3677854e-05, 6.4040830e-09], dtype=float32)
#
# loglikelihood=Array(10639.424, dtype=float32)
# theta=array([1.00173933, 1.0017386 , 1.10000089])
# step_size * gradient_step=array([1.3683589e-05, 1.3677854e-05, 6.4041705e-09], dtype=float32)
#
# loglikelihood=Array(10765.272, dtype=float32)
# theta=array([1.00175303, 1.0017523 , 1.1000009 ])
# step_size * gradient_step=array([1.3683588e-05, 1.3677854e-05, 6.4042589e-09], dtype=float32)
#
# loglikelihood=Array(10857.434, dtype=float32)
# theta=array([1.00176674, 1.001766  , 1.10000091])
# step_size * gradient_step=array([1.3683588e-05, 1.3677854e-05, 6.4043468e-09], dtype=float32)
# loglikelihood=Array(10950.72, dtype=float32)
# theta=array([1.00178045, 1.0017797 , 1.10000092])
# step_size * gradient_step=array([1.3683588e-05, 1.3677854e-05, 6.4044356e-09], dtype=float32)
#
# loglikelihood=Array(11039.068, dtype=float32)
# theta=array([1.00179416, 1.0017934 , 1.10000092])
# step_size * gradient_step=array([1.3683589e-05, 1.3677854e-05, 6.4045236e-09], dtype=float32)
#
# loglikelihood=Array(11133.1045, dtype=float32)
# theta=array([1.00180787, 1.00180711, 1.10000093])
# step_size * gradient_step=array([1.36835888e-05, 1.36778535e-05, 6.40461240e-09], dtype=float32)
#
# loglikelihood=Array(11225.141, dtype=float32)
# theta=array([1.00182157, 1.00182081, 1.10000094])
# step_size * gradient_step=array([1.3683588e-05, 1.3677854e-05, 6.4047003e-09], dtype=float32)
#
# loglikelihood=Array(11324.552, dtype=float32)
# theta=array([1.00183528, 1.00183451, 1.10000094])
# step_size * gradient_step=array([1.3683588e-05, 1.3677854e-05, 6.4047891e-09], dtype=float32)
#
# loglikelihood=Array(11402.838, dtype=float32)
# theta=array([1.00184899, 1.00184822, 1.10000095])
# step_size * gradient_step=array([1.36835888e-05, 1.36778535e-05, 6.40487663e-09], dtype=float32)
#
# loglikelihood=Array(11472.624, dtype=float32)
# theta=array([1.0018627 , 1.00186192, 1.10000096])
# step_size * gradient_step=array([1.36835888e-05, 1.36778535e-05, 6.40496545e-09], dtype=float32)
#
# loglikelihood=Array(11580.723, dtype=float32)
# theta=array([1.00187641, 1.00187562, 1.10000096])
# step_size * gradient_step=array([1.36835879e-05, 1.36778535e-05, 6.40505382e-09], dtype=float32)
#
# loglikelihood=Array(11713.133, dtype=float32)
# theta=array([1.00189012, 1.00188933, 1.10000097])
# step_size * gradient_step=array([1.36835888e-05, 1.36778535e-05, 6.40514219e-09], dtype=float32)
#
# loglikelihood=Array(11812.794, dtype=float32)
# theta=array([1.00190383, 1.00190303, 1.10000098])
# step_size * gradient_step=array([1.36835888e-05, 1.36778535e-05, 6.40523012e-09], dtype=float32)
#
# loglikelihood=Array(11918.705, dtype=float32)
# theta=array([1.00191754, 1.00191673, 1.10000099])
# step_size * gradient_step=array([1.36835879e-05, 1.36778535e-05, 6.40531850e-09], dtype=float32)
#
# loglikelihood=Array(12041.241, dtype=float32)
# theta=array([1.00193125, 1.00193044, 1.10000099])
# step_size * gradient_step=array([1.36835879e-05, 1.36778535e-05, 6.40540776e-09], dtype=float32)
#
# loglikelihood=Array(12138.465, dtype=float32)
# theta=array([1.00194496, 1.00194414, 1.100001  ])
# step_size * gradient_step=array([1.36835888e-05, 1.36778535e-05, 6.40549569e-09], dtype=float32)
#
# loglikelihood=Array(12248.626, dtype=float32)
# theta=array([1.00195867, 1.00195785, 1.10000101])
# step_size * gradient_step=array([1.3683590e-05, 1.3677854e-05, 6.4055850e-09], dtype=float32)
#
# loglikelihood=Array(12353.037, dtype=float32)
# theta=array([1.00197238, 1.00197155, 1.10000101])
# step_size * gradient_step=array([1.36835879e-05, 1.36778535e-05, 6.40567199e-09], dtype=float32)
#
# loglikelihood=Array(12454.261, dtype=float32)
# theta=array([1.00198609, 1.00198526, 1.10000102])
# step_size * gradient_step=array([1.3683589e-05, 1.3677853e-05, 6.4057608e-09], dtype=float32)
#
# loglikelihood=Array(12544.234, dtype=float32)
# theta=array([1.0019998 , 1.00199896, 1.10000103])
# step_size * gradient_step=array([1.3683590e-05, 1.3677854e-05, 6.4058496e-09], dtype=float32)
#
# loglikelihood=Array(12641.5205, dtype=float32)
# theta=array([1.00201351, 1.00201267, 1.10000103])
# step_size * gradient_step=array([1.3683589e-05, 1.3677853e-05, 6.4059376e-09], dtype=float32)
#
# loglikelihood=Array(12745.182, dtype=float32)
# theta=array([1.00202722, 1.00202637, 1.10000104])
# step_size * gradient_step=array([1.3683589e-05, 1.3677853e-05, 6.4060242e-09], dtype=float32)
#
# loglikelihood=Array(12849.155, dtype=float32)
# theta=array([1.00204093, 1.00204008, 1.10000105])
# step_size * gradient_step=array([1.3683590e-05, 1.3677854e-05, 6.4061130e-09], dtype=float32)
#
# loglikelihood=Array(12974.066, dtype=float32)
# theta=array([1.00205465, 1.00205378, 1.10000106])
# step_size * gradient_step=array([1.36835906e-05, 1.36778535e-05, 6.40620179e-09], dtype=float32)
#
# loglikelihood=Array(13070.603, dtype=float32)
# theta=array([1.00206836, 1.00206749, 1.10000106])
# step_size * gradient_step=array([1.3683590e-05, 1.3677854e-05, 6.4062893e-09], dtype=float32)
#
# loglikelihood=Array(13199.014, dtype=float32)
# theta=array([1.00208207, 1.0020812 , 1.10000107])
# step_size * gradient_step=array([1.3683590e-05, 1.3677854e-05, 6.4063781e-09], dtype=float32)
#
# loglikelihood=Array(13284.862, dtype=float32)
# theta=array([1.00209578, 1.0020949 , 1.10000108])
# step_size * gradient_step=array([1.3683589e-05, 1.3677853e-05, 6.4064665e-09], dtype=float32)
#
# loglikelihood=Array(13365.898, dtype=float32)
# theta=array([1.00210949, 1.00210861, 1.10000108])
# step_size * gradient_step=array([1.3683590e-05, 1.3677854e-05, 6.4065548e-09], dtype=float32)
#
# loglikelihood=Array(13481.496, dtype=float32)
# theta=array([1.00212321, 1.00212232, 1.10000109])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40664366e-09], dtype=float32)
#
# loglikelihood=Array(13602.72, dtype=float32)
# theta=array([1.00213692, 1.00213602, 1.1000011 ])
# step_size * gradient_step=array([1.3683589e-05, 1.3677853e-05, 6.4067307e-09], dtype=float32)
#
# loglikelihood=Array(13723.131, dtype=float32)
# theta=array([1.00215063, 1.00214973, 1.10000111])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40682041e-09], dtype=float32)
#
# loglikelihood=Array(13823.042, dtype=float32)
# theta=array([1.00216435, 1.00216344, 1.10000111])
# step_size * gradient_step=array([1.36835906e-05, 1.36778535e-05, 6.40690834e-09], dtype=float32)
#
# loglikelihood=Array(13928.078, dtype=float32)
# theta=array([1.00217806, 1.00217715, 1.10000112])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40699671e-09], dtype=float32)
#
# loglikelihood=Array(14021.177, dtype=float32)
# theta=array([1.00219177, 1.00219085, 1.10000113])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40708553e-09], dtype=float32)
#
# loglikelihood=Array(14145.963, dtype=float32)
# theta=array([1.00220549, 1.00220456, 1.10000113])
# step_size * gradient_step=array([1.36835906e-05, 1.36778535e-05, 6.40717346e-09], dtype=float32)
#
# loglikelihood=Array(14258.124, dtype=float32)
# theta=array([1.0022192 , 1.00221827, 1.10000114])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40726183e-09], dtype=float32)
#
# loglikelihood=Array(14343.848, dtype=float32)
# theta=array([1.00223291, 1.00223198, 1.10000115])
# step_size * gradient_step=array([1.3683591e-05, 1.3677853e-05, 6.4073502e-09], dtype=float32)
#
# loglikelihood=Array(14425.884, dtype=float32)
# theta=array([1.00224663, 1.00224569, 1.10000115])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40743858e-09], dtype=float32)
#
# loglikelihood=Array(14538.857, dtype=float32)
# theta=array([1.00226034, 1.00225939, 1.10000116])
# step_size * gradient_step=array([1.3683592e-05, 1.3677855e-05, 6.4075287e-09], dtype=float32)
#
# loglikelihood=Array(14621.331, dtype=float32)
# theta=array([1.00227406, 1.0022731 , 1.10000117])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40761444e-09], dtype=float32)
#
# loglikelihood=Array(14733.492, dtype=float32)
# theta=array([1.00228777, 1.00228681, 1.10000118])
# step_size * gradient_step=array([1.3683592e-05, 1.3677855e-05, 6.4077041e-09], dtype=float32)
#
# loglikelihood=Array(14832.402, dtype=float32)
# theta=array([1.00230149, 1.00230052, 1.10000118])
# step_size * gradient_step=array([1.36835897e-05, 1.36778535e-05, 6.40779207e-09], dtype=float32)
#
# loglikelihood=Array(14891.688, dtype=float32)
# theta=array([1.0023152 , 1.00231423, 1.10000119])
# step_size * gradient_step=array([1.3683592e-05, 1.3677855e-05, 6.4078809e-09], dtype=float32)
#
# loglikelihood=Array(14992.225, dtype=float32)
# theta=array([1.00232892, 1.00232794, 1.1000012 ])
# step_size * gradient_step=array([1.3683593e-05, 1.3677854e-05, 6.4079697e-09], dtype=float32)
#
# loglikelihood=Array(15085.636, dtype=float32)
# theta=array([1.00234263, 1.00234165, 1.1000012 ])
# step_size * gradient_step=array([1.3683592e-05, 1.3677855e-05, 6.4080576e-09], dtype=float32)
#
# loglikelihood=Array(15185.984, dtype=float32)
# theta=array([1.00235635, 1.00235536, 1.10000121])
# step_size * gradient_step=array([1.3683593e-05, 1.3677854e-05, 6.4081465e-09], dtype=float32)
# loglikelihood=Array(15257.2705, dtype=float32)
# theta=array([1.00237006, 1.00236907, 1.10000122])
# step_size * gradient_step=array([1.3683592e-05, 1.3677855e-05, 6.4082344e-09], dtype=float32)
#
# loglikelihood=Array(15367.494, dtype=float32)
# theta=array([1.00238378, 1.00238278, 1.10000123])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4083228e-09], dtype=float32)
#
# loglikelihood=Array(15463.343, dtype=float32)
# theta=array([1.0023975 , 1.00239649, 1.10000123])
# step_size * gradient_step=array([1.3683592e-05, 1.3677855e-05, 6.4084111e-09], dtype=float32)
#
# loglikelihood=Array(15564.066, dtype=float32)
# theta=array([1.00241121, 1.0024102 , 1.10000124])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4085000e-09], dtype=float32)
#
# loglikelihood=Array(15663.04, dtype=float32)
# theta=array([1.00242493, 1.00242391, 1.10000125])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4085879e-09], dtype=float32)
#
# loglikelihood=Array(15764.701, dtype=float32)
# theta=array([1.00243865, 1.00243762, 1.10000125])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4086763e-09], dtype=float32)
#
# loglikelihood=Array(15899.924, dtype=float32)
# theta=array([1.00245236, 1.00245134, 1.10000126])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4087646e-09], dtype=float32)
#
# loglikelihood=Array(16013.086, dtype=float32)
# theta=array([1.00246608, 1.00246505, 1.10000127])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4088534e-09], dtype=float32)
#
# loglikelihood=Array(16091.684, dtype=float32)
# theta=array([1.0024798 , 1.00247876, 1.10000127])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4089418e-09], dtype=float32)
#
# loglikelihood=Array(16206.783, dtype=float32)
# theta=array([1.00249352, 1.00249247, 1.10000128])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40902931e-09], dtype=float32)
#
# loglikelihood=Array(16301.943, dtype=float32)
# theta=array([1.00250723, 1.00250618, 1.10000129])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4091181e-09], dtype=float32)
#
# loglikelihood=Array(16396.918, dtype=float32)
# theta=array([1.00252095, 1.00251989, 1.1000013 ])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40920605e-09], dtype=float32)
#
# loglikelihood=Array(16502.703, dtype=float32)
# theta=array([1.00253467, 1.00253361, 1.1000013 ])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4092949e-09], dtype=float32)
#
# loglikelihood=Array(16600.303, dtype=float32)
# theta=array([1.00254839, 1.00254732, 1.10000131])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4093828e-09], dtype=float32)
#
# loglikelihood=Array(16705.275, dtype=float32)
# theta=array([1.00256211, 1.00256103, 1.10000132])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40947162e-09], dtype=float32)
#
# loglikelihood=Array(16794.188, dtype=float32)
# theta=array([1.00257583, 1.00257475, 1.10000132])
# step_size * gradient_step=array([1.3683592e-05, 1.3677854e-05, 6.4095595e-09], dtype=float32)
#
# loglikelihood=Array(16870.035, dtype=float32)
# theta=array([1.00258954, 1.00258846, 1.10000133])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40964881e-09], dtype=float32)
#
# loglikelihood=Array(16989.57, dtype=float32)
# theta=array([1.00260326, 1.00260217, 1.10000134])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40973719e-09], dtype=float32)
#
# loglikelihood=Array(17084.107, dtype=float32)
# theta=array([1.00261698, 1.00261589, 1.10000134])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40982600e-09], dtype=float32)
#
# loglikelihood=Array(17201.08, dtype=float32)
# theta=array([1.0026307 , 1.0026296 , 1.10000135])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.40991393e-09], dtype=float32)
#
# loglikelihood=Array(17268.742, dtype=float32)
# theta=array([1.00264442, 1.00264331, 1.10000136])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.41000275e-09], dtype=float32)
#
# loglikelihood=Array(17417.152, dtype=float32)
# theta=array([1.00265814, 1.00265703, 1.10000137])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4100920e-09], dtype=float32)
#
# loglikelihood=Array(17521.877, dtype=float32)
# theta=array([1.00267186, 1.00267074, 1.10000137])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.41017950e-09], dtype=float32)
#
# loglikelihood=Array(17615.162, dtype=float32)
# theta=array([1.00268558, 1.00268446, 1.10000138])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4102688e-09], dtype=float32)
#
# loglikelihood=Array(17734.95, dtype=float32)
# theta=array([1.0026993 , 1.00269817, 1.10000139])
# step_size * gradient_step=array([1.3683595e-05, 1.3677855e-05, 6.4103576e-09], dtype=float32)
#
# loglikelihood=Array(17820.734, dtype=float32)
# theta=array([1.00271302, 1.00271189, 1.10000139])
# step_size * gradient_step=array([1.36835924e-05, 1.36778535e-05, 6.41044373e-09], dtype=float32)
#
# loglikelihood=Array(17942.145, dtype=float32)
# theta=array([1.00272674, 1.0027256 , 1.1000014 ])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4105343e-09], dtype=float32)
#
# loglikelihood=Array(18027.432, dtype=float32)
# theta=array([1.00274047, 1.00273932, 1.10000141])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4106209e-09], dtype=float32)
#
# loglikelihood=Array(18141.469, dtype=float32)
# theta=array([1.00275419, 1.00275303, 1.10000142])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4107093e-09], dtype=float32)
#
# loglikelihood=Array(18247.504, dtype=float32)
# theta=array([1.00276791, 1.00276675, 1.10000142])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4107977e-09], dtype=float32)
#
# loglikelihood=Array(18335.164, dtype=float32)
# theta=array([1.00278163, 1.00278046, 1.10000143])
# step_size * gradient_step=array([1.3683595e-05, 1.3677855e-05, 6.4108860e-09], dtype=float32)
#
# loglikelihood=Array(18441.826, dtype=float32)
# theta=array([1.00279535, 1.00279418, 1.10000144])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4109749e-09], dtype=float32)
#
# loglikelihood=Array(18528.924, dtype=float32)
# theta=array([1.00280907, 1.00280789, 1.10000144])
# step_size * gradient_step=array([1.3683596e-05, 1.3677855e-05, 6.4110628e-09], dtype=float32)
#
# loglikelihood=Array(18634.023, dtype=float32)
# theta=array([1.0028228 , 1.00282161, 1.10000145])
# step_size * gradient_step=array([1.3683595e-05, 1.3677855e-05, 6.4111512e-09], dtype=float32)
#
# loglikelihood=Array(18710.621, dtype=float32)
# theta=array([1.00283652, 1.00283533, 1.10000146])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4112395e-09], dtype=float32)
#
# loglikelihood=Array(18815.346, dtype=float32)
# theta=array([1.00285024, 1.00284904, 1.10000146])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4113279e-09], dtype=float32)
#
# loglikelihood=Array(18915.256, dtype=float32)
# theta=array([1.00286396, 1.00286276, 1.10000147])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4114172e-09], dtype=float32)
#
# loglikelihood=Array(18995.105, dtype=float32)
# theta=array([1.00287769, 1.00287648, 1.10000148])
# step_size * gradient_step=array([1.3683595e-05, 1.3677855e-05, 6.4115051e-09], dtype=float32)
#
# loglikelihood=Array(19085.39, dtype=float32)
# theta=array([1.00289141, 1.0028902 , 1.10000149])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4115939e-09], dtype=float32)
#
# loglikelihood=Array(19190.676, dtype=float32)
# theta=array([1.00290513, 1.00290391, 1.10000149])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4116819e-09], dtype=float32)
#
# loglikelihood=Array(19301.9, dtype=float32)
# theta=array([1.00291886, 1.00291763, 1.1000015 ])
# step_size * gradient_step=array([1.3683595e-05, 1.3677854e-05, 6.4117702e-09], dtype=float32)
#
# loglikelihood=Array(19391.873, dtype=float32)
# theta=array([1.00293258, 1.00293135, 1.10000151])
# step_size * gradient_step=array([1.36835961e-05, 1.36778535e-05, 6.41185904e-09], dtype=float32)
#
# loglikelihood=Array(19494.91, dtype=float32)
# theta=array([1.0029463 , 1.00294507, 1.10000151])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4119474e-09], dtype=float32)
# loglikelihood=Array(19593.32, dtype=float32)
# theta=array([1.00296003, 1.00295878, 1.10000152])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4120353e-09], dtype=float32)
#
# loglikelihood=Array(19682.107, dtype=float32)
# theta=array([1.00297375, 1.0029725 , 1.10000153])
# step_size * gradient_step=array([1.3683595e-05, 1.3677854e-05, 6.4121233e-09], dtype=float32)
#
# loglikelihood=Array(19773.08, dtype=float32)
# theta=array([1.00298748, 1.00298622, 1.10000154])
# step_size * gradient_step=array([1.3683597e-05, 1.3677855e-05, 6.4122134e-09], dtype=float32)
#
# loglikelihood=Array(19862.867, dtype=float32)
# theta=array([1.0030012 , 1.00299994, 1.10000154])
# step_size * gradient_step=array([1.36835961e-05, 1.36778535e-05, 6.41230047e-09], dtype=float32)
#
# loglikelihood=Array(19979.902, dtype=float32)
# theta=array([1.00301492, 1.00301366, 1.10000155])
# step_size * gradient_step=array([1.3683596e-05, 1.3677854e-05, 6.4123888e-09], dtype=float32)
#
# loglikelihood=Array(20069.377, dtype=float32)
# theta=array([1.00302865, 1.00302738, 1.10000156])
# step_size * gradient_step=array([1.3683597e-05, 1.3677855e-05, 6.4124772e-09], dtype=float32)
#
# loglikelihood=Array(20189.1, dtype=float32)
# theta=array([1.00304237, 1.0030411 , 1.10000156])
# step_size * gradient_step=array([1.3683597e-05, 1.3677855e-05, 6.4125665e-09], dtype=float32)
#
# loglikelihood=Array(20300.635, dtype=float32)
# theta=array([1.0030561 , 1.00305482, 1.10000157])
# step_size * gradient_step=array([1.36835961e-05, 1.36778535e-05, 6.41265485e-09], dtype=float32)
#
# loglikelihood=Array(20412.984, dtype=float32)
# theta=array([1.00306983, 1.00306854, 1.10000158])
# step_size * gradient_step=array([1.36835961e-05, 1.36778535e-05, 6.41274323e-09], dtype=float32)
#
# loglikelihood=Array(20519.895, dtype=float32)
# theta=array([1.00308355, 1.00308226, 1.10000158])
# step_size * gradient_step=array([1.36835961e-05, 1.36778535e-05, 6.41283115e-09], dtype=float32)
#
# loglikelihood=Array(20619.807, dtype=float32)
# theta=array([1.00309728, 1.00309598, 1.10000159])
# step_size * gradient_step=array([1.3683597e-05, 1.3677854e-05, 6.4129204e-09], dtype=float32)
#
# loglikelihood=Array(20711.592, dtype=float32)
# theta=array([1.003111 , 1.0031097, 1.1000016])
# step_size * gradient_step=array([1.3683597e-05, 1.3677854e-05, 6.4130088e-09], dtype=float32)
#
# loglikelihood=Array(20791.379, dtype=float32)
# theta=array([1.00312473, 1.00312342, 1.10000161])
# step_size * gradient_step=array([1.3683598e-05, 1.3677854e-05, 6.4130976e-09], dtype=float32)
#
# loglikelihood=Array(20884.602, dtype=float32)
# theta=array([1.00313846, 1.00313714, 1.10000161])
# step_size * gradient_step=array([1.36835961e-05, 1.36778535e-05, 6.41318465e-09], dtype=float32)
#
# loglikelihood=Array(21005.576, dtype=float32)
# theta=array([1.00315218, 1.00315086, 1.10000162])
# step_size * gradient_step=array([1.3683597e-05, 1.3677855e-05, 6.4132744e-09], dtype=float32)
#
# loglikelihood=Array(21110.299, dtype=float32)
# theta=array([1.00316591, 1.00316458, 1.10000163])
# step_size * gradient_step=array([1.3683597e-05, 1.3677854e-05, 6.4133618e-09], dtype=float32)
#
# loglikelihood=Array(21206.21, dtype=float32)
# theta=array([1.00317964, 1.0031783 , 1.10000163])
# step_size * gradient_step=array([1.3683597e-05, 1.3677854e-05, 6.4134507e-09], dtype=float32)
#
# loglikelihood=Array(21298.184, dtype=float32)
# theta=array([1.00319336, 1.00319202, 1.10000164])
# step_size * gradient_step=array([1.3683597e-05, 1.3677854e-05, 6.4135399e-09], dtype=float32)
#
# loglikelihood=Array(21435.031, dtype=float32)
# theta=array([1.00320709, 1.00320575, 1.10000165])
# step_size * gradient_step=array([1.3683597e-05, 1.3677854e-05, 6.4136270e-09], dtype=float32)
#
# loglikelihood=Array(21517.818, dtype=float32)
# theta=array([1.00322082, 1.00321947, 1.10000166])
# step_size * gradient_step=array([1.3683598e-05, 1.3677854e-05, 6.4137158e-09], dtype=float32)
#
# loglikelihood=Array(21622.666, dtype=float32)
# theta=array([1.00323455, 1.00323319, 1.10000166])
# step_size * gradient_step=array([1.3683598e-05, 1.3677854e-05, 6.4138042e-09], dtype=float32)
#
# loglikelihood=Array(21704.953, dtype=float32)
# theta=array([1.00324827, 1.00324691, 1.10000167])
# step_size * gradient_step=array([1.36835970e-05, 1.36778535e-05, 6.41389208e-09], dtype=float32)
#
# loglikelihood=Array(21819.55, dtype=float32)
# theta=array([1.003262  , 1.00326063, 1.10000168])
# step_size * gradient_step=array([1.36835970e-05, 1.36778535e-05, 6.41398135e-09], dtype=float32)
#
# loglikelihood=Array(21899.213, dtype=float32)
# theta=array([1.00327573, 1.00327436, 1.10000168])
# step_size * gradient_step=array([1.36835970e-05, 1.36778535e-05, 6.41406883e-09], dtype=float32)
#
# loglikelihood=Array(22030.623, dtype=float32)
# theta=array([1.00328946, 1.00328808, 1.10000169])
# step_size * gradient_step=array([1.36835970e-05, 1.36778535e-05, 6.41415765e-09], dtype=float32)
#
# loglikelihood=Array(22158.723, dtype=float32)
# theta=array([1.00330319, 1.0033018 , 1.1000017 ])
# step_size * gradient_step=array([1.36835970e-05, 1.36778535e-05, 6.41424514e-09], dtype=float32)
#
# loglikelihood=Array(22234.258, dtype=float32)
# theta=array([1.00331692, 1.00331552, 1.1000017 ])
# step_size * gradient_step=array([1.36835979e-05, 1.36778535e-05, 6.41433484e-09], dtype=float32)
#
# loglikelihood=Array(22322.918, dtype=float32)
# theta=array([1.00333065, 1.00332925, 1.10000171])
# step_size * gradient_step=array([1.36835979e-05, 1.36778535e-05, 6.41442366e-09], dtype=float32)
#
# loglikelihood=Array(22420.83, dtype=float32)
# theta=array([1.00334438, 1.00334297, 1.10000172])
# step_size * gradient_step=array([1.36835979e-05, 1.36778535e-05, 6.41451114e-09], dtype=float32)
#
# loglikelihood=Array(22511.928, dtype=float32)
# theta=array([1.0033581 , 1.0033567 , 1.10000173])
# step_size * gradient_step=array([1.3683598e-05, 1.3677853e-05, 6.4146000e-09], dtype=float32)
#
# loglikelihood=Array(22596.027, dtype=float32)
# theta=array([1.00337183, 1.00337042, 1.10000173])
# step_size * gradient_step=array([1.3683598e-05, 1.3677853e-05, 6.4146883e-09], dtype=float32)
#
# loglikelihood=Array(22695.875, dtype=float32)
# theta=array([1.00338556, 1.00338414, 1.10000174])
# step_size * gradient_step=array([1.3683597e-05, 1.3677853e-05, 6.4147767e-09], dtype=float32)
#
# loglikelihood=Array(22769.662, dtype=float32)
# theta=array([1.00339929, 1.00339787, 1.10000175])
# step_size * gradient_step=array([1.3683597e-05, 1.3677853e-05, 6.4148655e-09], dtype=float32)
#
# loglikelihood=Array(22868.26, dtype=float32)
# theta=array([1.00341302, 1.00341159, 1.10000175])
# step_size * gradient_step=array([1.36835970e-05, 1.36778535e-05, 6.41495346e-09], dtype=float32)
#
# loglikelihood=Array(22979.734, dtype=float32)
# theta=array([1.00342675, 1.00342532, 1.10000176])
# step_size * gradient_step=array([1.3683597e-05, 1.3677853e-05, 6.4150418e-09], dtype=float32)
#
# loglikelihood=Array(23067.332, dtype=float32)
# ...
#
# loglikelihood=Array(76752.47, dtype=float32)
# theta=array([1.0108272 , 1.01082262, 1.10000556])
# step_size * gradient_step=array([1.3683646e-05, 1.3677861e-05, 6.4627255e-09], dtype=float32)
#
# loglikelihood=Array(76863.82, dtype=float32)
# theta=array([1.01084103, 1.01083644, 1.10000557])
# step_size * gradient_step=array([1.3683646e-05, 1.3677861e-05, 6.4628130e-09], dtype=float32)
#
# loglikelihood=Array(76941.664, dtype=float32)
# theta=array([1.01085486, 1.01085027, 1.10000558])
# step_size * gradient_step=array([1.3683646e-05, 1.3677861e-05, 6.4629022e-09], dtype=float32)
#
# loglikelihood=Array(77006.2, dtype=float32)
# theta=array([1.01086869, 1.0108641 , 1.10000559])
# step_size * gradient_step=array([1.3683646e-05, 1.3677861e-05, 6.4629915e-09], dtype=float32)
#
# loglikelihood=Array(77112.734, dtype=float32)
# theta=array([1.01088253, 1.01087792, 1.10000559])
# step_size * gradient_step=array([1.3683648e-05, 1.3677860e-05, 6.4630803e-09], dtype=float32)
#
# loglikelihood=Array(77205.02, dtype=float32)
# theta=array([1.01089636, 1.01089175, 1.1000056 ])
# step_size * gradient_step=array([1.3683648e-05, 1.3677860e-05, 6.4631696e-09], dtype=float32)
#
# loglikelihood=Array(77329.805, dtype=float32)
# theta=array([1.01091019, 1.01090558, 1.10000561])
# step_size * gradient_step=array([1.3683646e-05, 1.3677859e-05, 6.4632579e-09], dtype=float32)
#
# loglikelihood=Array(77455.03, dtype=float32)
# theta=array([1.01092402, 1.0109194 , 1.10000561])
# step_size * gradient_step=array([1.3683646e-05, 1.3677861e-05, 6.4633476e-09], dtype=float32)
#
# loglikelihood=Array(77543.38, dtype=float32)
# theta=array([1.01093786, 1.01093323, 1.10000562])
# step_size * gradient_step=array([1.3683646e-05, 1.3677861e-05, 6.4634369e-09], dtype=float32)
#
# loglikelihood=Array(77656.914, dtype=float32)
# theta=array([1.01095169, 1.01094706, 1.10000563])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4635257e-09], dtype=float32)
#
# loglikelihood=Array(77747.08, dtype=float32)
# theta=array([1.01096552, 1.01096089, 1.10000564])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4636145e-09], dtype=float32)
#
# loglikelihood=Array(77827.67, dtype=float32)
# theta=array([1.01097936, 1.01097471, 1.10000564])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4637047e-09], dtype=float32)
#
# loglikelihood=Array(77924.586, dtype=float32)
# theta=array([1.01099319, 1.01098854, 1.10000565])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4637935e-09], dtype=float32)
#
# loglikelihood=Array(78028.125, dtype=float32)
# theta=array([1.01100703, 1.01100237, 1.10000566])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4638828e-09], dtype=float32)
#
# loglikelihood=Array(78119.91, dtype=float32)
# theta=array([1.01102086, 1.0110162 , 1.10000566])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4639716e-09], dtype=float32)
#
# loglikelihood=Array(78215.26, dtype=float32)
# theta=array([1.01103469, 1.01103003, 1.10000567])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4640608e-09], dtype=float32)
#
# loglikelihood=Array(78317.98, dtype=float32)
# theta=array([1.01104853, 1.01104386, 1.10000568])
# step_size * gradient_step=array([1.3683648e-05, 1.3677860e-05, 6.4641501e-09], dtype=float32)
#
# loglikelihood=Array(78404.39, dtype=float32)
# theta=array([1.01106236, 1.01105769, 1.10000569])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4642407e-09], dtype=float32)
#
# loglikelihood=Array(78503.984, dtype=float32)
# theta=array([1.0110762 , 1.01107151, 1.10000569])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4643295e-09], dtype=float32)
#
# loglikelihood=Array(78605.21, dtype=float32)
# theta=array([1.01109003, 1.01108534, 1.1000057 ])
# step_size * gradient_step=array([1.3683646e-05, 1.3677860e-05, 6.4644174e-09], dtype=float32)
#
# loglikelihood=Array(78678.25, dtype=float32)
# theta=array([1.01110387, 1.01109917, 1.10000571])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4645076e-09], dtype=float32)
#
# loglikelihood=Array(78805.34, dtype=float32)
# theta=array([1.01111771, 1.011113  , 1.10000571])
# step_size * gradient_step=array([1.3683648e-05, 1.3677858e-05, 6.4645951e-09], dtype=float32)
#
# loglikelihood=Array(78886.07, dtype=float32)
# theta=array([1.01113154, 1.01112683, 1.10000572])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4646857e-09], dtype=float32)
#
# loglikelihood=Array(78984.1, dtype=float32)
# theta=array([1.01114538, 1.01114066, 1.10000573])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4647749e-09], dtype=float32)
#
# loglikelihood=Array(79066.266, dtype=float32)
# theta=array([1.01115921, 1.01115449, 1.10000574])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4648638e-09], dtype=float32)
#
# loglikelihood=Array(79151.62, dtype=float32)
# theta=array([1.01117305, 1.01116832, 1.10000574])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4649535e-09], dtype=float32)
#
# loglikelihood=Array(79262.71, dtype=float32)
# theta=array([1.01118689, 1.01118216, 1.10000575])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4650427e-09], dtype=float32)
#
# loglikelihood=Array(79346.75, dtype=float32)
# theta=array([1.01120072, 1.01119599, 1.10000576])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4651315e-09], dtype=float32)
#
# loglikelihood=Array(79446.97, dtype=float32)
# theta=array([1.01121456, 1.01120982, 1.10000576])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4652208e-09], dtype=float32)
#
# loglikelihood=Array(79535.88, dtype=float32)
# theta=array([1.0112284 , 1.01122365, 1.10000577])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4653101e-09], dtype=float32)
#
# loglikelihood=Array(79621.86, dtype=float32)
# theta=array([1.01124224, 1.01123748, 1.10000578])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4653989e-09], dtype=float32)
#
# loglikelihood=Array(79721.266, dtype=float32)
# theta=array([1.01125607, 1.01125131, 1.10000579])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4654881e-09], dtype=float32)
#
# loglikelihood=Array(79849.99, dtype=float32)
# theta=array([1.01126991, 1.01126514, 1.10000579])
# step_size * gradient_step=array([1.3683650e-05, 1.3677862e-05, 6.4655774e-09], dtype=float32)
#
# loglikelihood=Array(79951.52, dtype=float32)
# theta=array([1.01128375, 1.01127898, 1.1000058 ])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4656662e-09], dtype=float32)
#
# loglikelihood=Array(80055.25, dtype=float32)
# theta=array([1.01129759, 1.01129281, 1.10000581])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4657550e-09], dtype=float32)
#
# loglikelihood=Array(80154.73, dtype=float32)
# theta=array([1.01131143, 1.01130664, 1.10000581])
# step_size * gradient_step=array([1.3683650e-05, 1.3677860e-05, 6.4658447e-09], dtype=float32)
#
# loglikelihood=Array(80275.07, dtype=float32)
# theta=array([1.01132526, 1.01132047, 1.10000582])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4659331e-09], dtype=float32)
#
# loglikelihood=Array(80373.42, dtype=float32)
# theta=array([1.0113391 , 1.01133431, 1.10000583])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4660224e-09], dtype=float32)
#
# loglikelihood=Array(80471.33, dtype=float32)
# theta=array([1.01135294, 1.01134814, 1.10000583])
# step_size * gradient_step=array([1.368365e-05, 1.367786e-05, 6.466111e-09], dtype=float32)
# loglikelihood=Array(80563.74, dtype=float32)
# theta=array([1.01136678, 1.01136197, 1.10000584])
# step_size * gradient_step=array([1.3683649e-05, 1.3677861e-05, 6.4662014e-09], dtype=float32)
#
# loglikelihood=Array(80679.086, dtype=float32)
# theta=array([1.01138062, 1.01137581, 1.10000585])
# step_size * gradient_step=array([1.368365e-05, 1.367786e-05, 6.466290e-09], dtype=float32)
#
# loglikelihood=Array(80776.25, dtype=float32)
# theta=array([1.01139446, 1.01138964, 1.10000586])
# step_size * gradient_step=array([1.368365e-05, 1.367786e-05, 6.466379e-09], dtype=float32)
#
# loglikelihood=Array(80896.85, dtype=float32)
# theta=array([1.0114083 , 1.01140347, 1.10000586])
# step_size * gradient_step=array([1.3683650e-05, 1.3677861e-05, 6.4664682e-09], dtype=float32)
#
# loglikelihood=Array(80984.51, dtype=float32)
# theta=array([1.01142214, 1.01141731, 1.10000587])
# step_size * gradient_step=array([1.3683650e-05, 1.3677860e-05, 6.4665575e-09], dtype=float32)
#
# loglikelihood=Array(81082.17, dtype=float32)
# theta=array([1.01143598, 1.01143114, 1.10000588])
# step_size * gradient_step=array([1.3683650e-05, 1.3677860e-05, 6.4666463e-09], dtype=float32)
#
# loglikelihood=Array(81192.39, dtype=float32)
# theta=array([1.01144982, 1.01144497, 1.10000588])
# step_size * gradient_step=array([1.3683650e-05, 1.3677860e-05, 6.4667356e-09], dtype=float32)
#
# loglikelihood=Array(81259.805, dtype=float32)
# theta=array([1.01146366, 1.01145881, 1.10000589])
# step_size * gradient_step=array([1.368365e-05, 1.367786e-05, 6.466825e-09], dtype=float32)
#
# loglikelihood=Array(81394.84, dtype=float32)
# theta=array([1.0114775 , 1.01147264, 1.1000059 ])
# step_size * gradient_step=array([1.3683652e-05, 1.3677863e-05, 6.4669154e-09], dtype=float32)
#
# loglikelihood=Array(81494.875, dtype=float32)
# theta=array([1.01149134, 1.01148648, 1.10000591])
# step_size * gradient_step=array([1.368365e-05, 1.367786e-05, 6.467004e-09], dtype=float32)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/5l/jdr1h_pn3x3_7nt8kgthzmv00000gn/T/ipykernel_36704/3866176045.py", line 1, in <module>
#     gradient_steps(events,T,theta_guess = [1,1,1.1])
#   File "/var/folders/5l/jdr1h_pn3x3_7nt8kgthzmv00000gn/T/ipykernel_36704/205610471.py", line 18, in gradient_steps
#     gradient_step = np.array(jax.grad(q)(logtheta))
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/traceback_util.py", line 162, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/api.py", line 1089, in grad_f
#     _, g = value_and_grad_f(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/traceback_util.py", line 162, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/api.py", line 1165, in value_and_grad_f
#     ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/api.py", line 2654, in _vjp
#     out_primal, out_vjp = ad.vjp(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/ad.py", line 135, in vjp
#     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/ad.py", line 124, in linearize
#     jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/profiler.py", line 314, in wrapper
#     return func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/partial_eval.py", line 767, in trace_to_jaxpr_nounits
#     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/linear_util.py", line 167, in call_wrapped
#     ans = self.f(*args, **dict(self.params, **kwargs))
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/traceback_util.py", line 162, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/api.py", line 626, in cache_miss
#     top_trace.process_call(primitive, fun_, tracers, params))
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/ad.py", line 339, in process_call
#     result = call_primitive.bind(_update_annotation(f_jvp, f.in_type, which_nz),
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/core.py", line 2024, in bind
#     outs = top_trace.process_call(self, fun_, tracers, params)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/partial_eval.py", line 265, in process_call
#     out = primitive.bind(_update_annotation_known(f_, f.in_type, in_knowns),
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/core.py", line 2024, in bind
#     outs = top_trace.process_call(self, fun_, tracers, params)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/core.py", line 715, in process_call
#     return primitive.impl(f, *tracers, **params)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/dispatch.py", line 247, in _xla_call_impl
#     compiled_fun = _xla_call_impl_lazy(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/dispatch.py", line 241, in _xla_call_impl_lazy
#     return xla_callable(fun, device, backend, name, donated_invars, keep_unused,
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/linear_util.py", line 303, in memoized_fun
#     ans = call(fun, *args)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/dispatch.py", line 359, in _xla_callable_uncached
#     return computation.compile(_allow_propagation_to_outputs=True).unsafe_call
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/pxla.py", line 3202, in compile
#     executable = self._compile_unloaded(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/pxla.py", line 3170, in _compile_unloaded
#     return UnloadedMeshExecutable.from_hlo(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/interpreters/pxla.py", line 3439, in from_hlo
#     xla_executable = dispatch.compile_or_get_cached(
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/dispatch.py", line 1079, in compile_or_get_cached
#     return backend_compile(backend, serialized_computation, compile_options,
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/profiler.py", line 314, in wrapper
#     return func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/jax/_src/dispatch.py", line 1014, in backend_compile
#     return backend.compile(built_c, compile_options=options)
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f98ad69fa90>> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     534         """Cache the modification times of any modules imported in this execution
#     535         """
# --> 536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
#     538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#
# KeyboardInterrupt:

# %% [markdown]
# $$Q\left(\hat\theta\right) = -\int_0^T \mu dt + \sum_{i=1}^n \mathbb P(b_i=0 \vert t,\hat\theta)\log(\mu) - \int_0^T \phi(t) dt + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\log(\phi(t_i))$$

# %% [markdown]
# $$Q_\mu\left(\hat\theta\right)=-T + \frac{1}{\mu}\sum_{i=1}^n \mathbb P(b_i=0\vert t,\hat\theta)=0 \implies \mu = \frac{1}{T}\sum_{i=1}^n \mathbb P(b_i=0\vert t,\hat\theta)$$

# %% [markdown]
# $$Q_\alpha(\hat\theta)=-\sum_{t_i< t} \int_{t_i}^T\exp(\beta (t_i-t))dt+\frac{1}{\alpha}\sum_{i=1}^n\sum_{t_j < t_i}\mathbb P(b_i=j \vert t,\hat\theta)=0\implies \alpha=\frac{\sum_{i=1}^n \mathbb P(b_i=1\vert t,\hat\theta)}{\sum_{i=1}^n \int_{t_i}^T \exp(\beta (t_i-t))dt}=\frac{\sum_{i=1}^n \mathbb P(b_i=1\vert t,\hat\theta)}{\beta\left(\sum_{i=1}^n 1-\exp(\beta (t_i-T))\right)}$$

# %% [markdown]
# $$\phi_\beta(t) = \sum_{t_i<t} (t_i-t)\alpha \exp(\beta(t_i-t))$$

# %% [markdown]
# $$Q_\beta\left(\hat\theta\right)=-\int_0^T \sum_{t_i < t}(t_i-t)\alpha \exp(\beta(t_i-t))dt + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$= -\sum_{i=1}^n \int_{t_i}^T (t_i-t)\alpha \exp(\beta(t_i-t))dt + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$= -\alpha\sum_{i=1}^n \frac{\exp(\beta(t_i-T))(\beta(T-t_i)+1)-1}{\beta^2} + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$= \frac{\alpha}{\beta^2}\left(n-\sum_{i=1}^n \exp(\beta(t_i-T))(\beta(T-t_i)+1)\right) + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$=\frac{\alpha}{\beta} \sum_{i=1}^n \int_{t_i}^T (t_i-t)d\left(\exp(\beta(t_i-t))\right) + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$=\frac{\alpha}{\beta}\sum_{i=1}^n \left((t_i-T)\exp(\beta(t_i-T)) + \int_{t_i}^T \exp(\beta(t_i-t))dt\right) + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$=\frac{\alpha}{\beta}\sum_{i=1}^n \left((t_i-T)\exp(\beta(t_i-T)) + \beta\left(1-\exp(\beta(t_i-T))\right)\right) + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$=n\alpha+\frac{\alpha}{\beta}\sum_{i=1}^n (t_i-T-\beta)\exp(\beta(t_i-T)) + \sum_{i=1}^n \mathbb P(b_i=1 \vert t,\hat\theta)\frac{\sum_{t_j < t_i}(t_j-t_i)\alpha \exp(\beta(t_j-t_i))}{\phi(t_i)}$$

# %% [markdown]
# $$Q_\beta\left(\hat\theta\right)=\beta \left(\int_0^T \phi(t)dt-\sum_{i=1}^n \mathbb P(b_i=1\vert t,\hat\theta)\right)=0 \implies \alpha=\frac{\sum_{i=1}^n \mathbb P(b_i=1\vert t,\hat\theta)}{\beta\left(\sum_{i=1}^n 1-\exp(\beta (t_i-T))\right)}$$

# %% [markdown]
# $$Q_\mu\left(\hat\theta\right)=-T+\sum_{i=1}^n \left(\frac{1+\log(\mu)}{\mu+\phi(t_i)}-\frac{\mu\log(\mu)+\phi(t_i)\log\phi(t_i)}{\left(\mu+\phi(t_i)\right)^2}\right)=-T+\sum_{i=1}^n \left(\frac{(1+\log(\mu))(\mu+\phi(t_i))-\mu\log(\mu)-\phi(t_i)\log\phi(t_i)}{\left(\mu+\phi(t_i)\right)^2}\right)$$

# %% [markdown]
# $$=-T+\sum_{i=1}^n \left(\frac{\mu+(1+\log(\mu)-\log\phi(t_i))\phi(t_i)}{\left(\mu+\phi(t_i)\right)^2}\right)$$

# %%
def q(events,theta,T):
    mu, alpha, beta = theta
    times = [e[0] for e in events]
    intensities = []
    for t in times:
        intensities.append()
    return -T*mu + sum([np.log(mu)*mu/(mu+phi(t))])

# %%
def em(events, timespan, theta_guess = [1,1,1], steps=100):
    #Q    = - mu * T + sum (1 / (mu + phi(t))) * mu * log(mu)
    #       - int phi(s) ds + sum (1 - mu / (mu + phi(t))) * log(phi(t))
    #Q_mu = -T - sum (mu+phi(t))^-2*mu*log(mu) + sum (mu+phi(t))^-1 * (log(mu)+1)
            + sum (1 - )
# Out:
#   File "/var/folders/5l/jdr1h_pn3x3_7nt8kgthzmv00000gn/T/ipykernel_29247/3522125044.py", line 5
#     + sum (1 - )
#                ^
# SyntaxError: invalid syntax
